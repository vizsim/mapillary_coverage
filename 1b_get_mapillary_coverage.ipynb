# %% [markdown]
# # Was tut dieses Skript?
# Dieses Skript lädt die Mapillay coverage je Bundesland je Tiles herunter,
# filtert sie nach Aufnahmedatum,
# und exportiert die Ergebnisse als Parquet-Dateien.

# %%
# Standard library
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime, timezone
import json
import os
import time
import logging
import sys

# Third-party
import geopandas as gpd
import mercantile
import pandas as pd
import requests
from requests.exceptions import SSLError
from tqdm import tqdm
from vt2geojson.tools import vt_bytes_to_geojson


from config import TILES_CONFIG, PROCESSING_CONFIG, MAPILLARY_CONFIG

# Setup Logging
log_folder = PROCESSING_CONFIG["ml_output_folder"]
os.makedirs(log_folder, exist_ok=True)
log_file = os.path.join(log_folder, f"mapillary_download_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log")

# Konfiguriere Logger
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file, encoding='utf-8'),
        logging.StreamHandler(sys.stdout)  # Auch in Console ausgeben
    ]
)

logger = logging.getLogger(__name__)
logger.info(f"=== Mapillary Coverage Download gestartet ===")
logger.info(f"Log-Datei: {log_file}")
# Out:
# 2026-02-02 01:06:47,932 - INFO - === Mapillary Coverage Download gestartet ===
# 2026-02-02 01:06:47,933 - INFO - Log-Datei: ml_output/mapillary_download_20260202_010647.log

# %%
TQDM_ENABLED = os.environ.get("TQDM_DISABLE", "0") != "1"

# %%
### Helper function for loading tile lists

def load_tiles_from_json(bundesland_id, input_folder = TILES_CONFIG["cache_folder"]):
    path = os.path.join(input_folder, f"{bundesland_id}_tiles.json")
    with open(path, "r") as f:
        tile_list = json.load(f)
    return [mercantile.Tile(**t) for t in tile_list]

# %%
def export_geodata(gdfs, output_folder = PROCESSING_CONFIG["output_folder"], base_name="mapillary_coverage", region="ger", save_parquet=True, save_geojson_gz=True):
    """
    Export one or more GeoDataFrames into output files (.parquet only, ohne Datum im Namen).
    
    Args:
        gdfs (list or GeoDataFrame): List of GeoDataFrames or a single GeoDataFrame.
        output_folder (str): Output directory (created if it doesn't exist).
        base_name (str): Base filename prefix.
        region (str): Region tag for filename.
        save_parquet (bool): Save .parquet file.
        save_geojson_gz (bool): Save .geojson.gz file (not implemented).
    
    Returns:
        str: Timestamp when data was processed (ISO format)
    """
    if gdfs is None or (isinstance(gdfs, (gpd.GeoDataFrame, pd.DataFrame)) and gdfs.empty):
        logger.warning("No data to export.")
        return None

    # Concatenate if needed
    if isinstance(gdfs, list):
        gdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))
    else:
        gdf = gdfs

    os.makedirs(output_folder, exist_ok=True)
    
    # Aktueller Zeitstempel für Metadata
    current_timestamp = datetime.now(timezone.utc).isoformat()

    if save_parquet:
        # Dateiname OHNE Datum - nur "latest"
        parquet_path = os.path.join(output_folder, f"{base_name}_{region}_latest.parquet")
        gdf.to_parquet(parquet_path, index=False)
        logger.info(f"✔ Parquet saved to: {parquet_path}")
    
    return current_timestamp

# %%
def process_bundesland(bundesland_id, region_name=None, input_folder = TILES_CONFIG["cache_folder"], output_folder = PROCESSING_CONFIG["ml_output_folder"] , max_workers=3, limit_tiles=None):
    logger.info(f"▶️ Starte Verarbeitung für {bundesland_id}...")

    tiles = load_tiles_from_json(bundesland_id, input_folder=input_folder)
    if limit_tiles:
        tiles = tiles[:limit_tiles]
    
    total_tiles = len(tiles)
    logger.info(f"📊 {bundesland_id}: {total_tiles} Tiles zu verarbeiten")
    
    # genereal config
    # Load your access token
    ACCESS_TOKEN = MAPILLARY_CONFIG["access_token"]

    # Use existing variables
    tile_layer = "sequence"  # or 'image' for points
    tile_coverage = "mly1_computed_public"
    
    # Tracking für aufeinanderfolgende Fehler
    consecutive_parse_errors = 0
    MAX_CONSECUTIVE_ERRORS = 5
    
    # Tracking für Fortschritt
    processed_count = 0
    successful_count = 0

    def process_tile(tile, retry_count=0, max_retries=3):
        """
        Verarbeite ein Tile mit Retry-Logik bei Parsing-Fehlern.
        
        Args:
            tile: Mercantile Tile Objekt
            retry_count: Aktueller Retry-Versuch
            max_retries: Maximale Anzahl an Versuchen
        """
        nonlocal consecutive_parse_errors
        
        url = f"https://tiles.mapillary.com/maps/vtp/{tile_coverage}/2/{tile.z}/{tile.x}/{tile.y}?access_token={ACCESS_TOKEN}"
        
        try:
            response = requests.get(url, timeout=30)
            
            # Rate Limit Check
            if response.status_code == 429:
                logger.warning(f"⚠️ Rate Limit erreicht bei Tile {tile.x}/{tile.y}. Pausiere für 5 Minuten...")
                time.sleep(300)
                if retry_count < max_retries:
                    return process_tile(tile, retry_count + 1, max_retries)
                return None
            
            if response.status_code != 200:
                logger.warning(f"⚠️ HTTP {response.status_code} bei Tile {tile.x}/{tile.y}")
                return None
            
            # Versuche Vector Tile zu parsen
            geojson = vt_bytes_to_geojson(response.content, tile.x, tile.y, tile.z, layer=tile_layer)
            features = geojson.get("features", [])
            
            if not features:
                return None
            
            gdf_tile = gpd.GeoDataFrame.from_features(features, crs="EPSG:4326")
            gdf_tile['captured_at'] = gdf_tile['captured_at'].apply(lambda x: datetime.fromtimestamp(x / 1000, tz=timezone.utc))
            
            # Timefilter
            min_date_str = PROCESSING_CONFIG["min_capture_date"]
            min_dt = datetime.strptime(min_date_str, "%Y-%m-%d").replace(tzinfo=timezone.utc)
            gdf_tile = gdf_tile[gdf_tile['captured_at'] >= min_dt]
            gdf_tile['captured_at'] = gdf_tile['captured_at'].dt.strftime('%Y-%m-%d')

            gdf_tile['tile_x'] = tile.x
            gdf_tile['tile_y'] = tile.y
            
            # Erfolg → Fehler-Counter zurücksetzen
            consecutive_parse_errors = 0
            return gdf_tile
            
        except Exception as e:
            error_msg = str(e)
            
            # Prüfe ob es ein Parsing-Fehler ist (wahrscheinlich Rate Limit)
            if "Error parsing message" in error_msg or "vector_tile" in error_msg:
                consecutive_parse_errors += 1
                
                # Prüfe ob zu viele aufeinanderfolgende Fehler
                if consecutive_parse_errors >= MAX_CONSECUTIVE_ERRORS:
                    logger.error(f"🛑 {MAX_CONSECUTIVE_ERRORS} aufeinanderfolgende Parsing-Fehler! API scheint blockiert zu sein.")
                    logger.warning(f"⏸️  LANGE PAUSE: 30 Minuten warten...")
                    time.sleep(1800)  # 30 Minuten
                    consecutive_parse_errors = 0  # Counter zurücksetzen
                    logger.info(f"▶️ Setze Verarbeitung fort nach langer Pause...")
                
                if retry_count < max_retries:
                    logger.warning(f"⚠️ Parsing-Fehler bei Tile {tile.x}/{tile.y} (Versuch {retry_count + 1}/{max_retries}, konsekutiv: {consecutive_parse_errors}). Pausiere für 5 Minuten...")
                    time.sleep(300)  # 5 Minuten Pause
                    return process_tile(tile, retry_count + 1, max_retries)
                else:
                    logger.error(f"❌ Tile {tile.x}/{tile.y} nach {max_retries} Versuchen fehlgeschlagen: {error_msg}")
                    return None
            else:
                logger.error(f"❌ Fehler bei Tile {tile.x}/{tile.y}: {error_msg}")
                return None

    gdf_all = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(process_tile, tile): tile for tile in tiles}
        for future in tqdm(as_completed(futures), total=len(futures), desc=f"🧩 {bundesland_id}", disable=not TQDM_ENABLED):
            try:
                result = future.result()
                processed_count += 1
                
                if result is not None:
                    gdf_all.append(result)
                    successful_count += 1
                
                # Progress-Logging alle 1000 Tiles (nur wenn >= 1000 Tiles total)
                if total_tiles >= 1000 and processed_count % 1000 == 0:
                    logger.info(f"📈 {bundesland_id}: {processed_count}/{total_tiles} Tiles verarbeitet ({successful_count} erfolgreich)")
                    
            except SSLError as e:
                logger.warning(f"⚠️ SSLError: {e}. Pausiere für 5 Minuten...")
                time.sleep(300)
            except Exception as e:
                logger.error(f"⚠️ Unbekannter Fehler: {e}")
    
    # Final Summary
    logger.info(f"✅ {bundesland_id}: {processed_count}/{total_tiles} Tiles abgeschlossen ({successful_count} erfolgreich, {processed_count - successful_count} fehlgeschlagen)")

    if gdf_all:
        gdf_all = gpd.GeoDataFrame(pd.concat(gdf_all, ignore_index=True))
        timestamp = export_geodata(
            gdfs=gdf_all,
            output_folder=output_folder,
            region=bundesland_id,
            save_parquet=True,
            save_geojson_gz=False
        )
        return timestamp
    else:
        logger.warning(f"⚠️ Keine Daten für {bundesland_id}.")
        return None

# %%
# Verarbeitung der Bundesländer basierend auf config.py
# takes about ~6.5h for all 16 bundesländer (on lokal machine)

# Lade Bundesländer aus Cache (wurde in Notebook 0 heruntergeladen)
bundesland_cache_path = os.path.join("prep", "bundeslaender.geojson")

if not os.path.exists(bundesland_cache_path):
    logger.error(f"❌ Bundesland-Cache nicht gefunden: {bundesland_cache_path}")
    logger.error(f"   Bitte zuerst Notebook 0_prepare_tiles.ipynb ausführen!")
    raise FileNotFoundError(f"Bundesland-GeoJSON fehlt: {bundesland_cache_path}")

logger.info(f"📂 Lade Bundesländer aus: {bundesland_cache_path}")
bland = gpd.read_file(bundesland_cache_path)

# Filter Bundesländer basierend auf config.py
from config import GEOFABRIK_CONFIG

selected_bundeslaender = GEOFABRIK_CONFIG.get("bundeslaender")
if selected_bundeslaender:
    # Nur die ausgewählten Bundesländer verarbeiten
    bland_filtered = bland[bland['id'].isin(selected_bundeslaender)]
    logger.info(f"🎯 Verarbeite {len(bland_filtered)} ausgewählte Bundesländer: {', '.join(selected_bundeslaender)}")
else:
    # Alle Bundesländer verarbeiten
    bland_filtered = bland
    logger.info(f"📍 Verarbeite alle {len(bland_filtered)} Bundesländer")

# Sammle Timestamps für Metadata
ml_timestamps = {}

for _, row in bland_filtered.iterrows():
    b_id = row["id"]
    name = row["name"]

    # Nur verarbeiten, wenn eine JSON-Datei existiert
    tile_json_path = os.path.join(TILES_CONFIG["cache_folder"], f"{b_id}_tiles.json")
    if not os.path.exists(tile_json_path):
        logger.warning(f"⏩ Überspringe {b_id}, keine Tiles gefunden.")
        continue

    # Prüfe ob Parquet bereits existiert und noch aktuell ist
    output_folder = PROCESSING_CONFIG["ml_output_folder"]
    parquet_path = os.path.join(output_folder, f"mapillary_coverage_{b_id}_latest.parquet")
    max_age_days = PROCESSING_CONFIG.get('max_file_age_days', 4)
    
    if os.path.exists(parquet_path):
        file_mtime = os.path.getmtime(parquet_path)
        file_age_days = (datetime.now().timestamp() - file_mtime) / 86400  # Sekunden in Tage
        
        if file_age_days < max_age_days:
            logger.info(f"⏩ {b_id}: Datei ist {file_age_days:.1f} Tage alt, überspringe Download")
            # Timestamp aus existierender Datei für Metadata verwenden
            ml_timestamps[b_id] = datetime.fromtimestamp(file_mtime, tz=timezone.utc).isoformat()
            continue
        else:
            logger.info(f"🔄 {b_id}: Datei ist {file_age_days:.1f} Tage alt, lade neu")

    timestamp = process_bundesland(b_id, region_name=name)
    if timestamp:
        ml_timestamps[b_id] = timestamp

# Speichere Metadata ähnlich wie osm_metadata.json
if ml_timestamps:
    # Finde ältesten Timestamp
    oldest_ml_timestamp = min(ml_timestamps.values())
    
    metadata = {
        "ml_data_from": oldest_ml_timestamp,
        "bundeslaender": ml_timestamps,
        "processed_date": datetime.now(timezone.utc).isoformat()
    }
    
    with open("output/ml_metadata.json", "w", encoding="utf-8") as f:
        json.dump(metadata, f, ensure_ascii=False, indent=2)
    
    logger.info(f"\n📅 Ältester Mapillary-Timestamp: {oldest_ml_timestamp}")
    logger.info(f"💾 Metadata gespeichert: output/ml_metadata.json")
    logger.info(f"📄 Log-Datei: {log_file}")
else:
    logger.warning("\n⚠️  Keine Mapillary-Daten verarbeitet, keine Metadata erstellt.")

logger.info("=== Mapillary Coverage Download abgeschlossen ===")
# Out:
# 2026-02-02 01:06:48,025 - INFO - 📂 Lade Bundesländer aus: prep/bundeslaender.geojson
# 2026-02-02 01:06:48,709 - INFO - 📍 Verarbeite alle 16 Bundesländer
# 2026-02-02 01:06:48,713 - INFO - 🔄 DE-BW: Datei ist 8.6 Tage alt, lade neu
# 2026-02-02 01:06:48,714 - INFO - ▶️ Starte Verarbeitung für DE-BW...
# 2026-02-02 01:06:48,778 - INFO - 📊 DE-BW: 14160 Tiles zu verarbeiten
# 2026-02-02 01:09:01,750 - INFO - 📈 DE-BW: 1000/14160 Tiles verarbeitet (843 erfolgreich)
# 2026-02-02 01:10:42,357 - INFO - 📈 DE-BW: 2000/14160 Tiles verarbeitet (1591 erfolgreich)
# 2026-02-02 01:12:24,520 - INFO - 📈 DE-BW: 3000/14160 Tiles verarbeitet (2376 erfolgreich)
# 2026-02-02 01:14:53,150 - INFO - 📈 DE-BW: 4000/14160 Tiles verarbeitet (3226 erfolgreich)
# 2026-02-02 01:18:12,325 - INFO - 📈 DE-BW: 5000/14160 Tiles verarbeitet (4066 erfolgreich)
# 2026-02-02 01:20:20,566 - INFO - 📈 DE-BW: 6000/14160 Tiles verarbeitet (4901 erfolgreich)
# 2026-02-02 01:22:54,133 - INFO - 📈 DE-BW: 7000/14160 Tiles verarbeitet (5771 erfolgreich)
# 2026-02-02 01:27:12,272 - INFO - 📈 DE-BW: 8000/14160 Tiles verarbeitet (6671 erfolgreich)
# 2026-02-02 01:29:59,290 - INFO - 📈 DE-BW: 9000/14160 Tiles verarbeitet (7557 erfolgreich)
# 2026-02-02 01:31:56,149 - INFO - 📈 DE-BW: 10000/14160 Tiles verarbeitet (8395 erfolgreich)
# 2026-02-02 01:33:39,851 - INFO - 📈 DE-BW: 11000/14160 Tiles verarbeitet (9185 erfolgreich)
# 2026-02-02 01:35:31,628 - INFO - 📈 DE-BW: 12000/14160 Tiles verarbeitet (9987 erfolgreich)
# 2026-02-02 01:37:29,230 - INFO - 📈 DE-BW: 13000/14160 Tiles verarbeitet (10799 erfolgreich)
# 2026-02-02 01:39:23,948 - INFO - 📈 DE-BW: 14000/14160 Tiles verarbeitet (11564 erfolgreich)
# 2026-02-02 01:39:37,733 - INFO - ✅ DE-BW: 14160/14160 Tiles abgeschlossen (11667 erfolgreich, 2493 fehlgeschlagen)
# 2026-02-02 01:39:44,998 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BW_latest.parquet
# 2026-02-02 01:39:46,035 - INFO - 🔄 DE-BY: Datei ist 8.6 Tage alt, lade neu
# 2026-02-02 01:39:46,036 - INFO - ▶️ Starte Verarbeitung für DE-BY...
# 2026-02-02 01:39:46,116 - INFO - 📊 DE-BY: 28376 Tiles zu verarbeiten
# 2026-02-02 01:41:44,629 - INFO - 📈 DE-BY: 1000/28376 Tiles verarbeitet (789 erfolgreich)
# 2026-02-02 01:43:39,668 - INFO - 📈 DE-BY: 2000/28376 Tiles verarbeitet (1522 erfolgreich)
# 2026-02-02 01:46:07,618 - INFO - 📈 DE-BY: 3000/28376 Tiles verarbeitet (2268 erfolgreich)
# 2026-02-02 01:48:02,045 - INFO - 📈 DE-BY: 4000/28376 Tiles verarbeitet (2982 erfolgreich)
# 2026-02-02 01:49:41,871 - INFO - 📈 DE-BY: 5000/28376 Tiles verarbeitet (3612 erfolgreich)
# 2026-02-02 01:51:10,694 - INFO - 📈 DE-BY: 6000/28376 Tiles verarbeitet (4216 erfolgreich)
# 2026-02-02 01:52:52,910 - INFO - 📈 DE-BY: 7000/28376 Tiles verarbeitet (4975 erfolgreich)
# 2026-02-02 01:54:33,068 - INFO - 📈 DE-BY: 8000/28376 Tiles verarbeitet (5663 erfolgreich)
# 2026-02-02 01:57:15,994 - INFO - 📈 DE-BY: 9000/28376 Tiles verarbeitet (6369 erfolgreich)
# 2026-02-02 02:02:31,339 - INFO - 📈 DE-BY: 10000/28376 Tiles verarbeitet (7076 erfolgreich)
# 2026-02-02 02:06:59,475 - INFO - 📈 DE-BY: 11000/28376 Tiles verarbeitet (7718 erfolgreich)
# 2026-02-02 02:08:52,203 - INFO - 📈 DE-BY: 12000/28376 Tiles verarbeitet (8410 erfolgreich)
# 2026-02-02 02:10:40,648 - INFO - 📈 DE-BY: 13000/28376 Tiles verarbeitet (9081 erfolgreich)
# 2026-02-02 02:12:24,093 - INFO - 📈 DE-BY: 14000/28376 Tiles verarbeitet (9762 erfolgreich)
# 2026-02-02 02:14:33,347 - INFO - 📈 DE-BY: 15000/28376 Tiles verarbeitet (10394 erfolgreich)
# 2026-02-02 02:17:21,492 - INFO - 📈 DE-BY: 16000/28376 Tiles verarbeitet (11040 erfolgreich)
# 2026-02-02 02:19:53,452 - INFO - 📈 DE-BY: 17000/28376 Tiles verarbeitet (11630 erfolgreich)
# 2026-02-02 02:21:57,211 - INFO - 📈 DE-BY: 18000/28376 Tiles verarbeitet (12219 erfolgreich)
# 2026-02-02 02:23:45,112 - INFO - 📈 DE-BY: 19000/28376 Tiles verarbeitet (12832 erfolgreich)
# 2026-02-02 02:25:36,550 - INFO - 📈 DE-BY: 20000/28376 Tiles verarbeitet (13466 erfolgreich)
# 2026-02-02 02:28:00,801 - INFO - 📈 DE-BY: 21000/28376 Tiles verarbeitet (14204 erfolgreich)
# 2026-02-02 02:29:54,216 - INFO - 📈 DE-BY: 22000/28376 Tiles verarbeitet (14947 erfolgreich)
# 2026-02-02 02:32:04,660 - INFO - 📈 DE-BY: 23000/28376 Tiles verarbeitet (15614 erfolgreich)
# 2026-02-02 02:35:00,590 - INFO - 📈 DE-BY: 24000/28376 Tiles verarbeitet (16191 erfolgreich)
# 2026-02-02 02:41:02,604 - INFO - 📈 DE-BY: 25000/28376 Tiles verarbeitet (16807 erfolgreich)
# 2026-02-02 02:43:32,811 - INFO - 📈 DE-BY: 26000/28376 Tiles verarbeitet (17420 erfolgreich)
# 2026-02-02 02:45:28,050 - INFO - 📈 DE-BY: 27000/28376 Tiles verarbeitet (18039 erfolgreich)
# 2026-02-02 02:46:53,548 - INFO - 📈 DE-BY: 28000/28376 Tiles verarbeitet (18553 erfolgreich)
# 2026-02-02 02:47:20,993 - INFO - ✅ DE-BY: 28376/28376 Tiles abgeschlossen (18708 erfolgreich, 9668 fehlgeschlagen)
# 2026-02-02 02:47:32,007 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BY_latest.parquet
# 2026-02-02 02:47:33,397 - INFO - 🔄 DE-BE: Datei ist 8.6 Tage alt, lade neu
# 2026-02-02 02:47:33,399 - INFO - ▶️ Starte Verarbeitung für DE-BE...
# 2026-02-02 02:47:33,403 - INFO - 📊 DE-BE: 399 Tiles zu verarbeiten
# 2026-02-02 02:56:23,808 - INFO - ✅ DE-BE: 399/399 Tiles abgeschlossen (398 erfolgreich, 1 fehlgeschlagen)
# 2026-02-02 02:56:24,431 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BE_latest.parquet
# 2026-02-02 02:56:24,568 - INFO - 🔄 DE-BB: Datei ist 8.6 Tage alt, lade neu
# 2026-02-02 02:56:24,570 - INFO - ▶️ Starte Verarbeitung für DE-BB...
# 2026-02-02 02:56:24,606 - INFO - 📊 DE-BB: 13585 Tiles zu verarbeiten
# 2026-02-02 02:58:16,537 - INFO - 📈 DE-BB: 1000/13585 Tiles verarbeitet (636 erfolgreich)
# 2026-02-02 02:59:34,871 - INFO - 📈 DE-BB: 2000/13585 Tiles verarbeitet (1286 erfolgreich)
# 2026-02-02 03:00:58,797 - INFO - 📈 DE-BB: 3000/13585 Tiles verarbeitet (1917 erfolgreich)
# 2026-02-02 03:02:35,433 - INFO - 📈 DE-BB: 4000/13585 Tiles verarbeitet (2656 erfolgreich)
# 2026-02-02 03:04:29,495 - INFO - 📈 DE-BB: 5000/13585 Tiles verarbeitet (3461 erfolgreich)
# 2026-02-02 03:06:30,526 - INFO - 📈 DE-BB: 6000/13585 Tiles verarbeitet (4323 erfolgreich)
# 2026-02-02 03:08:44,894 - INFO - 📈 DE-BB: 7000/13585 Tiles verarbeitet (5185 erfolgreich)
# 2026-02-02 03:10:57,529 - INFO - 📈 DE-BB: 8000/13585 Tiles verarbeitet (6063 erfolgreich)
# 2026-02-02 03:12:52,516 - INFO - 📈 DE-BB: 9000/13585 Tiles verarbeitet (6928 erfolgreich)
# 2026-02-02 03:14:31,453 - INFO - 📈 DE-BB: 10000/13585 Tiles verarbeitet (7785 erfolgreich)
# 2026-02-02 03:15:55,276 - INFO - 📈 DE-BB: 11000/13585 Tiles verarbeitet (8618 erfolgreich)
# 2026-02-02 03:17:24,030 - INFO - 📈 DE-BB: 12000/13585 Tiles verarbeitet (9395 erfolgreich)
# 2026-02-02 03:18:53,509 - INFO - 📈 DE-BB: 13000/13585 Tiles verarbeitet (10228 erfolgreich)
# 2026-02-02 03:19:45,144 - INFO - ✅ DE-BB: 13585/13585 Tiles abgeschlossen (10718 erfolgreich, 2867 fehlgeschlagen)
# 2026-02-02 03:19:50,538 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BB_latest.parquet
# 2026-02-02 03:19:51,021 - INFO - 🔄 DE-HB: Datei ist 8.6 Tage alt, lade neu
# 2026-02-02 03:19:51,023 - INFO - ▶️ Starte Verarbeitung für DE-HB...
# 2026-02-02 03:19:51,029 - INFO - 📊 DE-HB: 145 Tiles zu verarbeiten
# 2026-02-02 03:20:52,115 - INFO - ✅ DE-HB: 145/145 Tiles abgeschlossen (135 erfolgreich, 10 fehlgeschlagen)
# 2026-02-02 03:20:52,218 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HB_latest.parquet
# 2026-02-02 03:20:52,234 - INFO - 🔄 DE-HH: Datei ist 8.6 Tage alt, lade neu
# 2026-02-02 03:20:52,236 - INFO - ▶️ Starte Verarbeitung für DE-HH...
# 2026-02-02 03:20:52,239 - INFO - 📊 DE-HH: 361 Tiles zu verarbeiten
# 2026-02-02 03:24:01,358 - INFO - ✅ DE-HH: 361/361 Tiles abgeschlossen (359 erfolgreich, 2 fehlgeschlagen)
# 2026-02-02 03:24:01,743 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HH_latest.parquet
# 2026-02-02 03:24:01,790 - INFO - 🔄 DE-HE: Datei ist 8.6 Tage alt, lade neu
# 2026-02-02 03:24:01,791 - INFO - ▶️ Starte Verarbeitung für DE-HE...
# 2026-02-02 03:24:01,815 - INFO - 📊 DE-HE: 8704 Tiles zu verarbeiten
# 2026-02-02 03:26:19,908 - INFO - 📈 DE-HE: 1000/8704 Tiles verarbeitet (805 erfolgreich)
# 2026-02-02 03:29:10,807 - INFO - 📈 DE-HE: 2000/8704 Tiles verarbeitet (1650 erfolgreich)
# 2026-02-02 03:34:54,114 - INFO - 📈 DE-HE: 3000/8704 Tiles verarbeitet (2541 erfolgreich)
# 2026-02-02 03:37:11,795 - INFO - 📈 DE-HE: 4000/8704 Tiles verarbeitet (3344 erfolgreich)
# 2026-02-02 03:39:10,843 - INFO - 📈 DE-HE: 5000/8704 Tiles verarbeitet (4108 erfolgreich)
# 2026-02-02 03:41:01,491 - INFO - 📈 DE-HE: 6000/8704 Tiles verarbeitet (4780 erfolgreich)
# 2026-02-02 03:43:00,303 - INFO - 📈 DE-HE: 7000/8704 Tiles verarbeitet (5448 erfolgreich)
# 2026-02-02 03:45:20,213 - INFO - 📈 DE-HE: 8000/8704 Tiles verarbeitet (6089 erfolgreich)
# 2026-02-02 03:46:48,695 - INFO - ✅ DE-HE: 8704/8704 Tiles abgeschlossen (6639 erfolgreich, 2065 fehlgeschlagen)
# 2026-02-02 03:46:52,460 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HE_latest.parquet
# 2026-02-02 03:46:52,837 - INFO - 🔄 DE-MV: Datei ist 8.6 Tage alt, lade neu
# 2026-02-02 03:46:52,838 - INFO - ▶️ Starte Verarbeitung für DE-MV...
# 2026-02-02 03:46:52,866 - INFO - 📊 DE-MV: 12294 Tiles zu verarbeiten
# 2026-02-02 03:48:48,654 - INFO - 📈 DE-MV: 1000/12294 Tiles verarbeitet (595 erfolgreich)
# 2026-02-02 03:50:34,582 - INFO - 📈 DE-MV: 2000/12294 Tiles verarbeitet (1158 erfolgreich)
# 2026-02-02 03:52:14,966 - INFO - 📈 DE-MV: 3000/12294 Tiles verarbeitet (1674 erfolgreich)
# 2026-02-02 03:53:51,236 - INFO - 📈 DE-MV: 4000/12294 Tiles verarbeitet (2038 erfolgreich)
# 2026-02-02 03:55:37,356 - INFO - 📈 DE-MV: 5000/12294 Tiles verarbeitet (2544 erfolgreich)
# 2026-02-02 03:57:20,160 - INFO - 📈 DE-MV: 6000/12294 Tiles verarbeitet (2980 erfolgreich)
# 2026-02-02 03:58:55,571 - INFO - 📈 DE-MV: 7000/12294 Tiles verarbeitet (3406 erfolgreich)
# 2026-02-02 04:00:28,344 - INFO - 📈 DE-MV: 8000/12294 Tiles verarbeitet (3731 erfolgreich)
# 2026-02-02 04:02:09,903 - INFO - 📈 DE-MV: 9000/12294 Tiles verarbeitet (4124 erfolgreich)
# 2026-02-02 04:03:50,892 - INFO - 📈 DE-MV: 10000/12294 Tiles verarbeitet (4627 erfolgreich)
# 2026-02-02 04:05:28,863 - INFO - 📈 DE-MV: 11000/12294 Tiles verarbeitet (5108 erfolgreich)
# 2026-02-02 04:07:09,712 - INFO - 📈 DE-MV: 12000/12294 Tiles verarbeitet (5610 erfolgreich)
# 2026-02-02 04:07:35,434 - WARNING - ⚠️ HTTP 404 bei Tile 8841/5298
# 2026-02-02 04:07:43,681 - INFO - ✅ DE-MV: 12294/12294 Tiles abgeschlossen (5798 erfolgreich, 6496 fehlgeschlagen)
# 2026-02-02 04:07:46,505 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-MV_latest.parquet
# 2026-02-02 04:07:46,740 - INFO - 🔄 DE-NI: Datei ist 8.6 Tage alt, lade neu
# 2026-02-02 04:07:46,741 - INFO - ▶️ Starte Verarbeitung für DE-NI...
# 2026-02-02 04:07:46,799 - INFO - 📊 DE-NI: 22844 Tiles zu verarbeiten
# 2026-02-02 04:10:19,509 - INFO - 📈 DE-NI: 1000/22844 Tiles verarbeitet (767 erfolgreich)
# 2026-02-02 04:12:21,199 - INFO - 📈 DE-NI: 2000/22844 Tiles verarbeitet (1493 erfolgreich)
# 2026-02-02 04:14:06,929 - INFO - 📈 DE-NI: 3000/22844 Tiles verarbeitet (2101 erfolgreich)
# 2026-02-02 04:15:47,829 - INFO - 📈 DE-NI: 4000/22844 Tiles verarbeitet (2467 erfolgreich)
# 2026-02-02 04:17:27,405 - INFO - 📈 DE-NI: 5000/22844 Tiles verarbeitet (3028 erfolgreich)
# 2026-02-02 04:19:30,311 - INFO - 📈 DE-NI: 6000/22844 Tiles verarbeitet (3710 erfolgreich)
# 2026-02-02 04:21:45,757 - INFO - 📈 DE-NI: 7000/22844 Tiles verarbeitet (4422 erfolgreich)
# 2026-02-02 04:23:36,089 - INFO - 📈 DE-NI: 8000/22844 Tiles verarbeitet (5026 erfolgreich)
# 2026-02-02 04:25:34,243 - INFO - 📈 DE-NI: 9000/22844 Tiles verarbeitet (5660 erfolgreich)
# 2026-02-02 04:27:20,623 - INFO - 📈 DE-NI: 10000/22844 Tiles verarbeitet (6239 erfolgreich)
# 2026-02-02 04:29:07,412 - INFO - 📈 DE-NI: 11000/22844 Tiles verarbeitet (6855 erfolgreich)
# 2026-02-02 04:31:12,620 - INFO - 📈 DE-NI: 12000/22844 Tiles verarbeitet (7574 erfolgreich)
# 2026-02-02 04:33:12,036 - INFO - 📈 DE-NI: 13000/22844 Tiles verarbeitet (8261 erfolgreich)
# 2026-02-02 04:35:18,934 - INFO - 📈 DE-NI: 14000/22844 Tiles verarbeitet (9011 erfolgreich)
# 2026-02-02 04:37:47,092 - INFO - 📈 DE-NI: 15000/22844 Tiles verarbeitet (9796 erfolgreich)
# 2026-02-02 04:40:27,401 - INFO - 📈 DE-NI: 16000/22844 Tiles verarbeitet (10528 erfolgreich)
# 2026-02-02 04:43:18,368 - INFO - 📈 DE-NI: 17000/22844 Tiles verarbeitet (11374 erfolgreich)
# 2026-02-02 04:45:45,484 - INFO - 📈 DE-NI: 18000/22844 Tiles verarbeitet (12145 erfolgreich)
# 2026-02-02 04:47:54,026 - INFO - 📈 DE-NI: 19000/22844 Tiles verarbeitet (12931 erfolgreich)
# 2026-02-02 04:50:31,957 - INFO - 📈 DE-NI: 20000/22844 Tiles verarbeitet (13690 erfolgreich)
# 2026-02-02 04:53:32,405 - INFO - 📈 DE-NI: 21000/22844 Tiles verarbeitet (14543 erfolgreich)
# 2026-02-02 04:55:55,445 - INFO - 📈 DE-NI: 22000/22844 Tiles verarbeitet (15303 erfolgreich)
# 2026-02-02 04:57:30,446 - INFO - ✅ DE-NI: 22844/22844 Tiles abgeschlossen (15939 erfolgreich, 6905 fehlgeschlagen)
# 2026-02-02 04:57:38,468 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-NI_latest.parquet
# 2026-02-02 04:57:39,204 - INFO - 🔄 DE-NW: Datei ist 8.6 Tage alt, lade neu
# 2026-02-02 04:57:39,207 - INFO - ▶️ Starte Verarbeitung für DE-NW...
# 2026-02-02 04:57:39,245 - INFO - 📊 DE-NW: 15243 Tiles zu verarbeiten
# 2026-02-02 05:00:36,475 - INFO - 📈 DE-NW: 1000/15243 Tiles verarbeitet (688 erfolgreich)
# 2026-02-02 05:05:52,698 - INFO - 📈 DE-NW: 2000/15243 Tiles verarbeitet (1659 erfolgreich)
# 2026-02-02 05:09:23,207 - INFO - 📈 DE-NW: 3000/15243 Tiles verarbeitet (2583 erfolgreich)
# 2026-02-02 05:13:39,246 - INFO - 📈 DE-NW: 4000/15243 Tiles verarbeitet (3498 erfolgreich)
# 2026-02-02 05:17:56,574 - INFO - 📈 DE-NW: 5000/15243 Tiles verarbeitet (4408 erfolgreich)
# 2026-02-02 05:22:29,319 - INFO - 📈 DE-NW: 6000/15243 Tiles verarbeitet (5355 erfolgreich)
# 2026-02-02 05:26:56,419 - INFO - 📈 DE-NW: 7000/15243 Tiles verarbeitet (6283 erfolgreich)
# 2026-02-02 05:29:59,083 - INFO - 📈 DE-NW: 8000/15243 Tiles verarbeitet (7180 erfolgreich)
# 2026-02-02 05:33:05,959 - INFO - 📈 DE-NW: 9000/15243 Tiles verarbeitet (8058 erfolgreich)
# 2026-02-02 05:36:37,122 - INFO - 📈 DE-NW: 10000/15243 Tiles verarbeitet (8860 erfolgreich)
# 2026-02-02 05:39:03,737 - INFO - 📈 DE-NW: 11000/15243 Tiles verarbeitet (9625 erfolgreich)
# 2026-02-02 05:41:02,544 - INFO - 📈 DE-NW: 12000/15243 Tiles verarbeitet (10265 erfolgreich)
# 2026-02-02 05:43:53,174 - INFO - 📈 DE-NW: 13000/15243 Tiles verarbeitet (11019 erfolgreich)
# 2026-02-02 05:46:50,941 - INFO - 📈 DE-NW: 14000/15243 Tiles verarbeitet (11839 erfolgreich)
# 2026-02-02 05:49:57,648 - INFO - 📈 DE-NW: 15000/15243 Tiles verarbeitet (12686 erfolgreich)
# 2026-02-02 05:50:22,192 - INFO - ✅ DE-NW: 15243/15243 Tiles abgeschlossen (12859 erfolgreich, 2384 fehlgeschlagen)
# 2026-02-02 05:50:29,783 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-NW_latest.parquet
# 2026-02-02 05:50:30,661 - INFO - 🔄 DE-RP: Datei ist 8.6 Tage alt, lade neu
# 2026-02-02 05:50:30,664 - INFO - ▶️ Starte Verarbeitung für DE-RP...
# 2026-02-02 05:50:30,705 - INFO - 📊 DE-RP: 8240 Tiles zu verarbeiten
# 2026-02-02 05:53:09,362 - INFO - 📈 DE-RP: 1000/8240 Tiles verarbeitet (835 erfolgreich)
# 2026-02-02 05:55:11,050 - INFO - 📈 DE-RP: 2000/8240 Tiles verarbeitet (1755 erfolgreich)
# 2026-02-02 05:57:19,555 - INFO - 📈 DE-RP: 3000/8240 Tiles verarbeitet (2653 erfolgreich)
# 2026-02-02 05:59:38,195 - INFO - 📈 DE-RP: 4000/8240 Tiles verarbeitet (3557 erfolgreich)
# 2026-02-02 06:02:00,733 - INFO - 📈 DE-RP: 5000/8240 Tiles verarbeitet (4419 erfolgreich)
# 2026-02-02 06:04:19,708 - INFO - 📈 DE-RP: 6000/8240 Tiles verarbeitet (5221 erfolgreich)
# 2026-02-02 06:06:35,240 - INFO - 📈 DE-RP: 7000/8240 Tiles verarbeitet (6029 erfolgreich)
# 2026-02-02 06:09:20,098 - INFO - 📈 DE-RP: 8000/8240 Tiles verarbeitet (6931 erfolgreich)
# 2026-02-02 06:10:12,600 - INFO - ✅ DE-RP: 8240/8240 Tiles abgeschlossen (7153 erfolgreich, 1087 fehlgeschlagen)
# 2026-02-02 06:10:16,544 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-RP_latest.parquet
# 2026-02-02 06:10:16,907 - INFO - 🔄 DE-SL: Datei ist 8.6 Tage alt, lade neu
# 2026-02-02 06:10:16,909 - INFO - ▶️ Starte Verarbeitung für DE-SL...
# 2026-02-02 06:10:16,916 - INFO - 📊 DE-SL: 1170 Tiles zu verarbeiten
# 2026-02-02 06:13:15,765 - INFO - 📈 DE-SL: 1000/1170 Tiles verarbeitet (883 erfolgreich)
# 2026-02-02 06:13:57,472 - INFO - ✅ DE-SL: 1170/1170 Tiles abgeschlossen (1035 erfolgreich, 135 fehlgeschlagen)
# 2026-02-02 06:13:58,049 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SL_latest.parquet
# 2026-02-02 06:13:58,102 - INFO - 🔄 DE-ST: Datei ist 8.6 Tage alt, lade neu
# 2026-02-02 06:13:58,104 - INFO - ▶️ Starte Verarbeitung für DE-ST...
# 2026-02-02 06:13:58,142 - INFO - 📊 DE-ST: 9077 Tiles zu verarbeiten
# 2026-02-02 06:15:39,789 - INFO - 📈 DE-ST: 1000/9077 Tiles verarbeitet (587 erfolgreich)
# 2026-02-02 06:17:22,995 - INFO - 📈 DE-ST: 2000/9077 Tiles verarbeitet (1224 erfolgreich)
# 2026-02-02 06:19:06,948 - INFO - 📈 DE-ST: 3000/9077 Tiles verarbeitet (1772 erfolgreich)
# 2026-02-02 06:20:52,001 - INFO - 📈 DE-ST: 4000/9077 Tiles verarbeitet (2315 erfolgreich)
# 2026-02-02 06:22:45,810 - INFO - 📈 DE-ST: 5000/9077 Tiles verarbeitet (2925 erfolgreich)
# 2026-02-02 06:24:44,364 - INFO - 📈 DE-ST: 6000/9077 Tiles verarbeitet (3613 erfolgreich)
# 2026-02-02 06:27:23,690 - INFO - 📈 DE-ST: 7000/9077 Tiles verarbeitet (4306 erfolgreich)
# 2026-02-02 06:29:38,498 - INFO - 📈 DE-ST: 8000/9077 Tiles verarbeitet (4913 erfolgreich)
# 2026-02-02 06:31:38,061 - INFO - 📈 DE-ST: 9000/9077 Tiles verarbeitet (5666 erfolgreich)
# 2026-02-02 06:31:45,874 - INFO - ✅ DE-ST: 9077/9077 Tiles abgeschlossen (5717 erfolgreich, 3360 fehlgeschlagen)
# 2026-02-02 06:31:49,156 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-ST_latest.parquet
# 2026-02-02 06:31:49,470 - INFO - 🔄 DE-SN: Datei ist 8.6 Tage alt, lade neu
# 2026-02-02 06:31:49,472 - INFO - ▶️ Starte Verarbeitung für DE-SN...
# 2026-02-02 06:31:49,507 - INFO - 📊 DE-SN: 8311 Tiles zu verarbeiten
# 2026-02-02 06:34:34,686 - INFO - 📈 DE-SN: 1000/8311 Tiles verarbeitet (800 erfolgreich)
# 2026-02-02 06:38:00,551 - INFO - 📈 DE-SN: 2000/8311 Tiles verarbeitet (1633 erfolgreich)
# 2026-02-02 06:40:12,970 - INFO - 📈 DE-SN: 3000/8311 Tiles verarbeitet (2419 erfolgreich)
# 2026-02-02 06:42:17,646 - INFO - 📈 DE-SN: 4000/8311 Tiles verarbeitet (3189 erfolgreich)
# 2026-02-02 06:44:07,420 - INFO - 📈 DE-SN: 5000/8311 Tiles verarbeitet (3948 erfolgreich)
# 2026-02-02 06:46:33,243 - INFO - 📈 DE-SN: 6000/8311 Tiles verarbeitet (4751 erfolgreich)
# 2026-02-02 06:48:14,223 - INFO - 📈 DE-SN: 7000/8311 Tiles verarbeitet (5483 erfolgreich)
# 2026-02-02 06:50:13,274 - INFO - 📈 DE-SN: 8000/8311 Tiles verarbeitet (6225 erfolgreich)
# 2026-02-02 06:51:11,294 - INFO - ✅ DE-SN: 8311/8311 Tiles abgeschlossen (6452 erfolgreich, 1859 fehlgeschlagen)
# 2026-02-02 06:51:14,740 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SN_latest.parquet
# 2026-02-02 06:51:15,108 - INFO - 🔄 DE-SH: Datei ist 8.6 Tage alt, lade neu
# 2026-02-02 06:51:15,109 - INFO - ▶️ Starte Verarbeitung für DE-SH...
# 2026-02-02 06:51:15,134 - INFO - 📊 DE-SH: 9101 Tiles zu verarbeiten
# 2026-02-02 06:53:18,464 - INFO - 📈 DE-SH: 1000/9101 Tiles verarbeitet (546 erfolgreich)
# 2026-02-02 06:55:02,946 - INFO - 📈 DE-SH: 2000/9101 Tiles verarbeitet (1065 erfolgreich)
# 2026-02-02 06:56:50,411 - INFO - 📈 DE-SH: 3000/9101 Tiles verarbeitet (1735 erfolgreich)
# 2026-02-02 06:58:53,504 - INFO - 📈 DE-SH: 4000/9101 Tiles verarbeitet (2354 erfolgreich)
# 2026-02-02 07:00:48,099 - INFO - 📈 DE-SH: 5000/9101 Tiles verarbeitet (2924 erfolgreich)
# 2026-02-02 07:03:03,331 - INFO - 📈 DE-SH: 6000/9101 Tiles verarbeitet (3553 erfolgreich)
# 2026-02-02 07:04:59,894 - INFO - 📈 DE-SH: 7000/9101 Tiles verarbeitet (4209 erfolgreich)
# 2026-02-02 07:07:04,102 - INFO - 📈 DE-SH: 8000/9101 Tiles verarbeitet (4990 erfolgreich)
# 2026-02-02 07:09:52,061 - INFO - 📈 DE-SH: 9000/9101 Tiles verarbeitet (5776 erfolgreich)
# 2026-02-02 07:10:03,255 - INFO - ✅ DE-SH: 9101/9101 Tiles abgeschlossen (5830 erfolgreich, 3271 fehlgeschlagen)
# 2026-02-02 07:10:06,375 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SH_latest.parquet
# 2026-02-02 07:10:06,682 - INFO - 🔄 DE-TH: Datei ist 8.6 Tage alt, lade neu
# 2026-02-02 07:10:06,684 - INFO - ▶️ Starte Verarbeitung für DE-TH...
# 2026-02-02 07:10:06,702 - INFO - 📊 DE-TH: 6819 Tiles zu verarbeiten
# 2026-02-02 07:11:52,242 - INFO - 📈 DE-TH: 1000/6819 Tiles verarbeitet (628 erfolgreich)
# 2026-02-02 07:14:06,214 - INFO - 📈 DE-TH: 2000/6819 Tiles verarbeitet (1363 erfolgreich)
# 2026-02-02 07:16:12,167 - INFO - 📈 DE-TH: 3000/6819 Tiles verarbeitet (2064 erfolgreich)
# 2026-02-02 07:18:00,869 - INFO - 📈 DE-TH: 4000/6819 Tiles verarbeitet (2692 erfolgreich)
# 2026-02-02 07:19:50,883 - INFO - 📈 DE-TH: 5000/6819 Tiles verarbeitet (3383 erfolgreich)
# 2026-02-02 07:22:33,305 - INFO - 📈 DE-TH: 6000/6819 Tiles verarbeitet (4217 erfolgreich)
# 2026-02-02 07:24:25,083 - INFO - ✅ DE-TH: 6819/6819 Tiles abgeschlossen (4785 erfolgreich, 2034 fehlgeschlagen)
# 2026-02-02 07:24:27,675 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-TH_latest.parquet
# 2026-02-02 07:24:27,920 - INFO -
# 📅 Ältester Mapillary-Timestamp: 2026-02-02T01:39:43.945909+00:00
# 2026-02-02 07:24:27,922 - INFO - 💾 Metadata gespeichert: output/ml_metadata.json
# 2026-02-02 07:24:27,923 - INFO - 📄 Log-Datei: ml_output/mapillary_download_20260202_010647.log
# 2026-02-02 07:24:27,924 - INFO - === Mapillary Coverage Download abgeschlossen ===
