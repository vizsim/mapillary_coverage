# %% [markdown]
# # Was tut dieses Skript?
# Dieses Skript lädt die Mapillay coverage je Bundesland je Tiles herunter,
# filtert sie nach Aufnahmedatum,
# und exportiert die Ergebnisse als Parquet-Dateien.

# %%
# Standard library
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime, timezone
import json
import os
import time
import logging
import sys

# Third-party
import geopandas as gpd
import mercantile
import pandas as pd
import requests
from requests.exceptions import SSLError
from tqdm import tqdm
from vt2geojson.tools import vt_bytes_to_geojson


from config import TILES_CONFIG, PROCESSING_CONFIG, MAPILLARY_CONFIG

# Setup Logging
log_folder = PROCESSING_CONFIG["ml_output_folder"]
os.makedirs(log_folder, exist_ok=True)
log_file = os.path.join(log_folder, f"mapillary_download_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log")

# Konfiguriere Logger
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file, encoding='utf-8'),
        logging.StreamHandler(sys.stdout)  # Auch in Console ausgeben
    ]
)

logger = logging.getLogger(__name__)
logger.info(f"=== Mapillary Coverage Download gestartet ===")
logger.info(f"Log-Datei: {log_file}")
# Out:
# 2026-01-24 09:53:55,709 - INFO - === Mapillary Coverage Download gestartet ===
# 2026-01-24 09:53:55,711 - INFO - Log-Datei: ml_output/mapillary_download_20260124_095355.log

# %%
TQDM_ENABLED = os.environ.get("TQDM_DISABLE", "0") != "1"

# %%
### Helper function for loading tile lists

def load_tiles_from_json(bundesland_id, input_folder = TILES_CONFIG["cache_folder"]):
    path = os.path.join(input_folder, f"{bundesland_id}_tiles.json")
    with open(path, "r") as f:
        tile_list = json.load(f)
    return [mercantile.Tile(**t) for t in tile_list]

# %%
def export_geodata(gdfs, output_folder = PROCESSING_CONFIG["output_folder"], base_name="mapillary_coverage", region="ger", save_parquet=True, save_geojson_gz=True):
    """
    Export one or more GeoDataFrames into output files (.parquet only, ohne Datum im Namen).
    
    Args:
        gdfs (list or GeoDataFrame): List of GeoDataFrames or a single GeoDataFrame.
        output_folder (str): Output directory (created if it doesn't exist).
        base_name (str): Base filename prefix.
        region (str): Region tag for filename.
        save_parquet (bool): Save .parquet file.
        save_geojson_gz (bool): Save .geojson.gz file (not implemented).
    
    Returns:
        str: Timestamp when data was processed (ISO format)
    """
    if gdfs is None or (isinstance(gdfs, (gpd.GeoDataFrame, pd.DataFrame)) and gdfs.empty):
        logger.warning("No data to export.")
        return None

    # Concatenate if needed
    if isinstance(gdfs, list):
        gdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))
    else:
        gdf = gdfs

    os.makedirs(output_folder, exist_ok=True)
    
    # Aktueller Zeitstempel für Metadata
    current_timestamp = datetime.now(timezone.utc).isoformat()

    if save_parquet:
        # Dateiname OHNE Datum - nur "latest"
        parquet_path = os.path.join(output_folder, f"{base_name}_{region}_latest.parquet")
        gdf.to_parquet(parquet_path, index=False)
        logger.info(f"✔ Parquet saved to: {parquet_path}")
    
    return current_timestamp

# %%
def process_bundesland(bundesland_id, region_name=None, input_folder = TILES_CONFIG["cache_folder"], output_folder = PROCESSING_CONFIG["ml_output_folder"] , max_workers=3, limit_tiles=None):
    logger.info(f"▶️ Starte Verarbeitung für {bundesland_id}...")

    tiles = load_tiles_from_json(bundesland_id, input_folder=input_folder)
    if limit_tiles:
        tiles = tiles[:limit_tiles]
    
    total_tiles = len(tiles)
    logger.info(f"📊 {bundesland_id}: {total_tiles} Tiles zu verarbeiten")
    
    # genereal config
    # Load your access token
    ACCESS_TOKEN = MAPILLARY_CONFIG["access_token"]

    # Use existing variables
    tile_layer = "sequence"  # or 'image' for points
    tile_coverage = "mly1_computed_public"
    
    # Tracking für aufeinanderfolgende Fehler
    consecutive_parse_errors = 0
    MAX_CONSECUTIVE_ERRORS = 5
    
    # Tracking für Fortschritt
    processed_count = 0
    successful_count = 0

    def process_tile(tile, retry_count=0, max_retries=3):
        """
        Verarbeite ein Tile mit Retry-Logik bei Parsing-Fehlern.
        
        Args:
            tile: Mercantile Tile Objekt
            retry_count: Aktueller Retry-Versuch
            max_retries: Maximale Anzahl an Versuchen
        """
        nonlocal consecutive_parse_errors
        
        url = f"https://tiles.mapillary.com/maps/vtp/{tile_coverage}/2/{tile.z}/{tile.x}/{tile.y}?access_token={ACCESS_TOKEN}"
        
        try:
            response = requests.get(url, timeout=30)
            
            # Rate Limit Check
            if response.status_code == 429:
                logger.warning(f"⚠️ Rate Limit erreicht bei Tile {tile.x}/{tile.y}. Pausiere für 5 Minuten...")
                time.sleep(300)
                if retry_count < max_retries:
                    return process_tile(tile, retry_count + 1, max_retries)
                return None
            
            if response.status_code != 200:
                logger.warning(f"⚠️ HTTP {response.status_code} bei Tile {tile.x}/{tile.y}")
                return None
            
            # Versuche Vector Tile zu parsen
            geojson = vt_bytes_to_geojson(response.content, tile.x, tile.y, tile.z, layer=tile_layer)
            features = geojson.get("features", [])
            
            if not features:
                return None
            
            gdf_tile = gpd.GeoDataFrame.from_features(features, crs="EPSG:4326")
            gdf_tile['captured_at'] = gdf_tile['captured_at'].apply(lambda x: datetime.fromtimestamp(x / 1000, tz=timezone.utc))
            
            # Timefilter
            min_date_str = PROCESSING_CONFIG["min_capture_date"]
            min_dt = datetime.strptime(min_date_str, "%Y-%m-%d").replace(tzinfo=timezone.utc)
            gdf_tile = gdf_tile[gdf_tile['captured_at'] >= min_dt]
            gdf_tile['captured_at'] = gdf_tile['captured_at'].dt.strftime('%Y-%m-%d')

            gdf_tile['tile_x'] = tile.x
            gdf_tile['tile_y'] = tile.y
            
            # Erfolg → Fehler-Counter zurücksetzen
            consecutive_parse_errors = 0
            return gdf_tile
            
        except Exception as e:
            error_msg = str(e)
            
            # Prüfe ob es ein Parsing-Fehler ist (wahrscheinlich Rate Limit)
            if "Error parsing message" in error_msg or "vector_tile" in error_msg:
                consecutive_parse_errors += 1
                
                # Prüfe ob zu viele aufeinanderfolgende Fehler
                if consecutive_parse_errors >= MAX_CONSECUTIVE_ERRORS:
                    logger.error(f"🛑 {MAX_CONSECUTIVE_ERRORS} aufeinanderfolgende Parsing-Fehler! API scheint blockiert zu sein.")
                    logger.warning(f"⏸️  LANGE PAUSE: 30 Minuten warten...")
                    time.sleep(1800)  # 30 Minuten
                    consecutive_parse_errors = 0  # Counter zurücksetzen
                    logger.info(f"▶️ Setze Verarbeitung fort nach langer Pause...")
                
                if retry_count < max_retries:
                    logger.warning(f"⚠️ Parsing-Fehler bei Tile {tile.x}/{tile.y} (Versuch {retry_count + 1}/{max_retries}, konsekutiv: {consecutive_parse_errors}). Pausiere für 5 Minuten...")
                    time.sleep(300)  # 5 Minuten Pause
                    return process_tile(tile, retry_count + 1, max_retries)
                else:
                    logger.error(f"❌ Tile {tile.x}/{tile.y} nach {max_retries} Versuchen fehlgeschlagen: {error_msg}")
                    return None
            else:
                logger.error(f"❌ Fehler bei Tile {tile.x}/{tile.y}: {error_msg}")
                return None

    gdf_all = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(process_tile, tile): tile for tile in tiles}
        for future in tqdm(as_completed(futures), total=len(futures), desc=f"🧩 {bundesland_id}", disable=not TQDM_ENABLED):
            try:
                result = future.result()
                processed_count += 1
                
                if result is not None:
                    gdf_all.append(result)
                    successful_count += 1
                
                # Progress-Logging alle 1000 Tiles (nur wenn >= 1000 Tiles total)
                if total_tiles >= 1000 and processed_count % 1000 == 0:
                    logger.info(f"📈 {bundesland_id}: {processed_count}/{total_tiles} Tiles verarbeitet ({successful_count} erfolgreich)")
                    
            except SSLError as e:
                logger.warning(f"⚠️ SSLError: {e}. Pausiere für 5 Minuten...")
                time.sleep(300)
            except Exception as e:
                logger.error(f"⚠️ Unbekannter Fehler: {e}")
    
    # Final Summary
    logger.info(f"✅ {bundesland_id}: {processed_count}/{total_tiles} Tiles abgeschlossen ({successful_count} erfolgreich, {processed_count - successful_count} fehlgeschlagen)")

    if gdf_all:
        gdf_all = gpd.GeoDataFrame(pd.concat(gdf_all, ignore_index=True))
        timestamp = export_geodata(
            gdfs=gdf_all,
            output_folder=output_folder,
            region=bundesland_id,
            save_parquet=True,
            save_geojson_gz=False
        )
        return timestamp
    else:
        logger.warning(f"⚠️ Keine Daten für {bundesland_id}.")
        return None

# %%
# Verarbeitung der Bundesländer basierend auf config.py
# takes about ~6.5h for all 16 bundesländer (on lokal machine)

# Lade Bundesländer aus Cache (wurde in Notebook 0 heruntergeladen)
bundesland_cache_path = os.path.join("prep", "bundeslaender.geojson")

if not os.path.exists(bundesland_cache_path):
    logger.error(f"❌ Bundesland-Cache nicht gefunden: {bundesland_cache_path}")
    logger.error(f"   Bitte zuerst Notebook 0_prepare_tiles.ipynb ausführen!")
    raise FileNotFoundError(f"Bundesland-GeoJSON fehlt: {bundesland_cache_path}")

logger.info(f"📂 Lade Bundesländer aus: {bundesland_cache_path}")
bland = gpd.read_file(bundesland_cache_path)

# Filter Bundesländer basierend auf config.py
from config import GEOFABRIK_CONFIG

selected_bundeslaender = GEOFABRIK_CONFIG.get("bundeslaender")
if selected_bundeslaender:
    # Nur die ausgewählten Bundesländer verarbeiten
    bland_filtered = bland[bland['id'].isin(selected_bundeslaender)]
    logger.info(f"🎯 Verarbeite {len(bland_filtered)} ausgewählte Bundesländer: {', '.join(selected_bundeslaender)}")
else:
    # Alle Bundesländer verarbeiten
    bland_filtered = bland
    logger.info(f"📍 Verarbeite alle {len(bland_filtered)} Bundesländer")

# Sammle Timestamps für Metadata
ml_timestamps = {}

for _, row in bland_filtered.iterrows():
    b_id = row["id"]
    name = row["name"]

    # Nur verarbeiten, wenn eine JSON-Datei existiert
    tile_json_path = os.path.join(TILES_CONFIG["cache_folder"], f"{b_id}_tiles.json")
    if not os.path.exists(tile_json_path):
        logger.warning(f"⏩ Überspringe {b_id}, keine Tiles gefunden.")
        continue

    # Prüfe ob Parquet bereits existiert und noch aktuell ist
    output_folder = PROCESSING_CONFIG["ml_output_folder"]
    parquet_path = os.path.join(output_folder, f"mapillary_coverage_{b_id}_latest.parquet")
    max_age_days = PROCESSING_CONFIG.get('max_file_age_days', 4)
    
    if os.path.exists(parquet_path):
        file_mtime = os.path.getmtime(parquet_path)
        file_age_days = (datetime.now().timestamp() - file_mtime) / 86400  # Sekunden in Tage
        
        if file_age_days < max_age_days:
            logger.info(f"⏩ {b_id}: Datei ist {file_age_days:.1f} Tage alt, überspringe Download")
            # Timestamp aus existierender Datei für Metadata verwenden
            ml_timestamps[b_id] = datetime.fromtimestamp(file_mtime, tz=timezone.utc).isoformat()
            continue
        else:
            logger.info(f"🔄 {b_id}: Datei ist {file_age_days:.1f} Tage alt, lade neu")

    timestamp = process_bundesland(b_id, region_name=name)
    if timestamp:
        ml_timestamps[b_id] = timestamp

# Speichere Metadata ähnlich wie osm_metadata.json
if ml_timestamps:
    # Finde ältesten Timestamp
    oldest_ml_timestamp = min(ml_timestamps.values())
    
    metadata = {
        "ml_data_from": oldest_ml_timestamp,
        "bundeslaender": ml_timestamps,
        "processed_date": datetime.now(timezone.utc).isoformat()
    }
    
    with open("output/ml_metadata.json", "w", encoding="utf-8") as f:
        json.dump(metadata, f, ensure_ascii=False, indent=2)
    
    logger.info(f"\n📅 Ältester Mapillary-Timestamp: {oldest_ml_timestamp}")
    logger.info(f"💾 Metadata gespeichert: output/ml_metadata.json")
    logger.info(f"📄 Log-Datei: {log_file}")
else:
    logger.warning("\n⚠️  Keine Mapillary-Daten verarbeitet, keine Metadata erstellt.")

logger.info("=== Mapillary Coverage Download abgeschlossen ===")
# Out:
# 2026-01-24 09:53:55,832 - INFO - 📂 Lade Bundesländer aus: prep/bundeslaender.geojson
# 2026-01-24 09:53:56,411 - INFO - 📍 Verarbeite alle 16 Bundesländer
# 2026-01-24 09:53:56,416 - INFO - 🔄 DE-BW: Datei ist 5.6 Tage alt, lade neu
# 2026-01-24 09:53:56,418 - INFO - ▶️ Starte Verarbeitung für DE-BW...
# 2026-01-24 09:53:56,460 - INFO - 📊 DE-BW: 14160 Tiles zu verarbeiten
# 2026-01-24 09:56:47,333 - INFO - 📈 DE-BW: 1000/14160 Tiles verarbeitet (843 erfolgreich)
# 2026-01-24 09:58:55,015 - INFO - 📈 DE-BW: 2000/14160 Tiles verarbeitet (1591 erfolgreich)
# 2026-01-24 10:01:04,838 - INFO - 📈 DE-BW: 3000/14160 Tiles verarbeitet (2376 erfolgreich)
# 2026-01-24 10:04:01,377 - INFO - 📈 DE-BW: 4000/14160 Tiles verarbeitet (3225 erfolgreich)
# 2026-01-24 10:07:53,710 - INFO - 📈 DE-BW: 5000/14160 Tiles verarbeitet (4065 erfolgreich)
# 2026-01-24 10:10:32,292 - INFO - 📈 DE-BW: 6000/14160 Tiles verarbeitet (4900 erfolgreich)
# 2026-01-24 10:13:41,747 - INFO - 📈 DE-BW: 7000/14160 Tiles verarbeitet (5770 erfolgreich)
# 2026-01-24 10:16:21,044 - WARNING - ⚠️ HTTP 404 bei Tile 8608/5609
# 2026-01-24 10:18:43,978 - INFO - 📈 DE-BW: 8000/14160 Tiles verarbeitet (6669 erfolgreich)
# 2026-01-24 10:22:05,872 - INFO - 📈 DE-BW: 9000/14160 Tiles verarbeitet (7555 erfolgreich)
# 2026-01-24 10:24:33,843 - INFO - 📈 DE-BW: 10000/14160 Tiles verarbeitet (8393 erfolgreich)
# 2026-01-24 10:26:41,245 - INFO - 📈 DE-BW: 11000/14160 Tiles verarbeitet (9183 erfolgreich)
# 2026-01-24 10:29:02,662 - INFO - 📈 DE-BW: 12000/14160 Tiles verarbeitet (9985 erfolgreich)
# 2026-01-24 10:31:31,634 - INFO - 📈 DE-BW: 13000/14160 Tiles verarbeitet (10797 erfolgreich)
# 2026-01-24 10:33:56,441 - INFO - 📈 DE-BW: 14000/14160 Tiles verarbeitet (11562 erfolgreich)
# 2026-01-24 10:34:14,159 - INFO - ✅ DE-BW: 14160/14160 Tiles abgeschlossen (11665 erfolgreich, 2495 fehlgeschlagen)
# 2026-01-24 10:34:21,677 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BW_latest.parquet
# 2026-01-24 10:34:22,375 - INFO - 🔄 DE-BY: Datei ist 5.6 Tage alt, lade neu
# 2026-01-24 10:34:22,377 - INFO - ▶️ Starte Verarbeitung für DE-BY...
# 2026-01-24 10:34:22,489 - INFO - 📊 DE-BY: 28376 Tiles zu verarbeiten
# 2026-01-24 10:36:49,964 - INFO - 📈 DE-BY: 1000/28376 Tiles verarbeitet (788 erfolgreich)
# 2026-01-24 10:39:13,086 - INFO - 📈 DE-BY: 2000/28376 Tiles verarbeitet (1522 erfolgreich)
# 2026-01-24 10:42:09,107 - INFO - 📈 DE-BY: 3000/28376 Tiles verarbeitet (2268 erfolgreich)
# 2026-01-24 10:44:24,599 - INFO - 📈 DE-BY: 4000/28376 Tiles verarbeitet (2982 erfolgreich)
# 2026-01-24 10:46:17,529 - INFO - 📈 DE-BY: 5000/28376 Tiles verarbeitet (3612 erfolgreich)
# 2026-01-24 10:48:02,514 - INFO - 📈 DE-BY: 6000/28376 Tiles verarbeitet (4216 erfolgreich)
# 2026-01-24 10:50:00,800 - INFO - 📈 DE-BY: 7000/28376 Tiles verarbeitet (4975 erfolgreich)
# 2026-01-24 10:52:02,970 - INFO - 📈 DE-BY: 8000/28376 Tiles verarbeitet (5663 erfolgreich)
# 2026-01-24 10:54:56,924 - INFO - 📈 DE-BY: 9000/28376 Tiles verarbeitet (6369 erfolgreich)
# 2026-01-24 11:00:20,937 - INFO - 📈 DE-BY: 10000/28376 Tiles verarbeitet (7076 erfolgreich)
# 2026-01-24 11:05:05,866 - INFO - 📈 DE-BY: 11000/28376 Tiles verarbeitet (7718 erfolgreich)
# 2026-01-24 11:07:21,593 - INFO - 📈 DE-BY: 12000/28376 Tiles verarbeitet (8410 erfolgreich)
# 2026-01-24 11:09:35,426 - INFO - 📈 DE-BY: 13000/28376 Tiles verarbeitet (9081 erfolgreich)
# 2026-01-24 11:11:47,869 - INFO - 📈 DE-BY: 14000/28376 Tiles verarbeitet (9762 erfolgreich)
# 2026-01-24 11:14:18,189 - INFO - 📈 DE-BY: 15000/28376 Tiles verarbeitet (10394 erfolgreich)
# 2026-01-24 11:17:27,671 - INFO - 📈 DE-BY: 16000/28376 Tiles verarbeitet (11040 erfolgreich)
# 2026-01-24 11:20:22,780 - INFO - 📈 DE-BY: 17000/28376 Tiles verarbeitet (11630 erfolgreich)
# 2026-01-24 11:22:50,652 - INFO - 📈 DE-BY: 18000/28376 Tiles verarbeitet (12219 erfolgreich)
# 2026-01-24 11:24:57,066 - INFO - 📈 DE-BY: 19000/28376 Tiles verarbeitet (12832 erfolgreich)
# 2026-01-24 11:27:12,844 - INFO - 📈 DE-BY: 20000/28376 Tiles verarbeitet (13466 erfolgreich)
# 2026-01-24 11:30:04,797 - INFO - 📈 DE-BY: 21000/28376 Tiles verarbeitet (14204 erfolgreich)
# 2026-01-24 11:32:30,296 - INFO - 📈 DE-BY: 22000/28376 Tiles verarbeitet (14941 erfolgreich)
# 2026-01-24 11:35:03,934 - INFO - 📈 DE-BY: 23000/28376 Tiles verarbeitet (15608 erfolgreich)
# 2026-01-24 11:38:23,412 - INFO - 📈 DE-BY: 24000/28376 Tiles verarbeitet (16185 erfolgreich)
# 2026-01-24 11:44:48,454 - INFO - 📈 DE-BY: 25000/28376 Tiles verarbeitet (16801 erfolgreich)
# 2026-01-24 11:47:42,210 - INFO - 📈 DE-BY: 26000/28376 Tiles verarbeitet (17414 erfolgreich)
# 2026-01-24 11:49:58,449 - INFO - 📈 DE-BY: 27000/28376 Tiles verarbeitet (18029 erfolgreich)
# 2026-01-24 11:51:48,685 - INFO - 📈 DE-BY: 28000/28376 Tiles verarbeitet (18543 erfolgreich)
# 2026-01-24 11:52:24,503 - INFO - ✅ DE-BY: 28376/28376 Tiles abgeschlossen (18698 erfolgreich, 9678 fehlgeschlagen)
# 2026-01-24 11:52:35,555 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BY_latest.parquet
# 2026-01-24 11:52:36,816 - INFO - 🔄 DE-BE: Datei ist 5.7 Tage alt, lade neu
# 2026-01-24 11:52:36,818 - INFO - ▶️ Starte Verarbeitung für DE-BE...
# 2026-01-24 11:52:36,822 - INFO - 📊 DE-BE: 399 Tiles zu verarbeiten
# 2026-01-24 12:01:46,441 - INFO - ✅ DE-BE: 399/399 Tiles abgeschlossen (398 erfolgreich, 1 fehlgeschlagen)
# 2026-01-24 12:01:47,097 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BE_latest.parquet
# 2026-01-24 12:01:47,332 - INFO - 🔄 DE-BB: Datei ist 5.7 Tage alt, lade neu
# 2026-01-24 12:01:47,334 - INFO - ▶️ Starte Verarbeitung für DE-BB...
# 2026-01-24 12:01:47,396 - INFO - 📊 DE-BB: 13585 Tiles zu verarbeiten
# 2026-01-24 12:04:09,062 - INFO - 📈 DE-BB: 1000/13585 Tiles verarbeitet (636 erfolgreich)
# 2026-01-24 12:05:50,246 - INFO - 📈 DE-BB: 2000/13585 Tiles verarbeitet (1286 erfolgreich)
# 2026-01-24 12:07:39,415 - INFO - 📈 DE-BB: 3000/13585 Tiles verarbeitet (1917 erfolgreich)
# 2026-01-24 12:09:43,008 - INFO - 📈 DE-BB: 4000/13585 Tiles verarbeitet (2656 erfolgreich)
# 2026-01-24 12:12:07,902 - INFO - 📈 DE-BB: 5000/13585 Tiles verarbeitet (3461 erfolgreich)
# 2026-01-24 12:14:34,106 - INFO - 📈 DE-BB: 6000/13585 Tiles verarbeitet (4323 erfolgreich)
# 2026-01-24 12:17:15,549 - INFO - 📈 DE-BB: 7000/13585 Tiles verarbeitet (5185 erfolgreich)
# 2026-01-24 12:19:56,874 - INFO - 📈 DE-BB: 8000/13585 Tiles verarbeitet (6063 erfolgreich)
# 2026-01-24 12:22:18,032 - INFO - 📈 DE-BB: 9000/13585 Tiles verarbeitet (6928 erfolgreich)
# 2026-01-24 12:24:22,568 - INFO - 📈 DE-BB: 10000/13585 Tiles verarbeitet (7785 erfolgreich)
# 2026-01-24 12:26:14,996 - INFO - 📈 DE-BB: 11000/13585 Tiles verarbeitet (8618 erfolgreich)
# 2026-01-24 12:28:03,203 - INFO - 📈 DE-BB: 12000/13585 Tiles verarbeitet (9395 erfolgreich)
# 2026-01-24 12:29:50,951 - INFO - 📈 DE-BB: 13000/13585 Tiles verarbeitet (10228 erfolgreich)
# 2026-01-24 12:30:58,400 - INFO - ✅ DE-BB: 13585/13585 Tiles abgeschlossen (10718 erfolgreich, 2867 fehlgeschlagen)
# 2026-01-24 12:31:04,534 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BB_latest.parquet
# 2026-01-24 12:31:05,187 - INFO - 🔄 DE-HB: Datei ist 5.7 Tage alt, lade neu
# 2026-01-24 12:31:05,190 - INFO - ▶️ Starte Verarbeitung für DE-HB...
# 2026-01-24 12:31:05,193 - INFO - 📊 DE-HB: 145 Tiles zu verarbeiten
# 2026-01-24 12:32:14,091 - INFO - ✅ DE-HB: 145/145 Tiles abgeschlossen (135 erfolgreich, 10 fehlgeschlagen)
# 2026-01-24 12:32:14,179 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HB_latest.parquet
# 2026-01-24 12:32:14,196 - INFO - 🔄 DE-HH: Datei ist 5.7 Tage alt, lade neu
# 2026-01-24 12:32:14,198 - INFO - ▶️ Starte Verarbeitung für DE-HH...
# 2026-01-24 12:32:14,204 - INFO - 📊 DE-HH: 361 Tiles zu verarbeiten
# 2026-01-24 12:35:43,769 - INFO - ✅ DE-HH: 361/361 Tiles abgeschlossen (359 erfolgreich, 2 fehlgeschlagen)
# 2026-01-24 12:35:44,001 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HH_latest.parquet
# 2026-01-24 12:35:44,045 - INFO - 🔄 DE-HE: Datei ist 5.7 Tage alt, lade neu
# 2026-01-24 12:35:44,047 - INFO - ▶️ Starte Verarbeitung für DE-HE...
# 2026-01-24 12:35:44,084 - INFO - 📊 DE-HE: 8704 Tiles zu verarbeiten
# 2026-01-24 12:38:30,431 - INFO - 📈 DE-HE: 1000/8704 Tiles verarbeitet (805 erfolgreich)
# 2026-01-24 12:41:53,557 - INFO - 📈 DE-HE: 2000/8704 Tiles verarbeitet (1650 erfolgreich)
# 2026-01-24 12:48:10,110 - INFO - 📈 DE-HE: 3000/8704 Tiles verarbeitet (2541 erfolgreich)
# 2026-01-24 12:50:56,972 - INFO - 📈 DE-HE: 4000/8704 Tiles verarbeitet (3344 erfolgreich)
# 2026-01-24 12:53:20,447 - INFO - 📈 DE-HE: 5000/8704 Tiles verarbeitet (4107 erfolgreich)
# 2026-01-24 12:55:39,924 - INFO - 📈 DE-HE: 6000/8704 Tiles verarbeitet (4779 erfolgreich)
# 2026-01-24 12:58:08,562 - INFO - 📈 DE-HE: 7000/8704 Tiles verarbeitet (5447 erfolgreich)
# 2026-01-24 13:00:33,802 - INFO - 📈 DE-HE: 8000/8704 Tiles verarbeitet (6088 erfolgreich)
# 2026-01-24 13:02:01,286 - INFO - ✅ DE-HE: 8704/8704 Tiles abgeschlossen (6638 erfolgreich, 2066 fehlgeschlagen)
# 2026-01-24 13:02:05,789 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HE_latest.parquet
# 2026-01-24 13:02:06,202 - INFO - 🔄 DE-MV: Datei ist 5.7 Tage alt, lade neu
# 2026-01-24 13:02:06,205 - INFO - ▶️ Starte Verarbeitung für DE-MV...
# 2026-01-24 13:02:06,250 - INFO - 📊 DE-MV: 12294 Tiles zu verarbeiten
# 2026-01-24 13:03:59,608 - INFO - 📈 DE-MV: 1000/12294 Tiles verarbeitet (595 erfolgreich)
# 2026-01-24 13:05:50,258 - INFO - 📈 DE-MV: 2000/12294 Tiles verarbeitet (1158 erfolgreich)
# 2026-01-24 13:07:34,807 - INFO - 📈 DE-MV: 3000/12294 Tiles verarbeitet (1674 erfolgreich)
# 2026-01-24 13:09:12,673 - INFO - 📈 DE-MV: 4000/12294 Tiles verarbeitet (2038 erfolgreich)
# 2026-01-24 13:11:00,012 - INFO - 📈 DE-MV: 5000/12294 Tiles verarbeitet (2544 erfolgreich)
# 2026-01-24 13:12:39,708 - INFO - 📈 DE-MV: 6000/12294 Tiles verarbeitet (2979 erfolgreich)
# 2026-01-24 13:14:17,279 - INFO - 📈 DE-MV: 7000/12294 Tiles verarbeitet (3405 erfolgreich)
# 2026-01-24 13:15:52,257 - INFO - 📈 DE-MV: 8000/12294 Tiles verarbeitet (3731 erfolgreich)
# 2026-01-24 13:17:30,342 - INFO - 📈 DE-MV: 9000/12294 Tiles verarbeitet (4124 erfolgreich)
# 2026-01-24 13:19:13,466 - INFO - 📈 DE-MV: 10000/12294 Tiles verarbeitet (4627 erfolgreich)
# 2026-01-24 13:20:51,895 - INFO - 📈 DE-MV: 11000/12294 Tiles verarbeitet (5108 erfolgreich)
# 2026-01-24 13:22:33,977 - INFO - 📈 DE-MV: 12000/12294 Tiles verarbeitet (5610 erfolgreich)
# 2026-01-24 13:23:05,713 - INFO - ✅ DE-MV: 12294/12294 Tiles abgeschlossen (5799 erfolgreich, 6495 fehlgeschlagen)
# 2026-01-24 13:23:08,628 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-MV_latest.parquet
# 2026-01-24 13:23:08,892 - INFO - 🔄 DE-NI: Datei ist 5.6 Tage alt, lade neu
# 2026-01-24 13:23:08,894 - INFO - ▶️ Starte Verarbeitung für DE-NI...
# 2026-01-24 13:23:08,963 - INFO - 📊 DE-NI: 22844 Tiles zu verarbeiten
# 2026-01-24 13:25:41,968 - INFO - 📈 DE-NI: 1000/22844 Tiles verarbeitet (767 erfolgreich)
# 2026-01-24 13:27:45,180 - INFO - 📈 DE-NI: 2000/22844 Tiles verarbeitet (1493 erfolgreich)
# 2026-01-24 13:29:36,610 - INFO - 📈 DE-NI: 3000/22844 Tiles verarbeitet (2101 erfolgreich)
# 2026-01-24 13:31:07,969 - INFO - 📈 DE-NI: 4000/22844 Tiles verarbeitet (2467 erfolgreich)
# 2026-01-24 13:32:45,224 - INFO - 📈 DE-NI: 5000/22844 Tiles verarbeitet (3028 erfolgreich)
# 2026-01-24 13:34:46,578 - INFO - 📈 DE-NI: 6000/22844 Tiles verarbeitet (3710 erfolgreich)
# 2026-01-24 13:37:04,257 - INFO - 📈 DE-NI: 7000/22844 Tiles verarbeitet (4423 erfolgreich)
# 2026-01-24 13:38:59,437 - INFO - 📈 DE-NI: 8000/22844 Tiles verarbeitet (5026 erfolgreich)
# 2026-01-24 13:40:56,446 - INFO - 📈 DE-NI: 9000/22844 Tiles verarbeitet (5660 erfolgreich)
# 2026-01-24 13:42:45,886 - INFO - 📈 DE-NI: 10000/22844 Tiles verarbeitet (6240 erfolgreich)
# 2026-01-24 13:44:35,699 - INFO - 📈 DE-NI: 11000/22844 Tiles verarbeitet (6855 erfolgreich)
# 2026-01-24 13:46:39,484 - INFO - 📈 DE-NI: 12000/22844 Tiles verarbeitet (7574 erfolgreich)
# 2026-01-24 13:48:41,742 - INFO - 📈 DE-NI: 13000/22844 Tiles verarbeitet (8261 erfolgreich)
# 2026-01-24 13:50:48,303 - INFO - 📈 DE-NI: 14000/22844 Tiles verarbeitet (9011 erfolgreich)
# 2026-01-24 13:53:17,324 - INFO - 📈 DE-NI: 15000/22844 Tiles verarbeitet (9796 erfolgreich)
# 2026-01-24 13:56:02,552 - INFO - 📈 DE-NI: 16000/22844 Tiles verarbeitet (10528 erfolgreich)
# 2026-01-24 13:58:48,813 - INFO - 📈 DE-NI: 17000/22844 Tiles verarbeitet (11374 erfolgreich)
# 2026-01-24 14:01:20,746 - INFO - 📈 DE-NI: 18000/22844 Tiles verarbeitet (12145 erfolgreich)
# 2026-01-24 14:03:34,902 - INFO - 📈 DE-NI: 19000/22844 Tiles verarbeitet (12931 erfolgreich)
# 2026-01-24 14:06:16,786 - INFO - 📈 DE-NI: 20000/22844 Tiles verarbeitet (13690 erfolgreich)
# 2026-01-24 14:09:22,114 - INFO - 📈 DE-NI: 21000/22844 Tiles verarbeitet (14543 erfolgreich)
# 2026-01-24 14:11:53,127 - INFO - 📈 DE-NI: 22000/22844 Tiles verarbeitet (15303 erfolgreich)
# 2026-01-24 14:13:30,413 - INFO - ✅ DE-NI: 22844/22844 Tiles abgeschlossen (15939 erfolgreich, 6905 fehlgeschlagen)
# 2026-01-24 14:13:39,216 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-NI_latest.parquet
# 2026-01-24 14:13:39,944 - INFO - 🔄 DE-NW: Datei ist 5.6 Tage alt, lade neu
# 2026-01-24 14:13:39,945 - INFO - ▶️ Starte Verarbeitung für DE-NW...
# 2026-01-24 14:13:39,999 - INFO - 📊 DE-NW: 15243 Tiles zu verarbeiten
# 2026-01-24 14:16:44,186 - INFO - 📈 DE-NW: 1000/15243 Tiles verarbeitet (688 erfolgreich)
# 2026-01-24 14:22:17,025 - INFO - 📈 DE-NW: 2000/15243 Tiles verarbeitet (1659 erfolgreich)
# 2026-01-24 14:25:47,719 - INFO - 📈 DE-NW: 3000/15243 Tiles verarbeitet (2580 erfolgreich)
# 2026-01-24 14:30:19,022 - INFO - 📈 DE-NW: 4000/15243 Tiles verarbeitet (3495 erfolgreich)
# 2026-01-24 14:30:59,306 - WARNING - ⚠️ HTTP 404 bei Tile 8496/5448
# 2026-01-24 14:34:53,762 - INFO - 📈 DE-NW: 5000/15243 Tiles verarbeitet (4402 erfolgreich)
# 2026-01-24 14:39:39,387 - INFO - 📈 DE-NW: 6000/15243 Tiles verarbeitet (5349 erfolgreich)
# 2026-01-24 14:44:16,157 - INFO - 📈 DE-NW: 7000/15243 Tiles verarbeitet (6277 erfolgreich)
# 2026-01-24 14:47:26,140 - INFO - 📈 DE-NW: 8000/15243 Tiles verarbeitet (7174 erfolgreich)
# 2026-01-24 14:50:40,327 - INFO - 📈 DE-NW: 9000/15243 Tiles verarbeitet (8051 erfolgreich)
# 2026-01-24 14:54:31,124 - INFO - 📈 DE-NW: 10000/15243 Tiles verarbeitet (8854 erfolgreich)
# 2026-01-24 14:55:41,525 - WARNING - ⚠️ HTTP 404 bei Tile 8548/5478
# 2026-01-24 14:57:10,448 - INFO - 📈 DE-NW: 11000/15243 Tiles verarbeitet (9618 erfolgreich)
# 2026-01-24 14:59:20,882 - INFO - 📈 DE-NW: 12000/15243 Tiles verarbeitet (10258 erfolgreich)
# 2026-01-24 15:02:22,972 - INFO - 📈 DE-NW: 13000/15243 Tiles verarbeitet (11012 erfolgreich)
# 2026-01-24 15:05:33,784 - INFO - 📈 DE-NW: 14000/15243 Tiles verarbeitet (11832 erfolgreich)
# 2026-01-24 15:09:00,566 - INFO - 📈 DE-NW: 15000/15243 Tiles verarbeitet (12679 erfolgreich)
# 2026-01-24 15:09:26,855 - INFO - ✅ DE-NW: 15243/15243 Tiles abgeschlossen (12852 erfolgreich, 2391 fehlgeschlagen)
# 2026-01-24 15:09:34,926 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-NW_latest.parquet
# 2026-01-24 15:09:35,757 - INFO - 🔄 DE-RP: Datei ist 5.7 Tage alt, lade neu
# 2026-01-24 15:09:35,759 - INFO - ▶️ Starte Verarbeitung für DE-RP...
# 2026-01-24 15:09:35,780 - INFO - 📊 DE-RP: 8240 Tiles zu verarbeiten
# 2026-01-24 15:12:20,188 - INFO - 📈 DE-RP: 1000/8240 Tiles verarbeitet (833 erfolgreich)
# 2026-01-24 15:14:32,953 - INFO - 📈 DE-RP: 2000/8240 Tiles verarbeitet (1753 erfolgreich)
# 2026-01-24 15:16:52,279 - INFO - 📈 DE-RP: 3000/8240 Tiles verarbeitet (2651 erfolgreich)
# 2026-01-24 15:19:22,577 - INFO - 📈 DE-RP: 4000/8240 Tiles verarbeitet (3555 erfolgreich)
# 2026-01-24 15:21:52,088 - INFO - 📈 DE-RP: 5000/8240 Tiles verarbeitet (4417 erfolgreich)
# 2026-01-24 15:24:19,160 - INFO - 📈 DE-RP: 6000/8240 Tiles verarbeitet (5219 erfolgreich)
# 2026-01-24 15:26:40,643 - INFO - 📈 DE-RP: 7000/8240 Tiles verarbeitet (6027 erfolgreich)
# 2026-01-24 15:29:35,115 - INFO - 📈 DE-RP: 8000/8240 Tiles verarbeitet (6929 erfolgreich)
# 2026-01-24 15:30:30,833 - INFO - ✅ DE-RP: 8240/8240 Tiles abgeschlossen (7151 erfolgreich, 1089 fehlgeschlagen)
# 2026-01-24 15:30:35,436 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-RP_latest.parquet
# 2026-01-24 15:30:35,823 - INFO - 🔄 DE-SL: Datei ist 5.7 Tage alt, lade neu
# 2026-01-24 15:30:35,825 - INFO - ▶️ Starte Verarbeitung für DE-SL...
# 2026-01-24 15:30:35,836 - INFO - 📊 DE-SL: 1170 Tiles zu verarbeiten
# 2026-01-24 15:33:42,522 - INFO - 📈 DE-SL: 1000/1170 Tiles verarbeitet (883 erfolgreich)
# 2026-01-24 15:34:27,396 - INFO - ✅ DE-SL: 1170/1170 Tiles abgeschlossen (1035 erfolgreich, 135 fehlgeschlagen)
# 2026-01-24 15:34:28,059 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SL_latest.parquet
# 2026-01-24 15:34:28,118 - INFO - 🔄 DE-ST: Datei ist 5.7 Tage alt, lade neu
# 2026-01-24 15:34:28,119 - INFO - ▶️ Starte Verarbeitung für DE-ST...
# 2026-01-24 15:34:28,223 - INFO - 📊 DE-ST: 9077 Tiles zu verarbeiten
# 2026-01-24 15:36:15,508 - INFO - 📈 DE-ST: 1000/9077 Tiles verarbeitet (587 erfolgreich)
# 2026-01-24 15:38:06,096 - INFO - 📈 DE-ST: 2000/9077 Tiles verarbeitet (1224 erfolgreich)
# 2026-01-24 15:39:50,737 - INFO - 📈 DE-ST: 3000/9077 Tiles verarbeitet (1772 erfolgreich)
# 2026-01-24 15:41:41,189 - INFO - 📈 DE-ST: 4000/9077 Tiles verarbeitet (2315 erfolgreich)
# 2026-01-24 15:43:37,875 - INFO - 📈 DE-ST: 5000/9077 Tiles verarbeitet (2925 erfolgreich)
# 2026-01-24 15:45:41,955 - INFO - 📈 DE-ST: 6000/9077 Tiles verarbeitet (3613 erfolgreich)
# 2026-01-24 15:48:27,258 - INFO - 📈 DE-ST: 7000/9077 Tiles verarbeitet (4306 erfolgreich)
# 2026-01-24 15:50:47,236 - INFO - 📈 DE-ST: 8000/9077 Tiles verarbeitet (4913 erfolgreich)
# 2026-01-24 15:52:50,471 - INFO - 📈 DE-ST: 9000/9077 Tiles verarbeitet (5666 erfolgreich)
# 2026-01-24 15:52:59,548 - INFO - ✅ DE-ST: 9077/9077 Tiles abgeschlossen (5717 erfolgreich, 3360 fehlgeschlagen)
# 2026-01-24 15:53:03,111 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-ST_latest.parquet
# 2026-01-24 15:53:03,464 - INFO - 🔄 DE-SN: Datei ist 5.7 Tage alt, lade neu
# 2026-01-24 15:53:03,466 - INFO - ▶️ Starte Verarbeitung für DE-SN...
# 2026-01-24 15:53:03,489 - INFO - 📊 DE-SN: 8311 Tiles zu verarbeiten
# 2026-01-24 15:55:55,716 - INFO - 📈 DE-SN: 1000/8311 Tiles verarbeitet (800 erfolgreich)
# 2026-01-24 15:59:35,581 - INFO - 📈 DE-SN: 2000/8311 Tiles verarbeitet (1633 erfolgreich)
# 2026-01-24 16:01:58,763 - INFO - 📈 DE-SN: 3000/8311 Tiles verarbeitet (2419 erfolgreich)
# 2026-01-24 16:04:12,060 - INFO - 📈 DE-SN: 4000/8311 Tiles verarbeitet (3189 erfolgreich)
# 2026-01-24 16:06:12,051 - INFO - 📈 DE-SN: 5000/8311 Tiles verarbeitet (3948 erfolgreich)
# 2026-01-24 16:08:46,938 - INFO - 📈 DE-SN: 6000/8311 Tiles verarbeitet (4752 erfolgreich)
# 2026-01-24 16:10:37,982 - WARNING - ⚠️ HTTP 404 bei Tile 8845/5474
# 2026-01-24 16:10:43,816 - WARNING - ⚠️ HTTP 404 bei Tile 8846/5473
# 2026-01-24 16:10:44,236 - INFO - 📈 DE-SN: 7000/8311 Tiles verarbeitet (5482 erfolgreich)
# 2026-01-24 16:10:52,707 - WARNING - ⚠️ HTTP 404 bei Tile 8847/5474
# 2026-01-24 16:10:53,350 - WARNING - ⚠️ HTTP 404 bei Tile 8847/5473
# 2026-01-24 16:12:58,017 - INFO - 📈 DE-SN: 8000/8311 Tiles verarbeitet (6222 erfolgreich)
# 2026-01-24 16:13:57,812 - INFO - ✅ DE-SN: 8311/8311 Tiles abgeschlossen (6449 erfolgreich, 1862 fehlgeschlagen)
# 2026-01-24 16:14:01,959 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SN_latest.parquet
# 2026-01-24 16:14:02,360 - INFO - 🔄 DE-SH: Datei ist 5.7 Tage alt, lade neu
# 2026-01-24 16:14:02,362 - INFO - ▶️ Starte Verarbeitung für DE-SH...
# 2026-01-24 16:14:02,400 - INFO - 📊 DE-SH: 9101 Tiles zu verarbeiten
# 2026-01-24 16:16:09,422 - INFO - 📈 DE-SH: 1000/9101 Tiles verarbeitet (546 erfolgreich)
# 2026-01-24 16:17:52,410 - INFO - 📈 DE-SH: 2000/9101 Tiles verarbeitet (1054 erfolgreich)
# 2026-01-24 16:19:37,941 - INFO - 📈 DE-SH: 3000/9101 Tiles verarbeitet (1719 erfolgreich)
# 2026-01-24 16:21:34,958 - INFO - 📈 DE-SH: 4000/9101 Tiles verarbeitet (2331 erfolgreich)
# 2026-01-24 16:23:29,732 - INFO - 📈 DE-SH: 5000/9101 Tiles verarbeitet (2901 erfolgreich)
# 2026-01-24 16:25:49,111 - INFO - 📈 DE-SH: 6000/9101 Tiles verarbeitet (3530 erfolgreich)
# 2026-01-24 16:27:46,943 - INFO - 📈 DE-SH: 7000/9101 Tiles verarbeitet (4186 erfolgreich)
# 2026-01-24 16:30:01,365 - INFO - 📈 DE-SH: 8000/9101 Tiles verarbeitet (4967 erfolgreich)
# 2026-01-24 16:32:56,749 - INFO - 📈 DE-SH: 9000/9101 Tiles verarbeitet (5753 erfolgreich)
# 2026-01-24 16:33:08,318 - INFO - ✅ DE-SH: 9101/9101 Tiles abgeschlossen (5807 erfolgreich, 3294 fehlgeschlagen)
# 2026-01-24 16:33:11,309 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SH_latest.parquet
# 2026-01-24 16:33:11,583 - INFO - 🔄 DE-TH: Datei ist 5.7 Tage alt, lade neu
# 2026-01-24 16:33:11,585 - INFO - ▶️ Starte Verarbeitung für DE-TH...
# 2026-01-24 16:33:11,603 - INFO - 📊 DE-TH: 6819 Tiles zu verarbeiten
# 2026-01-24 16:35:02,210 - INFO - 📈 DE-TH: 1000/6819 Tiles verarbeitet (628 erfolgreich)
# 2026-01-24 16:37:21,954 - INFO - 📈 DE-TH: 2000/6819 Tiles verarbeitet (1363 erfolgreich)
# 2026-01-24 16:39:36,670 - INFO - 📈 DE-TH: 3000/6819 Tiles verarbeitet (2064 erfolgreich)
# 2026-01-24 16:41:34,327 - INFO - 📈 DE-TH: 4000/6819 Tiles verarbeitet (2692 erfolgreich)
# 2026-01-24 16:43:30,833 - INFO - 📈 DE-TH: 5000/6819 Tiles verarbeitet (3383 erfolgreich)
# 2026-01-24 16:46:27,488 - INFO - 📈 DE-TH: 6000/6819 Tiles verarbeitet (4217 erfolgreich)
# 2026-01-24 16:48:28,438 - INFO - ✅ DE-TH: 6819/6819 Tiles abgeschlossen (4785 erfolgreich, 2034 fehlgeschlagen)
# 2026-01-24 16:48:31,245 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-TH_latest.parquet
# 2026-01-24 16:48:31,484 - INFO -
# 📅 Ältester Mapillary-Timestamp: 2026-01-24T10:34:20.439366+00:00
# 2026-01-24 16:48:31,486 - INFO - 💾 Metadata gespeichert: output/ml_metadata.json
# 2026-01-24 16:48:31,487 - INFO - 📄 Log-Datei: ml_output/mapillary_download_20260124_095355.log
# 2026-01-24 16:48:31,488 - INFO - === Mapillary Coverage Download abgeschlossen ===
