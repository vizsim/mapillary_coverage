# %% [markdown]
# # Was tut dieses Skript?
# Dieses Skript lädt die Mapillay coverage je Bundesland je Tiles herunter,
# filtert sie nach Aufnahmedatum,
# und exportiert die Ergebnisse als Parquet-Dateien.

# %%
import os

from config import BUNDESLAENDER, MAPILLARY_CONFIG, PROCESSING_CONFIG, TILES_CONFIG
from mapillary_coverage.mapillary import run_mapillary_download_pipeline

MAPILLARY_OUTPUT_FOLDER = os.environ.get(
    "MAPILLARY_COVERAGE_ML_OUTPUT_FOLDER",
    PROCESSING_CONFIG["ml_output_folder"],
    )
MAPILLARY_METADATA_OUTPUT_FOLDER = os.environ.get(
    "MAPILLARY_COVERAGE_OUTPUT_FOLDER",
    PROCESSING_CONFIG["output_folder"],
    )
MAPILLARY_TILE_CACHE_FOLDER = os.environ.get(
    "MAPILLARY_COVERAGE_TILE_CACHE_FOLDER",
    TILES_CONFIG["cache_folder"],
    )
MAPILLARY_NOTEBOOK_DRY_RUN = os.environ.get("MAPILLARY_COVERAGE_DRY_RUN", "").strip().lower() in {
    "1",
    "true",
    "yes",
    "on",
}
MAPILLARY_NOTEBOOK_LIMIT_TILES = (
    int(os.environ["MAPILLARY_COVERAGE_LIMIT_TILES"])
) if os.environ.get("MAPILLARY_COVERAGE_LIMIT_TILES") else None

print(f"Tile cache: {MAPILLARY_TILE_CACHE_FOLDER}")
print(f"Output:     {MAPILLARY_OUTPUT_FOLDER}")
print(f"Metadata:   {MAPILLARY_METADATA_OUTPUT_FOLDER}")
print(f"Dry run:    {MAPILLARY_NOTEBOOK_DRY_RUN}")
print(f"Limit tiles:{MAPILLARY_NOTEBOOK_LIMIT_TILES}")
print(f"Bundeslaender: {BUNDESLAENDER}")
# Out:
# Tile cache: prep/tile_cache
# Output:     ml_output
# Metadata:   output
# Dry run:    False
# Limit tiles:None
# Bundeslaender: None

# %%
mapillary_result = run_mapillary_download_pipeline(
    processing_config=PROCESSING_CONFIG,
    mapillary_config=MAPILLARY_CONFIG,
    tiles_config={**TILES_CONFIG, "cache_folder": MAPILLARY_TILE_CACHE_FOLDER},
    selected_bundeslaender=BUNDESLAENDER,
    output_folder=MAPILLARY_OUTPUT_FOLDER,
    metadata_output_folder=MAPILLARY_METADATA_OUTPUT_FOLDER,
    limit_tiles=MAPILLARY_NOTEBOOK_LIMIT_TILES,
    dry_run=MAPILLARY_NOTEBOOK_DRY_RUN,
    emit=print,
    )

mapillary_result
# Out:
# 2026-04-25 15:01:21,314 - INFO - === Mapillary Coverage Download gestartet ===
# 2026-04-25 15:01:21,316 - INFO - Log-Datei: ml_output/mapillary_download_20260425_150121.log
# 2026-04-25 15:01:21,317 - INFO - 📂 Lade Bundesländer aus: prep/bundeslaender.geojson
# 2026-04-25 15:01:21,318 - INFO - 📍 Verarbeite alle 16 Bundesländer
# 2026-04-25 15:01:21,319 - INFO - 📅 Freshness-Filter: Berlin Lauf-Tag-Start 2026-04-25T00:00:00+02:00, Cutoff 2023-10-25T00:00:00+02:00 (Vergleich UTC: 2023-10-24T22:00:00+00:00)
# 2026-04-25 15:01:21,321 - INFO - ▶️ Starte Verarbeitung für DE-BW...
# 2026-04-25 15:01:21,354 - INFO - 📊 DE-BW: 14160 Tiles zu verarbeiten
# 🧩 DE-BW:   6%|▌         | 841/14160 [01:48<28:41,  7.74it/s]
