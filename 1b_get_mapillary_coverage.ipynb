# %% [markdown]
# # Was tut dieses Skript?
# Dieses Skript lädt die Mapillay coverage je Bundesland je Tiles herunter,
# filtert sie nach Aufnahmedatum,
# und exportiert die Ergebnisse als Parquet-Dateien.

# %%
# Standard library
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime, timezone
import json
import os
import time
import logging
import sys

# Third-party
import geopandas as gpd
import mercantile
import pandas as pd
import requests
from requests.exceptions import SSLError
from tqdm import tqdm
from vt2geojson.tools import vt_bytes_to_geojson


from config import TILES_CONFIG, PROCESSING_CONFIG, MAPILLARY_CONFIG

# Setup Logging
log_folder = PROCESSING_CONFIG["ml_output_folder"]
os.makedirs(log_folder, exist_ok=True)
log_file = os.path.join(log_folder, f"mapillary_download_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log")

# Konfiguriere Logger
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file, encoding='utf-8'),
        logging.StreamHandler(sys.stdout)  # Auch in Console ausgeben
    ]
)

logger = logging.getLogger(__name__)
logger.info(f"=== Mapillary Coverage Download gestartet ===")
logger.info(f"Log-Datei: {log_file}")
# Out:
# 2026-02-19 18:03:04,202 - INFO - === Mapillary Coverage Download gestartet ===
# 2026-02-19 18:03:04,205 - INFO - Log-Datei: ml_output/mapillary_download_20260219_180304.log

# %%
TQDM_ENABLED = os.environ.get("TQDM_DISABLE", "0") != "1"

# %%
### Helper function for loading tile lists

def load_tiles_from_json(bundesland_id, input_folder = TILES_CONFIG["cache_folder"]):
    path = os.path.join(input_folder, f"{bundesland_id}_tiles.json")
    with open(path, "r") as f:
        tile_list = json.load(f)
    return [mercantile.Tile(**t) for t in tile_list]

# %%
def export_geodata(gdfs, output_folder = PROCESSING_CONFIG["output_folder"], base_name="mapillary_coverage", region="ger", save_parquet=True, save_geojson_gz=True):
    """
    Export one or more GeoDataFrames into output files (.parquet only, ohne Datum im Namen).
    
    Args:
        gdfs (list or GeoDataFrame): List of GeoDataFrames or a single GeoDataFrame.
        output_folder (str): Output directory (created if it doesn't exist).
        base_name (str): Base filename prefix.
        region (str): Region tag for filename.
        save_parquet (bool): Save .parquet file.
        save_geojson_gz (bool): Save .geojson.gz file (not implemented).
    
    Returns:
        str: Timestamp when data was processed (ISO format)
    """
    if gdfs is None or (isinstance(gdfs, (gpd.GeoDataFrame, pd.DataFrame)) and gdfs.empty):
        logger.warning("No data to export.")
        return None

    # Concatenate if needed
    if isinstance(gdfs, list):
        gdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))
    else:
        gdf = gdfs

    os.makedirs(output_folder, exist_ok=True)
    
    # Aktueller Zeitstempel für Metadata
    current_timestamp = datetime.now(timezone.utc).isoformat()

    if save_parquet:
        # Dateiname OHNE Datum - nur "latest"
        parquet_path = os.path.join(output_folder, f"{base_name}_{region}_latest.parquet")
        gdf.to_parquet(parquet_path, index=False)
        logger.info(f"✔ Parquet saved to: {parquet_path}")
    
    return current_timestamp

# %%
def process_bundesland(bundesland_id, region_name=None, input_folder = TILES_CONFIG["cache_folder"], output_folder = PROCESSING_CONFIG["ml_output_folder"] , max_workers=3, limit_tiles=None):
    logger.info(f"▶️ Starte Verarbeitung für {bundesland_id}...")

    tiles = load_tiles_from_json(bundesland_id, input_folder=input_folder)
    if limit_tiles:
        tiles = tiles[:limit_tiles]
    
    total_tiles = len(tiles)
    logger.info(f"📊 {bundesland_id}: {total_tiles} Tiles zu verarbeiten")
    
    # genereal config
    # Load your access token
    ACCESS_TOKEN = MAPILLARY_CONFIG["access_token"]

    # Use existing variables
    tile_layer = "sequence"  # or 'image' for points
    tile_coverage = "mly1_computed_public"
    
    # Tracking für aufeinanderfolgende Fehler
    consecutive_parse_errors = 0
    MAX_CONSECUTIVE_ERRORS = 5
    
    # Tracking für Fortschritt
    processed_count = 0
    successful_count = 0

    def process_tile(tile, retry_count=0, max_retries=3):
        """
        Verarbeite ein Tile mit Retry-Logik bei Parsing-Fehlern.
        
        Args:
            tile: Mercantile Tile Objekt
            retry_count: Aktueller Retry-Versuch
            max_retries: Maximale Anzahl an Versuchen
        """
        nonlocal consecutive_parse_errors
        
        url = f"https://tiles.mapillary.com/maps/vtp/{tile_coverage}/2/{tile.z}/{tile.x}/{tile.y}?access_token={ACCESS_TOKEN}"
        
        try:
            response = requests.get(url, timeout=30)
            
            # Rate Limit Check
            if response.status_code == 429:
                logger.warning(f"⚠️ Rate Limit erreicht bei Tile {tile.x}/{tile.y}. Pausiere für 5 Minuten...")
                time.sleep(300)
                if retry_count < max_retries:
                    return process_tile(tile, retry_count + 1, max_retries)
                return None
            
            if response.status_code != 200:
                logger.warning(f"⚠️ HTTP {response.status_code} bei Tile {tile.x}/{tile.y}")
                return None
            
            # Versuche Vector Tile zu parsen
            geojson = vt_bytes_to_geojson(response.content, tile.x, tile.y, tile.z, layer=tile_layer)
            features = geojson.get("features", [])
            
            if not features:
                return None
            
            gdf_tile = gpd.GeoDataFrame.from_features(features, crs="EPSG:4326")
            gdf_tile['captured_at'] = gdf_tile['captured_at'].apply(lambda x: datetime.fromtimestamp(x / 1000, tz=timezone.utc))
            
            # Timefilter
            min_date_str = PROCESSING_CONFIG["min_capture_date"]
            min_dt = datetime.strptime(min_date_str, "%Y-%m-%d").replace(tzinfo=timezone.utc)
            gdf_tile = gdf_tile[gdf_tile['captured_at'] >= min_dt]
            gdf_tile['captured_at'] = gdf_tile['captured_at'].dt.strftime('%Y-%m-%d')

            gdf_tile['tile_x'] = tile.x
            gdf_tile['tile_y'] = tile.y
            
            # Erfolg → Fehler-Counter zurücksetzen
            consecutive_parse_errors = 0
            return gdf_tile
            
        except Exception as e:
            error_msg = str(e)
            
            # Prüfe ob es ein Parsing-Fehler ist (wahrscheinlich Rate Limit)
            if "Error parsing message" in error_msg or "vector_tile" in error_msg:
                consecutive_parse_errors += 1
                
                # Prüfe ob zu viele aufeinanderfolgende Fehler
                if consecutive_parse_errors >= MAX_CONSECUTIVE_ERRORS:
                    logger.error(f"🛑 {MAX_CONSECUTIVE_ERRORS} aufeinanderfolgende Parsing-Fehler! API scheint blockiert zu sein.")
                    logger.warning(f"⏸️  LANGE PAUSE: 30 Minuten warten...")
                    time.sleep(1800)  # 30 Minuten
                    consecutive_parse_errors = 0  # Counter zurücksetzen
                    logger.info(f"▶️ Setze Verarbeitung fort nach langer Pause...")
                
                if retry_count < max_retries:
                    logger.warning(f"⚠️ Parsing-Fehler bei Tile {tile.x}/{tile.y} (Versuch {retry_count + 1}/{max_retries}, konsekutiv: {consecutive_parse_errors}). Pausiere für 5 Minuten...")
                    time.sleep(300)  # 5 Minuten Pause
                    return process_tile(tile, retry_count + 1, max_retries)
                else:
                    logger.error(f"❌ Tile {tile.x}/{tile.y} nach {max_retries} Versuchen fehlgeschlagen: {error_msg}")
                    return None
            else:
                logger.error(f"❌ Fehler bei Tile {tile.x}/{tile.y}: {error_msg}")
                return None

    gdf_all = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(process_tile, tile): tile for tile in tiles}
        for future in tqdm(as_completed(futures), total=len(futures), desc=f"🧩 {bundesland_id}", disable=not TQDM_ENABLED):
            try:
                result = future.result()
                processed_count += 1
                
                if result is not None:
                    gdf_all.append(result)
                    successful_count += 1
                
                # Progress-Logging alle 1000 Tiles (nur wenn >= 1000 Tiles total)
                if total_tiles >= 1000 and processed_count % 1000 == 0:
                    logger.info(f"📈 {bundesland_id}: {processed_count}/{total_tiles} Tiles verarbeitet ({successful_count} erfolgreich)")
                    
            except SSLError as e:
                logger.warning(f"⚠️ SSLError: {e}. Pausiere für 5 Minuten...")
                time.sleep(300)
            except Exception as e:
                logger.error(f"⚠️ Unbekannter Fehler: {e}")
    
    # Final Summary
    logger.info(f"✅ {bundesland_id}: {processed_count}/{total_tiles} Tiles abgeschlossen ({successful_count} erfolgreich, {processed_count - successful_count} fehlgeschlagen)")

    if gdf_all:
        gdf_all = gpd.GeoDataFrame(pd.concat(gdf_all, ignore_index=True))
        timestamp = export_geodata(
            gdfs=gdf_all,
            output_folder=output_folder,
            region=bundesland_id,
            save_parquet=True,
            save_geojson_gz=False
        )
        return timestamp
    else:
        logger.warning(f"⚠️ Keine Daten für {bundesland_id}.")
        return None

# %%
# Verarbeitung der Bundesländer basierend auf config.py
# takes about ~6.5h for all 16 bundesländer (on lokal machine)

# Lade Bundesländer aus Cache (wurde in Notebook 0 heruntergeladen)
bundesland_cache_path = os.path.join("prep", "bundeslaender.geojson")

if not os.path.exists(bundesland_cache_path):
    logger.error(f"❌ Bundesland-Cache nicht gefunden: {bundesland_cache_path}")
    logger.error(f"   Bitte zuerst Notebook 0_prepare_tiles.ipynb ausführen!")
    raise FileNotFoundError(f"Bundesland-GeoJSON fehlt: {bundesland_cache_path}")

logger.info(f"📂 Lade Bundesländer aus: {bundesland_cache_path}")
bland = gpd.read_file(bundesland_cache_path)

# Filter Bundesländer basierend auf config.py
from config import GEOFABRIK_CONFIG

selected_bundeslaender = GEOFABRIK_CONFIG.get("bundeslaender")
if selected_bundeslaender:
    # Nur die ausgewählten Bundesländer verarbeiten
    bland_filtered = bland[bland['id'].isin(selected_bundeslaender)]
    logger.info(f"🎯 Verarbeite {len(bland_filtered)} ausgewählte Bundesländer: {', '.join(selected_bundeslaender)}")
else:
    # Alle Bundesländer verarbeiten
    bland_filtered = bland
    logger.info(f"📍 Verarbeite alle {len(bland_filtered)} Bundesländer")

# Sammle Timestamps für Metadata
ml_timestamps = {}

for _, row in bland_filtered.iterrows():
    b_id = row["id"]
    name = row["name"]

    # Nur verarbeiten, wenn eine JSON-Datei existiert
    tile_json_path = os.path.join(TILES_CONFIG["cache_folder"], f"{b_id}_tiles.json")
    if not os.path.exists(tile_json_path):
        logger.warning(f"⏩ Überspringe {b_id}, keine Tiles gefunden.")
        continue

    # Prüfe ob Parquet bereits existiert und noch aktuell ist
    output_folder = PROCESSING_CONFIG["ml_output_folder"]
    parquet_path = os.path.join(output_folder, f"mapillary_coverage_{b_id}_latest.parquet")
    max_age_days = PROCESSING_CONFIG.get('max_file_age_days', 4)
    
    if os.path.exists(parquet_path):
        file_mtime = os.path.getmtime(parquet_path)
        file_age_days = (datetime.now().timestamp() - file_mtime) / 86400  # Sekunden in Tage
        
        if file_age_days < max_age_days:
            logger.info(f"⏩ {b_id}: Datei ist {file_age_days:.1f} Tage alt, überspringe Download")
            # Timestamp aus existierender Datei für Metadata verwenden
            ml_timestamps[b_id] = datetime.fromtimestamp(file_mtime, tz=timezone.utc).isoformat()
            continue
        else:
            logger.info(f"🔄 {b_id}: Datei ist {file_age_days:.1f} Tage alt, lade neu")

    timestamp = process_bundesland(b_id, region_name=name)
    if timestamp:
        ml_timestamps[b_id] = timestamp

# Speichere Metadata ähnlich wie osm_metadata.json
if ml_timestamps:
    # Finde ältesten Timestamp
    oldest_ml_timestamp = min(ml_timestamps.values())
    
    metadata = {
        "ml_data_from": oldest_ml_timestamp,
        "bundeslaender": ml_timestamps,
        "processed_date": datetime.now(timezone.utc).isoformat()
    }
    
    with open("output/ml_metadata.json", "w", encoding="utf-8") as f:
        json.dump(metadata, f, ensure_ascii=False, indent=2)
    
    logger.info(f"\n📅 Ältester Mapillary-Timestamp: {oldest_ml_timestamp}")
    logger.info(f"💾 Metadata gespeichert: output/ml_metadata.json")
    logger.info(f"📄 Log-Datei: {log_file}")
else:
    logger.warning("\n⚠️  Keine Mapillary-Daten verarbeitet, keine Metadata erstellt.")

logger.info("=== Mapillary Coverage Download abgeschlossen ===")
# Out:
# 2026-02-19 18:03:04,289 - INFO - 📂 Lade Bundesländer aus: prep/bundeslaender.geojson
# 2026-02-19 18:03:04,881 - INFO - 📍 Verarbeite alle 16 Bundesländer
# 2026-02-19 18:03:04,886 - INFO - 🔄 DE-BW: Datei ist 3.7 Tage alt, lade neu
# 2026-02-19 18:03:04,887 - INFO - ▶️ Starte Verarbeitung für DE-BW...
# 2026-02-19 18:03:04,942 - INFO - 📊 DE-BW: 14160 Tiles zu verarbeiten
# 2026-02-19 18:03:05,093 - ERROR - ❌ Fehler bei Tile 8533/5709: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Max retries exceeded with url: /maps/vtp/mly1_computed_public/2/14/8533/5709?access_token=MLY%7C9298308523597911%7Cc4503f1224f08315f3877b3fa267e186 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x75f92564c530>: Failed to resolve 'tiles.mapillary.com' ([Errno -3] Temporary failure in name resolution)"))
# 2026-02-19 18:03:05,109 - ERROR - ❌ Fehler bei Tile 8533/5708: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Max retries exceeded with url: /maps/vtp/mly1_computed_public/2/14/8533/5708?access_token=MLY%7C9298308523597911%7Cc4503f1224f08315f3877b3fa267e186 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x75f91991e540>: Failed to resolve 'tiles.mapillary.com' ([Errno -3] Temporary failure in name resolution)"))
# 2026-02-19 18:03:05,123 - ERROR - ❌ Fehler bei Tile 8533/5710: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Max retries exceeded with url: /maps/vtp/mly1_computed_public/2/14/8533/5710?access_token=MLY%7C9298308523597911%7Cc4503f1224f08315f3877b3fa267e186 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x75f919801550>: Failed to resolve 'tiles.mapillary.com' ([Errno -3] Temporary failure in name resolution)"))
# 2026-02-19 18:03:05,136 - ERROR - ❌ Fehler bei Tile 8533/5712: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Max retries exceeded with url: /maps/vtp/mly1_computed_public/2/14/8533/5712?access_token=MLY%7C9298308523597911%7Cc4503f1224f08315f3877b3fa267e186 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x75f9196b24b0>: Failed to resolve 'tiles.mapillary.com' ([Errno -3] Temporary failure in name resolution)"))
# 2026-02-19 18:03:05,136 - ERROR - ❌ Fehler bei Tile 8533/5711: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Max retries exceeded with url: /maps/vtp/mly1_computed_public/2/14/8533/5711?access_token=MLY%7C9298308523597911%7Cc4503f1224f08315f3877b3fa267e186 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x75f9196b2060>: Failed to resolve 'tiles.mapillary.com' ([Errno -3] Temporary failure in name resolution)"))
# 2026-02-19 18:03:05,147 - ERROR - ❌ Fehler bei Tile 8533/5713: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Max retries exceeded with url: /maps/vtp/mly1_computed_public/2/14/8533/5713?access_token=MLY%7C9298308523597911%7Cc4503f1224f08315f3877b3fa267e186 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x75f9196b28d0>: Failed to resolve 'tiles.mapillary.com' ([Errno -3] Temporary failure in name resolution)"))
# 2026-02-19 18:03:05,165 - ERROR - ❌ Fehler bei Tile 8533/5714: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Max retries exceeded with url: /maps/vtp/mly1_computed_public/2/14/8533/5714?access_token=MLY%7C9298308523597911%7Cc4503f1224f08315f3877b3fa267e186 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x75f9196749b0>: Failed to resolve 'tiles.mapillary.com' ([Errno -3] Temporary failure in name resolution)"))
# 2026-02-19 18:03:05,191 - ERROR - ❌ Fehler bei Tile 8533/5715: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Max retries exceeded with url: /maps/vtp/mly1_computed_public/2/14/8533/
# 2026-02-19 20:56:47,534 - INFO - 📈 DE-BB: 12000/13585 Tiles verarbeitet (9396 erfolgreich)
# 2026-02-19 20:58:47,240 - INFO - 📈 DE-BB: 13000/13585 Tiles verarbeitet (10228 erfolgreich)
# 2026-02-19 21:00:03,147 - INFO - ✅ DE-BB: 13585/13585 Tiles abgeschlossen (10718 erfolgreich, 2867 fehlgeschlagen)
# 2026-02-19 21:00:10,423 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BB_latest.parquet
# 2026-02-19 21:00:11,140 - INFO - 🔄 DE-HB: Datei ist 3.7 Tage alt, lade neu
# 2026-02-19 21:00:11,146 - INFO - ▶️ Starte Verarbeitung für DE-HB...
# 2026-02-19 21:00:11,153 - INFO - 📊 DE-HB: 145 Tiles zu verarbeiten
# 2026-02-19 21:01:25,130 - INFO - ✅ DE-HB: 145/145 Tiles abgeschlossen (135 erfolgreich, 10 fehlgeschlagen)
# 2026-02-19 21:01:25,285 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HB_latest.parquet
# 2026-02-19 21:01:25,308 - INFO - 🔄 DE-HH: Datei ist 3.7 Tage alt, lade neu
# 2026-02-19 21:01:25,314 - INFO - ▶️ Starte Verarbeitung für DE-HH...
# 2026-02-19 21:01:25,321 - INFO - 📊 DE-HH: 361 Tiles zu verarbeiten
# 2026-02-19 21:05:26,580 - INFO - ✅ DE-HH: 361/361 Tiles abgeschlossen (359 erfolgreich, 2 fehlgeschlagen)
# 2026-02-19 21:05:26,841 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HH_latest.parquet
# 2026-02-19 21:05:26,886 - INFO - 🔄 DE-HE: Datei ist 3.7 Tage alt, lade neu
# 2026-02-19 21:05:26,890 - INFO - ▶️ Starte Verarbeitung für DE-HE...
# 2026-02-19 21:05:26,919 - INFO - 📊 DE-HE: 8704 Tiles zu verarbeiten
# 2026-02-19 21:10:39,410 - INFO - 📈 DE-HE: 1000/8704 Tiles verarbeitet (805 erfolgreich)
# 2026-02-19 21:14:20,753 - INFO - 📈 DE-HE: 2000/8704 Tiles verarbeitet (1650 erfolgreich)
# 2026-02-19 21:21:12,657 - INFO - 📈 DE-HE: 3000/8704 Tiles verarbeitet (2541 erfolgreich)
# 2026-02-19 21:24:30,048 - INFO - 📈 DE-HE: 4000/8704 Tiles verarbeitet (3344 erfolgreich)
# 2026-02-19 21:27:28,188 - INFO - 📈 DE-HE: 5000/8704 Tiles verarbeitet (4108 erfolgreich)
# 2026-02-19 21:30:06,480 - INFO - 📈 DE-HE: 6000/8704 Tiles verarbeitet (4780 erfolgreich)
# 2026-02-19 21:32:42,888 - INFO - 📈 DE-HE: 7000/8704 Tiles verarbeitet (5448 erfolgreich)
# 2026-02-19 21:35:26,312 - INFO - 📈 DE-HE: 8000/8704 Tiles verarbeitet (6090 erfolgreich)
# 2026-02-19 21:37:04,714 - INFO - ✅ DE-HE: 8704/8704 Tiles abgeschlossen (6640 erfolgreich, 2064 fehlgeschlagen)
# 2026-02-19 21:37:09,051 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HE_latest.parquet
# 2026-02-19 21:37:09,579 - INFO - 🔄 DE-MV: Datei ist 3.7 Tage alt, lade neu
# 2026-02-19 21:37:09,592 - INFO - ▶️ Starte Verarbeitung für DE-MV...
# 2026-02-19 21:37:09,631 - INFO - 📊 DE-MV: 12294 Tiles zu verarbeiten
# 2026-02-19 21:39:07,262 - INFO - 📈 DE-MV: 1000/12294 Tiles verarbeitet (595 erfolgreich)
# 2026-02-19 21:41:19,700 - INFO - 📈 DE-MV: 2000/12294 Tiles verarbeitet (1158 erfolgreich)
# 2026-02-19 21:43:09,235 - INFO - 📈 DE-MV: 3000/12294 Tiles verarbeitet (1674 erfolgreich)
# 2026-02-19 21:45:27,462 - INFO - 📈 DE-MV: 4000/12294 Tiles verarbeitet (2037 erfolgreich)
# 2026-02-19 21:47:23,389 - INFO - 📈 DE-MV: 5000/12294 Tiles verarbeitet (2543 erfolgreich)
# 2026-02-19 21:49:10,721 - INFO - 📈 DE-MV: 6000/12294 Tiles verarbeitet (2979 erfolgreich)
# 2026-02-19 21:50:54,246 - INFO - 📈 DE-MV: 7000/12294 Tiles verarbeitet (3405 erfolgreich)
# 2026-02-19 21:52:53,473 - INFO - 📈 DE-MV: 8000/12294 Tiles verarbeitet (3731 erfolgreich)
# 2026-02-19 21:55:15,167 - INFO - 📈 DE-MV: 9000/12294 Tiles verarbeitet (4124 erfolgreich)
# 2026-02-19 21:57:31,163 - INFO - 📈 DE-MV: 10000/12294 Tiles verarbeitet (4627 erfolgreich)
# 2026-02-19 21:59:41,597 - INFO - 📈 DE-MV: 11000/12294 Tiles verarbeitet (5108 erfolgreich)
# 2026-02-19 22:01:43,444 - INFO - 📈 DE-MV: 12000/12294 Tiles verarbeitet (5610 erfolgreich)
# 2026-02-19 22:02:16,750 - INFO - ✅ DE-MV: 12294/12294 Tiles abgeschlossen (5799 erfolgreich, 6495 fehlgeschlagen)
# 2026-02-19 22:02:20,353 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-MV_latest.parquet
# 2026-02-19 22:02:20,702 - INFO - 🔄 DE-NI: Datei ist 3.7 Tage alt, lade neu
# 2026-02-19 22:02:20,708 - INFO - ▶️ Starte Verarbeitung für DE-NI...
# 2026-02-19 22:02:20,912 - INFO - 📊 DE-NI: 22844 Tiles zu verarbeiten
# 2026-02-19 22:05:05,488 - INFO - 📈 DE-NI: 1000/22844 Tiles verarbeitet (767 erfolgreich)
# 2026-02-19 22:07:11,989 - INFO - 📈 DE-NI: 2000/22844 Tiles verarbeitet (1494 erfolgreich)
# 2026-02-19 22:09:00,903 - INFO - 📈 DE-NI: 3000/22844 Tiles verarbeitet (2102 erfolgreich)
# 2026-02-19 22:11:19,361 - INFO - 📈 DE-NI: 4000/22844 Tiles verarbeitet (2467 erfolgreich)
# 2026-02-19 22:13:16,032 - INFO - 📈 DE-NI: 5000/22844 Tiles verarbeitet (3029 erfolgreich)
# 2026-02-19 22:15:21,966 - INFO - 📈 DE-NI: 6000/22844 Tiles verarbeitet (3713 erfolgreich)
# 2026-02-19 22:17:52,199 - INFO - 📈 DE-NI: 7000/22844 Tiles verarbeitet (4426 erfolgreich)
# 2026-02-19 22:20:05,154 - INFO - 📈 DE-NI: 8000/22844 Tiles verarbeitet (5032 erfolgreich)
# 2026-02-19 22:22:04,022 - INFO - 📈 DE-NI: 9000/22844 Tiles verarbeitet (5669 erfolgreich)
# 2026-02-19 23:38:33,869 - INFO - 📈 DE-NW: 10000/15243 Tiles verarbeitet (8864 erfolgreich)
# 2026-02-19 23:41:11,109 - INFO - 📈 DE-NW: 11000/15243 Tiles verarbeitet (9629 erfolgreich)
# 2026-02-19 23:43:13,129 - INFO - 📈 DE-NW: 12000/15243 Tiles verarbeitet (10270 erfolgreich)
# 2026-02-19 23:46:15,523 - INFO - 📈 DE-NW: 13000/15243 Tiles verarbeitet (11024 erfolgreich)
# 2026-02-19 23:49:25,587 - INFO - 📈 DE-NW: 14000/15243 Tiles verarbeitet (11844 erfolgreich)
# 2026-02-19 23:52:44,522 - INFO - 📈 DE-NW: 15000/15243 Tiles verarbeitet (12691 erfolgreich)
# 2026-02-19 23:53:07,522 - INFO - ✅ DE-NW: 15243/15243 Tiles abgeschlossen (12864 erfolgreich, 2379 fehlgeschlagen)
# 2026-02-19 23:53:17,664 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-NW_latest.parquet
# 2026-02-19 23:53:18,859 - INFO - 🔄 DE-RP: Datei ist 3.7 Tage alt, lade neu
# 2026-02-19 23:53:18,865 - INFO - ▶️ Starte Verarbeitung für DE-RP...
# 2026-02-19 23:53:18,893 - INFO - 📊 DE-RP: 8240 Tiles zu verarbeiten
# 2026-02-19 23:55:57,861 - INFO - 📈 DE-RP: 1000/8240 Tiles verarbeitet (836 erfolgreich)
# 2026-02-19 23:58:00,962 - INFO - 📈 DE-RP: 2000/8240 Tiles verarbeitet (1756 erfolgreich)
# 2026-02-20 00:00:18,405 - INFO - 📈 DE-RP: 3000/8240 Tiles verarbeitet (2654 erfolgreich)
# 2026-02-20 00:02:52,463 - INFO - 📈 DE-RP: 4000/8240 Tiles verarbeitet (3558 erfolgreich)
# 2026-02-20 00:05:19,490 - INFO - 📈 DE-RP: 5000/8240 Tiles verarbeitet (4420 erfolgreich)
# 2026-02-20 00:07:41,315 - INFO - 📈 DE-RP: 6000/8240 Tiles verarbeitet (5222 erfolgreich)
# 2026-02-20 00:10:03,473 - INFO - 📈 DE-RP: 7000/8240 Tiles verarbeitet (6031 erfolgreich)
# 2026-02-20 00:13:02,602 - INFO - 📈 DE-RP: 8000/8240 Tiles verarbeitet (6933 erfolgreich)
# 2026-02-20 00:13:59,396 - INFO - ✅ DE-RP: 8240/8240 Tiles abgeschlossen (7155 erfolgreich, 1085 fehlgeschlagen)
# 2026-02-20 00:14:03,821 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-RP_latest.parquet
# 2026-02-20 00:14:04,196 - INFO - 🔄 DE-SL: Datei ist 3.7 Tage alt, lade neu
# 2026-02-20 00:14:04,209 - INFO - ▶️ Starte Verarbeitung für DE-SL...
# 2026-02-20 00:14:04,216 - INFO - 📊 DE-SL: 1170 Tiles zu verarbeiten
# 2026-02-20 00:17:16,898 - INFO - 📈 DE-SL: 1000/1170 Tiles verarbeitet (883 erfolgreich)
# 2026-02-20 00:18:05,498 - INFO - ✅ DE-SL: 1170/1170 Tiles abgeschlossen (1035 erfolgreich, 135 fehlgeschlagen)
# 2026-02-20 00:18:06,214 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SL_latest.parquet
# 2026-02-20 00:18:06,293 - INFO - 🔄 DE-ST: Datei ist 3.7 Tage alt, lade neu
# 2026-02-20 00:18:06,298 - INFO - ▶️ Starte Verarbeitung für DE-ST...
# 2026-02-20 00:18:06,333 - INFO - 📊 DE-ST: 9077 Tiles zu verarbeiten
# 2026-02-20 00:19:57,527 - INFO - 📈 DE-ST: 1000/9077 Tiles verarbeitet (587 erfolgreich)
# 2026-02-20 00:21:41,371 - INFO - 📈 DE-ST: 2000/9077 Tiles verarbeitet (1224 erfolgreich)
# 2026-02-20 00:23:27,011 - INFO - 📈 DE-ST: 3000/9077 Tiles verarbeitet (1772 erfolgreich)
# 2026-02-20 00:25:13,565 - INFO - 📈 DE-ST: 4000/9077 Tiles verarbeitet (2314 erfolgreich)
# 2026-02-20 00:27:07,884 - INFO - 📈 DE-ST: 5000/9077 Tiles verarbeitet (2925 erfolgreich)
# 2026-02-20 00:29:06,126 - INFO - 📈 DE-ST: 6000/9077 Tiles verarbeitet (3612 erfolgreich)
# 2026-02-20 00:31:43,512 - INFO - 📈 DE-ST: 7000/9077 Tiles verarbeitet (4306 erfolgreich)
# 2026-02-20 00:33:54,069 - INFO - 📈 DE-ST: 8000/9077 Tiles verarbeitet (4913 erfolgreich)
# 2026-02-20 00:35:45,830 - INFO - 📈 DE-ST: 9000/9077 Tiles verarbeitet (5666 erfolgreich)
# 2026-02-20 00:35:53,293 - INFO - ✅ DE-ST: 9077/9077 Tiles abgeschlossen (5717 erfolgreich, 3360 fehlgeschlagen)
# 2026-02-20 00:35:57,568 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-ST_latest.parquet
# 2026-02-20 00:35:57,971 - INFO - 🔄 DE-SN: Datei ist 3.7 Tage alt, lade neu
# 2026-02-20 00:35:57,983 - INFO - ▶️ Starte Verarbeitung für DE-SN...
# 2026-02-20 00:35:58,012 - INFO - 📊 DE-SN: 8311 Tiles zu verarbeiten
# 2026-02-20 00:38:44,557 - INFO - 📈 DE-SN: 1000/8311 Tiles verarbeitet (801 erfolgreich)
# 2026-02-20 00:42:22,561 - INFO - 📈 DE-SN: 2000/8311 Tiles verarbeitet (1634 erfolgreich)
# 2026-02-20 00:44:36,606 - INFO - 📈 DE-SN: 3000/8311 Tiles verarbeitet (2420 erfolgreich)
# 2026-02-20 00:46:38,979 - INFO - 📈 DE-SN: 4000/8311 Tiles verarbeitet (3192 erfolgreich)
# 2026-02-20 00:48:24,818 - INFO - 📈 DE-SN: 5000/8311 Tiles verarbeitet (3951 erfolgreich)
# 2026-02-20 00:50:50,967 - INFO - 📈 DE-SN: 6000/8311 Tiles verarbeitet (4754 erfolgreich)
# 2026-02-20 00:52:29,409 - INFO - 📈 DE-SN: 7000/8311 Tiles verarbeitet (5486 erfolgreich)
# 2026-02-20 00:54:25,751 - INFO - 📈 DE-SN: 8000/8311 Tiles verarbeitet (6228 erfolgreich)
# 2026-02-20 00:55:24,433 - INFO - ✅ DE-SN: 8311/8311 Tiles abgeschlossen (6455 erfolgreich, 1856 fehlgeschlagen)
# 2026-02-20 00:55:28,889 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SN_latest.parquet
# 2026-02-20 00:55:29,330 - INFO - 🔄 DE-SH: Datei ist 3.7 Tage alt, lade neu
# 2026-02-20 00:55:29,342 - INFO - ▶️ Starte Verarbeitung für DE-SH...
# 2026-02-20 00:55:29,379 - INFO - 📊 DE-SH: 9101 Tiles zu verarbeiten
# 2026-02-20 00:57:26,504 - INFO - 📈 DE-SH: 1000/9101 Tiles verarbeitet (547 erfolgreich)
# 2026-02-20 00:58:56,160 - INFO - 📈 DE-SH: 2000/9101 Tiles verarbeitet (1055 erfolgreich)
# 2026-02-20 01:00:33,394 - INFO - 📈 DE-SH: 3000/9101 Tiles verarbeitet (1720 erfolgreich)
# 2026-02-20 01:02:26,210 - INFO - 📈 DE-SH: 4000/9101 Tiles verarbeitet (2332 erfolgreich)
# 2026-02-20 01:04:09,849 - INFO - 📈 DE-SH: 5000/9101 Tiles verarbeitet (2902 erfolgreich)
# 2026-02-20 01:06:36,080 - INFO - 📈 DE-SH: 6000/9101 Tiles verarbeitet (3532 erfolgreich)
# 2026-02-20 01:08:36,572 - INFO - 📈 DE-SH: 7000/9101 Tiles verarbeitet (4189 erfolgreich)
# 2026-02-20 01:10:51,493 - INFO - 📈 DE-SH: 8000/9101 Tiles verarbeitet (4970 erfolgreich)
# 2026-02-20 01:13:55,044 - INFO - 📈 DE-SH: 9000/9101 Tiles verarbeitet (5756 erfolgreich)
# 2026-02-20 01:14:07,339 - INFO - ✅ DE-SH: 9101/9101 Tiles abgeschlossen (5810 erfolgreich, 3291 fehlgeschlagen)
# 2026-02-20 01:14:11,117 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SH_latest.parquet
# 2026-02-20 01:14:11,517 - INFO - 🔄 DE-TH: Datei ist 3.7 Tage alt, lade neu
# 2026-02-20 01:14:11,538 - INFO - ▶️ Starte Verarbeitung für DE-TH...
# 2026-02-20 01:14:11,563 - INFO - 📊 DE-TH: 6819 Tiles zu verarbeiten
# 2026-02-20 01:16:01,461 - INFO - 📈 DE-TH: 1000/6819 Tiles verarbeitet (628 erfolgreich)
# 2026-02-20 01:18:21,595 - INFO - 📈 DE-TH: 2000/6819 Tiles verarbeitet (1363 erfolgreich)
# 2026-02-20 01:20:33,670 - INFO - 📈 DE-TH: 3000/6819 Tiles verarbeitet (2065 erfolgreich)
# 2026-02-20 01:22:26,444 - INFO - 📈 DE-TH: 4000/6819 Tiles verarbeitet (2693 erfolgreich)
# 2026-02-20 01:24:20,528 - INFO - 📈 DE-TH: 5000/6819 Tiles verarbeitet (3384 erfolgreich)
# 2026-02-20 01:27:15,386 - INFO - 📈 DE-TH: 6000/6819 Tiles verarbeitet (4218 erfolgreich)
# 2026-02-20 01:29:20,191 - INFO - ✅ DE-TH: 6819/6819 Tiles abgeschlossen (4786 erfolgreich, 2033 fehlgeschlagen)
# 2026-02-20 01:29:23,380 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-TH_latest.parquet
# 2026-02-20 01:29:23,676 - INFO -
# 📅 Ältester Mapillary-Timestamp: 2026-02-19T18:33:13.642813+00:00
# 2026-02-20 01:29:23,682 - INFO - 💾 Metadata gespeichert: output/ml_metadata.json
# 2026-02-20 01:29:23,689 - INFO - 📄 Log-Datei: ml_output/mapillary_download_20260219_180304.log
# 2026-02-20 01:29:23,695 - INFO - === Mapillary Coverage Download abgeschlossen ===
