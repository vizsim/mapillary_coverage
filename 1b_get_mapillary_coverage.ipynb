# %% [markdown]
# # Was tut dieses Skript?
# Dieses Skript lädt die Mapillay coverage je Bundesland je Tiles herunter,
# filtert sie nach Aufnahmedatum,
# und exportiert die Ergebnisse als Parquet-Dateien.

# %%
# Standard library
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime, timezone
import json
import os
import time
import logging
import sys

# Third-party
import geopandas as gpd
import mercantile
import pandas as pd
import requests
from requests.exceptions import SSLError
from tqdm import tqdm
from vt2geojson.tools import vt_bytes_to_geojson


from config import TILES_CONFIG, PROCESSING_CONFIG, MAPILLARY_CONFIG

# Setup Logging
log_folder = PROCESSING_CONFIG["ml_output_folder"]
os.makedirs(log_folder, exist_ok=True)
log_file = os.path.join(log_folder, f"mapillary_download_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log")

# Konfiguriere Logger
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file, encoding='utf-8'),
        logging.StreamHandler(sys.stdout)  # Auch in Console ausgeben
    ]
)

logger = logging.getLogger(__name__)
logger.info(f"=== Mapillary Coverage Download gestartet ===")
logger.info(f"Log-Datei: {log_file}")
# Out:
# 2026-01-18 17:37:58,504 - INFO - === Mapillary Coverage Download gestartet ===
# 2026-01-18 17:37:58,508 - INFO - Log-Datei: ml_output/mapillary_download_20260118_173758.log

# %%
TQDM_ENABLED = os.environ.get("TQDM_DISABLE", "0") != "1"

# %%
### Helper function for loading tile lists

def load_tiles_from_json(bundesland_id, input_folder = TILES_CONFIG["cache_folder"]):
    path = os.path.join(input_folder, f"{bundesland_id}_tiles.json")
    with open(path, "r") as f:
        tile_list = json.load(f)
    return [mercantile.Tile(**t) for t in tile_list]

# %%
def export_geodata(gdfs, output_folder = PROCESSING_CONFIG["output_folder"], base_name="mapillary_coverage", region="ger", save_parquet=True, save_geojson_gz=True):
    """
    Export one or more GeoDataFrames into output files (.parquet only, ohne Datum im Namen).
    
    Args:
        gdfs (list or GeoDataFrame): List of GeoDataFrames or a single GeoDataFrame.
        output_folder (str): Output directory (created if it doesn't exist).
        base_name (str): Base filename prefix.
        region (str): Region tag for filename.
        save_parquet (bool): Save .parquet file.
        save_geojson_gz (bool): Save .geojson.gz file (not implemented).
    
    Returns:
        str: Timestamp when data was processed (ISO format)
    """
    if gdfs is None or (isinstance(gdfs, (gpd.GeoDataFrame, pd.DataFrame)) and gdfs.empty):
        logger.warning("No data to export.")
        return None

    # Concatenate if needed
    if isinstance(gdfs, list):
        gdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))
    else:
        gdf = gdfs

    os.makedirs(output_folder, exist_ok=True)
    
    # Aktueller Zeitstempel für Metadata
    current_timestamp = datetime.now(timezone.utc).isoformat()

    if save_parquet:
        # Dateiname OHNE Datum - nur "latest"
        parquet_path = os.path.join(output_folder, f"{base_name}_{region}_latest.parquet")
        gdf.to_parquet(parquet_path, index=False)
        logger.info(f"✔ Parquet saved to: {parquet_path}")
    
    return current_timestamp

# %%
def process_bundesland(bundesland_id, region_name=None, input_folder = TILES_CONFIG["cache_folder"], output_folder = PROCESSING_CONFIG["ml_output_folder"] , max_workers=3, limit_tiles=None):
    logger.info(f"▶️ Starte Verarbeitung für {bundesland_id}...")

    tiles = load_tiles_from_json(bundesland_id, input_folder=input_folder)
    if limit_tiles:
        tiles = tiles[:limit_tiles]
    
    total_tiles = len(tiles)
    logger.info(f"📊 {bundesland_id}: {total_tiles} Tiles zu verarbeiten")
    
    # genereal config
    # Load your access token
    ACCESS_TOKEN = MAPILLARY_CONFIG["access_token"]

    # Use existing variables
    tile_layer = "sequence"  # or 'image' for points
    tile_coverage = "mly1_computed_public"
    
    # Tracking für aufeinanderfolgende Fehler
    consecutive_parse_errors = 0
    MAX_CONSECUTIVE_ERRORS = 5
    
    # Tracking für Fortschritt
    processed_count = 0
    successful_count = 0

    def process_tile(tile, retry_count=0, max_retries=3):
        """
        Verarbeite ein Tile mit Retry-Logik bei Parsing-Fehlern.
        
        Args:
            tile: Mercantile Tile Objekt
            retry_count: Aktueller Retry-Versuch
            max_retries: Maximale Anzahl an Versuchen
        """
        nonlocal consecutive_parse_errors
        
        url = f"https://tiles.mapillary.com/maps/vtp/{tile_coverage}/2/{tile.z}/{tile.x}/{tile.y}?access_token={ACCESS_TOKEN}"
        
        try:
            response = requests.get(url, timeout=30)
            
            # Rate Limit Check
            if response.status_code == 429:
                logger.warning(f"⚠️ Rate Limit erreicht bei Tile {tile.x}/{tile.y}. Pausiere für 5 Minuten...")
                time.sleep(300)
                if retry_count < max_retries:
                    return process_tile(tile, retry_count + 1, max_retries)
                return None
            
            if response.status_code != 200:
                logger.warning(f"⚠️ HTTP {response.status_code} bei Tile {tile.x}/{tile.y}")
                return None
            
            # Versuche Vector Tile zu parsen
            geojson = vt_bytes_to_geojson(response.content, tile.x, tile.y, tile.z, layer=tile_layer)
            features = geojson.get("features", [])
            
            if not features:
                return None
            
            gdf_tile = gpd.GeoDataFrame.from_features(features, crs="EPSG:4326")
            gdf_tile['captured_at'] = gdf_tile['captured_at'].apply(lambda x: datetime.fromtimestamp(x / 1000, tz=timezone.utc))
            
            # Timefilter
            min_date_str = PROCESSING_CONFIG["min_capture_date"]
            min_dt = datetime.strptime(min_date_str, "%Y-%m-%d").replace(tzinfo=timezone.utc)
            gdf_tile = gdf_tile[gdf_tile['captured_at'] >= min_dt]
            gdf_tile['captured_at'] = gdf_tile['captured_at'].dt.strftime('%Y-%m-%d')

            gdf_tile['tile_x'] = tile.x
            gdf_tile['tile_y'] = tile.y
            
            # Erfolg → Fehler-Counter zurücksetzen
            consecutive_parse_errors = 0
            return gdf_tile
            
        except Exception as e:
            error_msg = str(e)
            
            # Prüfe ob es ein Parsing-Fehler ist (wahrscheinlich Rate Limit)
            if "Error parsing message" in error_msg or "vector_tile" in error_msg:
                consecutive_parse_errors += 1
                
                # Prüfe ob zu viele aufeinanderfolgende Fehler
                if consecutive_parse_errors >= MAX_CONSECUTIVE_ERRORS:
                    logger.error(f"🛑 {MAX_CONSECUTIVE_ERRORS} aufeinanderfolgende Parsing-Fehler! API scheint blockiert zu sein.")
                    logger.warning(f"⏸️  LANGE PAUSE: 30 Minuten warten...")
                    time.sleep(1800)  # 30 Minuten
                    consecutive_parse_errors = 0  # Counter zurücksetzen
                    logger.info(f"▶️ Setze Verarbeitung fort nach langer Pause...")
                
                if retry_count < max_retries:
                    logger.warning(f"⚠️ Parsing-Fehler bei Tile {tile.x}/{tile.y} (Versuch {retry_count + 1}/{max_retries}, konsekutiv: {consecutive_parse_errors}). Pausiere für 5 Minuten...")
                    time.sleep(300)  # 5 Minuten Pause
                    return process_tile(tile, retry_count + 1, max_retries)
                else:
                    logger.error(f"❌ Tile {tile.x}/{tile.y} nach {max_retries} Versuchen fehlgeschlagen: {error_msg}")
                    return None
            else:
                logger.error(f"❌ Fehler bei Tile {tile.x}/{tile.y}: {error_msg}")
                return None

    gdf_all = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(process_tile, tile): tile for tile in tiles}
        for future in tqdm(as_completed(futures), total=len(futures), desc=f"🧩 {bundesland_id}", disable=not TQDM_ENABLED):
            try:
                result = future.result()
                processed_count += 1
                
                if result is not None:
                    gdf_all.append(result)
                    successful_count += 1
                
                # Progress-Logging alle 1000 Tiles (nur wenn >= 1000 Tiles total)
                if total_tiles >= 1000 and processed_count % 1000 == 0:
                    logger.info(f"📈 {bundesland_id}: {processed_count}/{total_tiles} Tiles verarbeitet ({successful_count} erfolgreich)")
                    
            except SSLError as e:
                logger.warning(f"⚠️ SSLError: {e}. Pausiere für 5 Minuten...")
                time.sleep(300)
            except Exception as e:
                logger.error(f"⚠️ Unbekannter Fehler: {e}")
    
    # Final Summary
    logger.info(f"✅ {bundesland_id}: {processed_count}/{total_tiles} Tiles abgeschlossen ({successful_count} erfolgreich, {processed_count - successful_count} fehlgeschlagen)")

    if gdf_all:
        gdf_all = gpd.GeoDataFrame(pd.concat(gdf_all, ignore_index=True))
        timestamp = export_geodata(
            gdfs=gdf_all,
            output_folder=output_folder,
            region=bundesland_id,
            save_parquet=True,
            save_geojson_gz=False
        )
        return timestamp
    else:
        logger.warning(f"⚠️ Keine Daten für {bundesland_id}.")
        return None

# %%
# Verarbeitung der Bundesländer basierend auf config.py
# takes about ~6.5h for all 16 bundesländer (on lokal machine)

# Lade Bundesländer aus Cache (wurde in Notebook 0 heruntergeladen)
bundesland_cache_path = os.path.join("prep", "bundeslaender.geojson")

if not os.path.exists(bundesland_cache_path):
    logger.error(f"❌ Bundesland-Cache nicht gefunden: {bundesland_cache_path}")
    logger.error(f"   Bitte zuerst Notebook 0_prepare_tiles.ipynb ausführen!")
    raise FileNotFoundError(f"Bundesland-GeoJSON fehlt: {bundesland_cache_path}")

logger.info(f"📂 Lade Bundesländer aus: {bundesland_cache_path}")
bland = gpd.read_file(bundesland_cache_path)

# Filter Bundesländer basierend auf config.py
from config import GEOFABRIK_CONFIG

selected_bundeslaender = GEOFABRIK_CONFIG.get("bundeslaender")
if selected_bundeslaender:
    # Nur die ausgewählten Bundesländer verarbeiten
    bland_filtered = bland[bland['id'].isin(selected_bundeslaender)]
    logger.info(f"🎯 Verarbeite {len(bland_filtered)} ausgewählte Bundesländer: {', '.join(selected_bundeslaender)}")
else:
    # Alle Bundesländer verarbeiten
    bland_filtered = bland
    logger.info(f"📍 Verarbeite alle {len(bland_filtered)} Bundesländer")

# Sammle Timestamps für Metadata
ml_timestamps = {}

for _, row in bland_filtered.iterrows():
    b_id = row["id"]
    name = row["name"]

    # Nur verarbeiten, wenn eine JSON-Datei existiert
    tile_json_path = os.path.join(TILES_CONFIG["cache_folder"], f"{b_id}_tiles.json")
    if not os.path.exists(tile_json_path):
        logger.warning(f"⏩ Überspringe {b_id}, keine Tiles gefunden.")
        continue

    # Prüfe ob Parquet bereits existiert und noch aktuell ist
    output_folder = PROCESSING_CONFIG["ml_output_folder"]
    parquet_path = os.path.join(output_folder, f"mapillary_coverage_{b_id}_latest.parquet")
    max_age_days = PROCESSING_CONFIG.get('max_file_age_days', 4)
    
    if os.path.exists(parquet_path):
        file_mtime = os.path.getmtime(parquet_path)
        file_age_days = (datetime.now().timestamp() - file_mtime) / 86400  # Sekunden in Tage
        
        if file_age_days < max_age_days:
            logger.info(f"⏩ {b_id}: Datei ist {file_age_days:.1f} Tage alt, überspringe Download")
            # Timestamp aus existierender Datei für Metadata verwenden
            ml_timestamps[b_id] = datetime.fromtimestamp(file_mtime, tz=timezone.utc).isoformat()
            continue
        else:
            logger.info(f"🔄 {b_id}: Datei ist {file_age_days:.1f} Tage alt, lade neu")

    timestamp = process_bundesland(b_id, region_name=name)
    if timestamp:
        ml_timestamps[b_id] = timestamp

# Speichere Metadata ähnlich wie osm_metadata.json
if ml_timestamps:
    # Finde ältesten Timestamp
    oldest_ml_timestamp = min(ml_timestamps.values())
    
    metadata = {
        "ml_data_from": oldest_ml_timestamp,
        "bundeslaender": ml_timestamps,
        "processed_date": datetime.now(timezone.utc).isoformat()
    }
    
    with open("output/ml_metadata.json", "w", encoding="utf-8") as f:
        json.dump(metadata, f, ensure_ascii=False, indent=2)
    
    logger.info(f"\n📅 Ältester Mapillary-Timestamp: {oldest_ml_timestamp}")
    logger.info(f"💾 Metadata gespeichert: output/ml_metadata.json")
    logger.info(f"📄 Log-Datei: {log_file}")
else:
    logger.warning("\n⚠️  Keine Mapillary-Daten verarbeitet, keine Metadata erstellt.")

logger.info("=== Mapillary Coverage Download abgeschlossen ===")
# Out:
# 2026-01-18 17:37:58,654 - INFO - 📂 Lade Bundesländer aus: prep/bundeslaender.geojson
# 2026-01-18 17:37:59,265 - INFO - 📍 Verarbeite alle 16 Bundesländer
# 2026-01-18 17:37:59,269 - INFO - 🔄 DE-BW: Datei ist 17.1 Tage alt, lade neu
# 2026-01-18 17:37:59,271 - INFO - ▶️ Starte Verarbeitung für DE-BW...
# 2026-01-18 17:37:59,327 - INFO - 📊 DE-BW: 14160 Tiles zu verarbeiten
# 2026-01-18 17:40:39,614 - INFO - 📈 DE-BW: 1000/14160 Tiles verarbeitet (843 erfolgreich)
# 2026-01-18 17:42:47,512 - INFO - 📈 DE-BW: 2000/14160 Tiles verarbeitet (1592 erfolgreich)
# 2026-01-18 17:44:56,110 - INFO - 📈 DE-BW: 3000/14160 Tiles verarbeitet (2376 erfolgreich)
# 2026-01-18 17:47:51,710 - INFO - 📈 DE-BW: 4000/14160 Tiles verarbeitet (3225 erfolgreich)
# 2026-01-18 17:51:40,657 - INFO - 📈 DE-BW: 5000/14160 Tiles verarbeitet (4065 erfolgreich)
# 2026-01-18 17:54:14,695 - INFO - 📈 DE-BW: 6000/14160 Tiles verarbeitet (4900 erfolgreich)
# 2026-01-18 17:57:18,693 - INFO - 📈 DE-BW: 7000/14160 Tiles verarbeitet (5770 erfolgreich)
# 2026-01-18 18:02:10,880 - INFO - 📈 DE-BW: 8000/14160 Tiles verarbeitet (6669 erfolgreich)
# 2026-01-18 18:05:35,124 - INFO - 📈 DE-BW: 9000/14160 Tiles verarbeitet (7549 erfolgreich)
# 2026-01-18 18:08:04,659 - INFO - 📈 DE-BW: 10000/14160 Tiles verarbeitet (8385 erfolgreich)
# 2026-01-18 18:10:20,475 - INFO - 📈 DE-BW: 11000/14160 Tiles verarbeitet (9176 erfolgreich)
# 2026-01-18 18:12:49,563 - INFO - 📈 DE-BW: 12000/14160 Tiles verarbeitet (9978 erfolgreich)
# 2026-01-18 18:15:23,857 - INFO - 📈 DE-BW: 13000/14160 Tiles verarbeitet (10790 erfolgreich)
# 2026-01-18 18:17:52,234 - INFO - 📈 DE-BW: 14000/14160 Tiles verarbeitet (11555 erfolgreich)
# 2026-01-18 18:18:11,393 - INFO - ✅ DE-BW: 14160/14160 Tiles abgeschlossen (11658 erfolgreich, 2502 fehlgeschlagen)
# 2026-01-18 18:18:20,241 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BW_latest.parquet
# 2026-01-18 18:18:21,360 - INFO - 🔄 DE-BY: Datei ist 17.0 Tage alt, lade neu
# 2026-01-18 18:18:21,361 - INFO - ▶️ Starte Verarbeitung für DE-BY...
# 2026-01-18 18:18:21,434 - INFO - 📊 DE-BY: 28376 Tiles zu verarbeiten
# 2026-01-18 18:20:53,842 - INFO - 📈 DE-BY: 1000/28376 Tiles verarbeitet (789 erfolgreich)
# 2026-01-18 18:23:18,711 - INFO - 📈 DE-BY: 2000/28376 Tiles verarbeitet (1522 erfolgreich)
# 2026-01-18 18:26:13,828 - INFO - 📈 DE-BY: 3000/28376 Tiles verarbeitet (2268 erfolgreich)
# 2026-01-18 18:28:27,480 - INFO - 📈 DE-BY: 4000/28376 Tiles verarbeitet (2982 erfolgreich)
# 2026-01-18 18:30:22,622 - INFO - 📈 DE-BY: 5000/28376 Tiles verarbeitet (3612 erfolgreich)
# 2026-01-18 18:32:13,117 - INFO - 📈 DE-BY: 6000/28376 Tiles verarbeitet (4216 erfolgreich)
# 2026-01-18 18:34:12,139 - INFO - 📈 DE-BY: 7000/28376 Tiles verarbeitet (4975 erfolgreich)
# 2026-01-18 18:36:15,487 - INFO - 📈 DE-BY: 8000/28376 Tiles verarbeitet (5663 erfolgreich)
# 2026-01-18 18:39:08,608 - INFO - 📈 DE-BY: 9000/28376 Tiles verarbeitet (6369 erfolgreich)
# 2026-01-18 18:44:40,195 - INFO - 📈 DE-BY: 10000/28376 Tiles verarbeitet (7076 erfolgreich)
# 2026-01-18 18:49:26,681 - INFO - 📈 DE-BY: 11000/28376 Tiles verarbeitet (7718 erfolgreich)
# 2026-01-18 18:51:37,011 - INFO - 📈 DE-BY: 12000/28376 Tiles verarbeitet (8410 erfolgreich)
# 2026-01-18 18:53:42,289 - INFO - 📈 DE-BY: 13000/28376 Tiles verarbeitet (9080 erfolgreich)
# 2026-01-18 18:55:43,344 - INFO - 📈 DE-BY: 14000/28376 Tiles verarbeitet (9762 erfolgreich)
# 2026-01-18 18:58:04,416 - INFO - 📈 DE-BY: 15000/28376 Tiles verarbeitet (10394 erfolgreich)
# 2026-01-18 19:01:02,321 - INFO - 📈 DE-BY: 16000/28376 Tiles verarbeitet (11040 erfolgreich)
# 2026-01-18 19:03:53,174 - INFO - 📈 DE-BY: 17000/28376 Tiles verarbeitet (11630 erfolgreich)
# 2026-01-18 19:06:11,325 - INFO - 📈 DE-BY: 18000/28376 Tiles verarbeitet (12219 erfolgreich)
# 2026-01-18 19:08:13,371 - INFO - 📈 DE-BY: 19000/28376 Tiles verarbeitet (12832 erfolgreich)
# 2026-01-18 19:10:22,603 - INFO - 📈 DE-BY: 20000/28376 Tiles verarbeitet (13467 erfolgreich)
# 2026-01-18 19:12:18,701 - WARNING - ⚠️ HTTP 404 bei Tile 8744/5657
# 2026-01-18 19:13:11,256 - INFO - 📈 DE-BY: 21000/28376 Tiles verarbeitet (14203 erfolgreich)
# 2026-01-18 19:15:27,682 - INFO - 📈 DE-BY: 22000/28376 Tiles verarbeitet (14940 erfolgreich)
# 2026-01-18 19:17:57,333 - INFO - 📈 DE-BY: 23000/28376 Tiles verarbeitet (15607 erfolgreich)
# 2026-01-18 19:21:12,473 - INFO - 📈 DE-BY: 24000/28376 Tiles verarbeitet (16184 erfolgreich)
# 2026-01-18 19:27:43,307 - INFO - 📈 DE-BY: 25000/28376 Tiles verarbeitet (16800 erfolgreich)
# 2026-01-18 19:30:35,884 - INFO - 📈 DE-BY: 26000/28376 Tiles verarbeitet (17413 erfolgreich)
# 2026-01-18 19:32:54,446 - INFO - 📈 DE-BY: 27000/28376 Tiles verarbeitet (18028 erfolgreich)
# 2026-01-18 19:34:43,772 - INFO - 📈 DE-BY: 28000/28376 Tiles verarbeitet (18542 erfolgreich)
# 2026-01-18 19:35:20,478 - INFO - ✅ DE-BY: 28376/28376 Tiles abgeschlossen (18697 erfolgreich, 9679 fehlgeschlagen)
# 2026-01-18 19:35:33,974 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BY_latest.parquet
# 2026-01-18 19:35:35,413 - INFO - 🔄 DE-BE: Datei ist 17.1 Tage alt, lade neu
# 2026-01-18 19:35:35,414 - INFO - ▶️ Starte Verarbeitung für DE-BE...
# 2026-01-18 19:35:35,418 - INFO - 📊 DE-BE: 399 Tiles zu verarbeiten
# 2026-01-18 19:44:45,551 - INFO - ✅ DE-BE: 399/399 Tiles abgeschlossen (398 erfolgreich, 1 fehlgeschlagen)
# 2026-01-18 19:44:46,302 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BE_latest.parquet
# 2026-01-18 19:44:46,430 - INFO - 🔄 DE-BB: Datei ist 17.1 Tage alt, lade neu
# 2026-01-18 19:44:46,432 - INFO - ▶️ Starte Verarbeitung für DE-BB...
# 2026-01-18 19:44:46,475 - INFO - 📊 DE-BB: 13585 Tiles zu verarbeiten
# 2026-01-18 19:47:12,272 - INFO - 📈 DE-BB: 1000/13585 Tiles verarbeitet (636 erfolgreich)
# 2026-01-18 19:49:00,186 - INFO - 📈 DE-BB: 2000/13585 Tiles verarbeitet (1287 erfolgreich)
# 2026-01-18 19:50:51,146 - INFO - 📈 DE-BB: 3000/13585 Tiles verarbeitet (1917 erfolgreich)
# 2026-01-18 19:52:53,207 - INFO - 📈 DE-BB: 4000/13585 Tiles verarbeitet (2656 erfolgreich)
# 2026-01-18 19:55:14,761 - INFO - 📈 DE-BB: 5000/13585 Tiles verarbeitet (3461 erfolgreich)
# 2026-01-18 19:57:40,987 - INFO - 📈 DE-BB: 6000/13585 Tiles verarbeitet (4323 erfolgreich)
# 2026-01-18 20:00:19,628 - INFO - 📈 DE-BB: 7000/13585 Tiles verarbeitet (5185 erfolgreich)
# 2026-01-18 20:02:56,782 - INFO - 📈 DE-BB: 8000/13585 Tiles verarbeitet (6063 erfolgreich)
# 2026-01-18 20:05:19,746 - INFO - 📈 DE-BB: 9000/13585 Tiles verarbeitet (6928 erfolgreich)
# 2026-01-18 20:07:21,995 - INFO - 📈 DE-BB: 10000/13585 Tiles verarbeitet (7785 erfolgreich)
# 2026-01-18 20:09:12,070 - INFO - 📈 DE-BB: 11000/13585 Tiles verarbeitet (8618 erfolgreich)
# 2026-01-18 20:10:54,575 - INFO - 📈 DE-BB: 12000/13585 Tiles verarbeitet (9393 erfolgreich)
# 2026-01-18 20:12:43,698 - INFO - 📈 DE-BB: 13000/13585 Tiles verarbeitet (10225 erfolgreich)
# 2026-01-18 20:13:48,984 - INFO - ✅ DE-BB: 13585/13585 Tiles abgeschlossen (10715 erfolgreich, 2870 fehlgeschlagen)
# 2026-01-18 20:13:57,394 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BB_latest.parquet
# 2026-01-18 20:13:58,012 - INFO - 🔄 DE-HB: Datei ist 17.1 Tage alt, lade neu
# 2026-01-18 20:13:58,013 - INFO - ▶️ Starte Verarbeitung für DE-HB...
# 2026-01-18 20:13:58,017 - INFO - 📊 DE-HB: 145 Tiles zu verarbeiten
# 2026-01-18 20:15:05,476 - INFO - ✅ DE-HB: 145/145 Tiles abgeschlossen (135 erfolgreich, 10 fehlgeschlagen)
# 2026-01-18 20:15:05,573 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HB_latest.parquet
# 2026-01-18 20:15:05,591 - INFO - 🔄 DE-HH: Datei ist 17.1 Tage alt, lade neu
# 2026-01-18 20:15:05,593 - INFO - ▶️ Starte Verarbeitung für DE-HH...
# 2026-01-18 20:15:05,596 - INFO - 📊 DE-HH: 361 Tiles zu verarbeiten
# 2026-01-18 20:18:33,451 - INFO - ✅ DE-HH: 361/361 Tiles abgeschlossen (359 erfolgreich, 2 fehlgeschlagen)
# 2026-01-18 20:18:33,707 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HH_latest.parquet
# 2026-01-18 20:18:33,759 - INFO - 🔄 DE-HE: Datei ist 17.1 Tage alt, lade neu
# 2026-01-18 20:18:33,761 - INFO - ▶️ Starte Verarbeitung für DE-HE...
# 2026-01-18 20:18:33,800 - INFO - 📊 DE-HE: 8704 Tiles zu verarbeiten
# 2026-01-18 20:21:12,625 - INFO - 📈 DE-HE: 1000/8704 Tiles verarbeitet (805 erfolgreich)
# 2026-01-18 20:24:26,826 - INFO - 📈 DE-HE: 2000/8704 Tiles verarbeitet (1650 erfolgreich)
# 2026-01-18 20:30:38,115 - INFO - 📈 DE-HE: 3000/8704 Tiles verarbeitet (2541 erfolgreich)
# 2026-01-18 20:33:10,179 - INFO - 📈 DE-HE: 4000/8704 Tiles verarbeitet (3344 erfolgreich)
# 2026-01-18 20:35:28,524 - INFO - 📈 DE-HE: 5000/8704 Tiles verarbeitet (4108 erfolgreich)
# 2026-01-18 20:37:42,765 - INFO - 📈 DE-HE: 6000/8704 Tiles verarbeitet (4779 erfolgreich)
# 2026-01-18 20:40:03,738 - INFO - 📈 DE-HE: 7000/8704 Tiles verarbeitet (5447 erfolgreich)
# 2026-01-18 20:42:24,875 - INFO - 📈 DE-HE: 8000/8704 Tiles verarbeitet (6088 erfolgreich)
# 2026-01-18 20:43:48,028 - INFO - ✅ DE-HE: 8704/8704 Tiles abgeschlossen (6638 erfolgreich, 2066 fehlgeschlagen)
# 2026-01-18 20:43:51,983 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HE_latest.parquet
# 2026-01-18 20:43:52,368 - INFO - 🔄 DE-MV: Datei ist 17.1 Tage alt, lade neu
# 2026-01-18 20:43:52,370 - INFO - ▶️ Starte Verarbeitung für DE-MV...
# 2026-01-18 20:43:52,406 - INFO - 📊 DE-MV: 12294 Tiles zu verarbeiten
# 2026-01-18 20:45:38,045 - INFO - 📈 DE-MV: 1000/12294 Tiles verarbeitet (595 erfolgreich)
# 2026-01-18 20:47:17,215 - INFO - 📈 DE-MV: 2000/12294 Tiles verarbeitet (1158 erfolgreich)
# 2026-01-18 20:48:53,194 - INFO - 📈 DE-MV: 3000/12294 Tiles verarbeitet (1674 erfolgreich)
# 2026-01-18 20:50:25,629 - INFO - 📈 DE-MV: 4000/12294 Tiles verarbeitet (2038 erfolgreich)
# 2026-01-18 20:52:08,478 - INFO - 📈 DE-MV: 5000/12294 Tiles verarbeitet (2544 erfolgreich)
# 2026-01-18 20:53:44,355 - INFO - 📈 DE-MV: 6000/12294 Tiles verarbeitet (2979 erfolgreich)
# 2026-01-18 20:55:17,114 - INFO - 📈 DE-MV: 7000/12294 Tiles verarbeitet (3406 erfolgreich)
# 2026-01-18 20:56:47,802 - INFO - 📈 DE-MV: 8000/12294 Tiles verarbeitet (3731 erfolgreich)
# 2026-01-18 20:58:24,245 - INFO - 📈 DE-MV: 9000/12294 Tiles verarbeitet (4124 erfolgreich)
# 2026-01-18 21:00:00,425 - INFO - 📈 DE-MV: 10000/12294 Tiles verarbeitet (4627 erfolgreich)
# 2026-01-18 21:01:32,955 - INFO - 📈 DE-MV: 11000/12294 Tiles verarbeitet (5108 erfolgreich)
# 2026-01-18 21:03:05,443 - INFO - 📈 DE-MV: 12000/12294 Tiles verarbeitet (5610 erfolgreich)
# 2026-01-18 21:03:34,337 - INFO - ✅ DE-MV: 12294/12294 Tiles abgeschlossen (5799 erfolgreich, 6495 fehlgeschlagen)
# 2026-01-18 21:03:37,658 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-MV_latest.parquet
# 2026-01-18 21:03:37,982 - INFO - 🔄 DE-NI: Datei ist 17.1 Tage alt, lade neu
# 2026-01-18 21:03:37,984 - INFO - ▶️ Starte Verarbeitung für DE-NI...
# 2026-01-18 21:03:38,075 - INFO - 📊 DE-NI: 22844 Tiles zu verarbeiten
# 2026-01-18 21:06:08,967 - INFO - 📈 DE-NI: 1000/22844 Tiles verarbeitet (768 erfolgreich)
# 2026-01-18 21:08:16,807 - INFO - 📈 DE-NI: 2000/22844 Tiles verarbeitet (1484 erfolgreich)
# 2026-01-18 21:10:09,276 - INFO - 📈 DE-NI: 3000/22844 Tiles verarbeitet (2092 erfolgreich)
# 2026-01-18 21:11:50,655 - INFO - 📈 DE-NI: 4000/22844 Tiles verarbeitet (2458 erfolgreich)
# 2026-01-18 21:13:37,541 - INFO - 📈 DE-NI: 5000/22844 Tiles verarbeitet (3018 erfolgreich)
# 2026-01-18 21:15:44,718 - INFO - 📈 DE-NI: 6000/22844 Tiles verarbeitet (3701 erfolgreich)
# 2026-01-18 21:18:01,736 - INFO - 📈 DE-NI: 7000/22844 Tiles verarbeitet (4413 erfolgreich)
# 2026-01-18 21:19:56,517 - INFO - 📈 DE-NI: 8000/22844 Tiles verarbeitet (5017 erfolgreich)
# 2026-01-18 21:21:52,379 - INFO - 📈 DE-NI: 9000/22844 Tiles verarbeitet (5651 erfolgreich)
# 2026-01-18 21:23:41,160 - INFO - 📈 DE-NI: 10000/22844 Tiles verarbeitet (6230 erfolgreich)
# 2026-01-18 21:25:27,342 - INFO - 📈 DE-NI: 11000/22844 Tiles verarbeitet (6846 erfolgreich)
# 2026-01-18 21:27:25,286 - INFO - 📈 DE-NI: 12000/22844 Tiles verarbeitet (7558 erfolgreich)
# 2026-01-18 21:29:21,384 - INFO - 📈 DE-NI: 13000/22844 Tiles verarbeitet (8245 erfolgreich)
# 2026-01-18 21:31:22,992 - INFO - 📈 DE-NI: 14000/22844 Tiles verarbeitet (8995 erfolgreich)
# 2026-01-18 21:33:45,984 - INFO - 📈 DE-NI: 15000/22844 Tiles verarbeitet (9780 erfolgreich)
# 2026-01-18 21:36:30,531 - INFO - 📈 DE-NI: 16000/22844 Tiles verarbeitet (10512 erfolgreich)
# 2026-01-18 21:39:22,969 - INFO - 📈 DE-NI: 17000/22844 Tiles verarbeitet (11358 erfolgreich)
# 2026-01-18 21:41:48,149 - INFO - 📈 DE-NI: 18000/22844 Tiles verarbeitet (12130 erfolgreich)
# 2026-01-18 21:43:55,926 - INFO - 📈 DE-NI: 19000/22844 Tiles verarbeitet (12915 erfolgreich)
# 2026-01-18 21:46:32,650 - INFO - 📈 DE-NI: 20000/22844 Tiles verarbeitet (13674 erfolgreich)
# 2026-01-18 21:49:34,563 - INFO - 📈 DE-NI: 21000/22844 Tiles verarbeitet (14527 erfolgreich)
# 2026-01-18 21:52:02,808 - INFO - 📈 DE-NI: 22000/22844 Tiles verarbeitet (15287 erfolgreich)
# 2026-01-18 21:53:34,427 - INFO - ✅ DE-NI: 22844/22844 Tiles abgeschlossen (15923 erfolgreich, 6921 fehlgeschlagen)
# 2026-01-18 21:53:43,879 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-NI_latest.parquet
# 2026-01-18 21:53:44,618 - INFO - 🔄 DE-NW: Datei ist 17.1 Tage alt, lade neu
# 2026-01-18 21:53:44,620 - INFO - ▶️ Starte Verarbeitung für DE-NW...
# 2026-01-18 21:53:44,667 - INFO - 📊 DE-NW: 15243 Tiles zu verarbeiten
# 2026-01-18 21:56:45,697 - INFO - 📈 DE-NW: 1000/15243 Tiles verarbeitet (687 erfolgreich)
# 2026-01-18 22:02:15,700 - INFO - 📈 DE-NW: 2000/15243 Tiles verarbeitet (1658 erfolgreich)
# 2026-01-18 22:05:45,578 - INFO - 📈 DE-NW: 3000/15243 Tiles verarbeitet (2579 erfolgreich)
# 2026-01-18 22:10:09,793 - INFO - 📈 DE-NW: 4000/15243 Tiles verarbeitet (3494 erfolgreich)
# 2026-01-18 22:14:29,653 - INFO - 📈 DE-NW: 5000/15243 Tiles verarbeitet (4402 erfolgreich)
# 2026-01-18 22:19:04,620 - INFO - 📈 DE-NW: 6000/15243 Tiles verarbeitet (5349 erfolgreich)
# 2026-01-18 22:23:48,245 - INFO - 📈 DE-NW: 7000/15243 Tiles verarbeitet (6277 erfolgreich)
# 2026-01-18 22:23:56,272 - WARNING - ⚠️ HTTP 404 bei Tile 8519/5467
# 2026-01-18 22:24:22,603 - WARNING - ⚠️ HTTP 404 bei Tile 8520/5464
# 2026-01-18 22:25:02,095 - WARNING - ⚠️ HTTP 404 bei Tile 8521/5509
# 2026-01-18 22:27:03,502 - INFO - 📈 DE-NW: 8000/15243 Tiles verarbeitet (7171 erfolgreich)
# 2026-01-18 22:30:06,793 - INFO - 📈 DE-NW: 9000/15243 Tiles verarbeitet (8049 erfolgreich)
# 2026-01-18 22:31:07,507 - WARNING - ⚠️ HTTP 404 bei Tile 8539/5406
# 2026-01-18 22:32:58,394 - WARNING - ⚠️ HTTP 404 bei Tile 8543/5417
# 2026-01-18 22:33:48,790 - INFO - 📈 DE-NW: 10000/15243 Tiles verarbeitet (8849 erfolgreich)
# 2026-01-18 22:36:32,066 - INFO - 📈 DE-NW: 11000/15243 Tiles verarbeitet (9614 erfolgreich)
# 2026-01-18 22:38:40,838 - INFO - 📈 DE-NW: 12000/15243 Tiles verarbeitet (10254 erfolgreich)
# 2026-01-18 22:41:34,921 - INFO - 📈 DE-NW: 13000/15243 Tiles verarbeitet (11005 erfolgreich)
# 2026-01-18 22:41:56,018 - WARNING - ⚠️ HTTP 404 bei Tile 8579/5422
# 2026-01-18 22:44:38,635 - INFO - 📈 DE-NW: 14000/15243 Tiles verarbeitet (11823 erfolgreich)
# 2026-01-18 22:47:41,063 - INFO - 📈 DE-NW: 15000/15243 Tiles verarbeitet (12669 erfolgreich)
# 2026-01-18 22:48:06,775 - INFO - ✅ DE-NW: 15243/15243 Tiles abgeschlossen (12842 erfolgreich, 2401 fehlgeschlagen)
# 2026-01-18 22:48:14,641 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-NW_latest.parquet
# 2026-01-18 22:48:15,515 - INFO - 🔄 DE-RP: Datei ist 17.1 Tage alt, lade neu
# 2026-01-18 22:48:15,517 - INFO - ▶️ Starte Verarbeitung für DE-RP...
# 2026-01-18 22:48:15,553 - INFO - 📊 DE-RP: 8240 Tiles zu verarbeiten
# 2026-01-18 22:50:56,938 - INFO - 📈 DE-RP: 1000/8240 Tiles verarbeitet (833 erfolgreich)
# 2026-01-18 22:53:00,894 - INFO - 📈 DE-RP: 2000/8240 Tiles verarbeitet (1753 erfolgreich)
# 2026-01-18 22:55:12,250 - INFO - 📈 DE-RP: 3000/8240 Tiles verarbeitet (2651 erfolgreich)
# 2026-01-18 22:57:31,423 - INFO - 📈 DE-RP: 4000/8240 Tiles verarbeitet (3555 erfolgreich)
# 2026-01-18 22:59:55,039 - INFO - 📈 DE-RP: 5000/8240 Tiles verarbeitet (4417 erfolgreich)
# 2026-01-18 23:02:21,180 - INFO - 📈 DE-RP: 6000/8240 Tiles verarbeitet (5219 erfolgreich)
# 2026-01-18 23:04:47,566 - INFO - 📈 DE-RP: 7000/8240 Tiles verarbeitet (6027 erfolgreich)
# 2026-01-18 23:07:37,744 - INFO - 📈 DE-RP: 8000/8240 Tiles verarbeitet (6929 erfolgreich)
# 2026-01-18 23:08:32,426 - INFO - ✅ DE-RP: 8240/8240 Tiles abgeschlossen (7151 erfolgreich, 1089 fehlgeschlagen)
# 2026-01-18 23:08:37,053 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-RP_latest.parquet
# 2026-01-18 23:08:37,409 - INFO - 🔄 DE-SL: Datei ist 17.1 Tage alt, lade neu
# 2026-01-18 23:08:37,411 - INFO - ▶️ Starte Verarbeitung für DE-SL...
# 2026-01-18 23:08:37,416 - INFO - 📊 DE-SL: 1170 Tiles zu verarbeiten
# 2026-01-18 23:11:38,349 - INFO - 📈 DE-SL: 1000/1170 Tiles verarbeitet (883 erfolgreich)
# 2026-01-18 23:12:20,896 - INFO - ✅ DE-SL: 1170/1170 Tiles abgeschlossen (1035 erfolgreich, 135 fehlgeschlagen)
# 2026-01-18 23:12:21,519 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SL_latest.parquet
# 2026-01-18 23:12:21,590 - INFO - 🔄 DE-ST: Datei ist 17.1 Tage alt, lade neu
# 2026-01-18 23:12:21,593 - INFO - ▶️ Starte Verarbeitung für DE-ST...
# 2026-01-18 23:12:21,636 - INFO - 📊 DE-ST: 9077 Tiles zu verarbeiten
# 2026-01-18 23:14:13,556 - INFO - 📈 DE-ST: 1000/9077 Tiles verarbeitet (587 erfolgreich)
# 2026-01-18 23:16:00,872 - INFO - 📈 DE-ST: 2000/9077 Tiles verarbeitet (1224 erfolgreich)
# 2026-01-18 23:17:45,098 - INFO - 📈 DE-ST: 3000/9077 Tiles verarbeitet (1772 erfolgreich)
# 2026-01-18 23:19:34,005 - INFO - 📈 DE-ST: 4000/9077 Tiles verarbeitet (2314 erfolgreich)
# 2026-01-18 23:21:31,758 - INFO - 📈 DE-ST: 5000/9077 Tiles verarbeitet (2925 erfolgreich)
# 2026-01-18 23:23:35,708 - INFO - 📈 DE-ST: 6000/9077 Tiles verarbeitet (3613 erfolgreich)
# 2026-01-18 23:26:16,875 - INFO - 📈 DE-ST: 7000/9077 Tiles verarbeitet (4306 erfolgreich)
# 2026-01-18 23:28:32,897 - INFO - 📈 DE-ST: 8000/9077 Tiles verarbeitet (4913 erfolgreich)
# 2026-01-18 23:30:30,738 - INFO - 📈 DE-ST: 9000/9077 Tiles verarbeitet (5666 erfolgreich)
# 2026-01-18 23:30:39,444 - INFO - ✅ DE-ST: 9077/9077 Tiles abgeschlossen (5717 erfolgreich, 3360 fehlgeschlagen)
# 2026-01-18 23:30:42,859 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-ST_latest.parquet
# 2026-01-18 23:30:43,162 - INFO - 🔄 DE-SN: Datei ist 17.1 Tage alt, lade neu
# 2026-01-18 23:30:43,164 - INFO - ▶️ Starte Verarbeitung für DE-SN...
# 2026-01-18 23:30:43,185 - INFO - 📊 DE-SN: 8311 Tiles zu verarbeiten
# 2026-01-18 23:33:28,359 - INFO - 📈 DE-SN: 1000/8311 Tiles verarbeitet (800 erfolgreich)
# 2026-01-18 23:36:59,720 - INFO - 📈 DE-SN: 2000/8311 Tiles verarbeitet (1633 erfolgreich)
# 2026-01-18 23:39:19,173 - INFO - 📈 DE-SN: 3000/8311 Tiles verarbeitet (2419 erfolgreich)
# 2026-01-18 23:41:26,075 - INFO - 📈 DE-SN: 4000/8311 Tiles verarbeitet (3189 erfolgreich)
# 2026-01-18 23:43:18,271 - INFO - 📈 DE-SN: 5000/8311 Tiles verarbeitet (3948 erfolgreich)
# 2026-01-18 23:45:50,042 - INFO - 📈 DE-SN: 6000/8311 Tiles verarbeitet (4751 erfolgreich)
# 2026-01-18 23:47:39,929 - INFO - 📈 DE-SN: 7000/8311 Tiles verarbeitet (5483 erfolgreich)
# 2026-01-18 23:49:44,208 - INFO - 📈 DE-SN: 8000/8311 Tiles verarbeitet (6225 erfolgreich)
# 2026-01-18 23:50:40,388 - INFO - ✅ DE-SN: 8311/8311 Tiles abgeschlossen (6452 erfolgreich, 1859 fehlgeschlagen)
# 2026-01-18 23:50:43,712 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SN_latest.parquet
# 2026-01-18 23:50:44,035 - INFO - 🔄 DE-SH: Datei ist 17.1 Tage alt, lade neu
# 2026-01-18 23:50:44,036 - INFO - ▶️ Starte Verarbeitung für DE-SH...
# 2026-01-18 23:50:44,061 - INFO - 📊 DE-SH: 9101 Tiles zu verarbeiten
# 2026-01-18 23:52:45,845 - INFO - 📈 DE-SH: 1000/9101 Tiles verarbeitet (546 erfolgreich)
# 2026-01-18 23:54:23,475 - INFO - 📈 DE-SH: 2000/9101 Tiles verarbeitet (1054 erfolgreich)
# 2026-01-18 23:56:07,118 - INFO - 📈 DE-SH: 3000/9101 Tiles verarbeitet (1719 erfolgreich)
# 2026-01-18 23:58:06,311 - INFO - 📈 DE-SH: 4000/9101 Tiles verarbeitet (2331 erfolgreich)
# 2026-01-18 23:59:57,896 - INFO - 📈 DE-SH: 5000/9101 Tiles verarbeitet (2901 erfolgreich)
# 2026-01-19 00:02:16,567 - INFO - 📈 DE-SH: 6000/9101 Tiles verarbeitet (3530 erfolgreich)
# 2026-01-19 00:04:15,247 - INFO - 📈 DE-SH: 7000/9101 Tiles verarbeitet (4186 erfolgreich)
# 2026-01-19 00:06:34,479 - INFO - 📈 DE-SH: 8000/9101 Tiles verarbeitet (4967 erfolgreich)
# 2026-01-19 00:09:35,493 - INFO - 📈 DE-SH: 9000/9101 Tiles verarbeitet (5753 erfolgreich)
# 2026-01-19 00:09:48,449 - INFO - ✅ DE-SH: 9101/9101 Tiles abgeschlossen (5807 erfolgreich, 3294 fehlgeschlagen)
# 2026-01-19 00:09:51,772 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SH_latest.parquet
# 2026-01-19 00:09:52,157 - INFO - 🔄 DE-TH: Datei ist 17.1 Tage alt, lade neu
# 2026-01-19 00:09:52,159 - INFO - ▶️ Starte Verarbeitung für DE-TH...
# 2026-01-19 00:09:52,190 - INFO - 📊 DE-TH: 6819 Tiles zu verarbeiten
# 2026-01-19 00:11:57,286 - INFO - 📈 DE-TH: 1000/6819 Tiles verarbeitet (629 erfolgreich)
# 2026-01-19 00:13:37,977 - WARNING - ⚠️ HTTP 404 bei Tile 8661/5486
# 2026-01-19 00:14:21,581 - INFO - 📈 DE-TH: 2000/6819 Tiles verarbeitet (1362 erfolgreich)
# 2026-01-19 00:16:35,677 - INFO - 📈 DE-TH: 3000/6819 Tiles verarbeitet (2063 erfolgreich)
# 2026-01-19 00:18:29,346 - INFO - 📈 DE-TH: 4000/6819 Tiles verarbeitet (2691 erfolgreich)
# 2026-01-19 00:20:22,660 - INFO - 📈 DE-TH: 5000/6819 Tiles verarbeitet (3382 erfolgreich)
# 2026-01-19 00:23:08,980 - INFO - 📈 DE-TH: 6000/6819 Tiles verarbeitet (4216 erfolgreich)
# 2026-01-19 00:24:27,704 - WARNING - ⚠️ HTTP 404 bei Tile 8735/5486
# 2026-01-19 00:25:13,095 - INFO - ✅ DE-TH: 6819/6819 Tiles abgeschlossen (4783 erfolgreich, 2036 fehlgeschlagen)
# 2026-01-19 00:25:15,847 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-TH_latest.parquet
# 2026-01-19 00:25:16,126 - INFO -
# 📅 Ältester Mapillary-Timestamp: 2026-01-18T18:18:18.889681+00:00
# 2026-01-19 00:25:16,127 - INFO - 💾 Metadata gespeichert: output/ml_metadata.json
# 2026-01-19 00:25:16,129 - INFO - 📄 Log-Datei: ml_output/mapillary_download_20260118_173758.log
# 2026-01-19 00:25:16,130 - INFO - === Mapillary Coverage Download abgeschlossen ===
