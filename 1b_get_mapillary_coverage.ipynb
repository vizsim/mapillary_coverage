# %% [markdown]
# # Was tut dieses Skript?
# Dieses Skript lädt die Mapillay coverage je Bundesland je Tiles herunter,
# filtert sie nach Aufnahmedatum,
# und exportiert die Ergebnisse als Parquet-Dateien.

# %%
# Standard library
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime, timezone
import json
import os
import time
import logging
import sys

# Third-party
import geopandas as gpd
import mercantile
import pandas as pd
import requests
from requests.exceptions import SSLError
from tqdm import tqdm
from vt2geojson.tools import vt_bytes_to_geojson


from config import TILES_CONFIG, PROCESSING_CONFIG, MAPILLARY_CONFIG

# Setup Logging
log_folder = PROCESSING_CONFIG["ml_output_folder"]
os.makedirs(log_folder, exist_ok=True)
log_file = os.path.join(log_folder, f"mapillary_download_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log")

# Konfiguriere Logger
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file, encoding='utf-8'),
        logging.StreamHandler(sys.stdout)  # Auch in Console ausgeben
    ]
)

logger = logging.getLogger(__name__)
logger.info(f"=== Mapillary Coverage Download gestartet ===")
logger.info(f"Log-Datei: {log_file}")
# Out:
# 2026-02-16 01:00:24,929 - INFO - === Mapillary Coverage Download gestartet ===
# 2026-02-16 01:00:24,932 - INFO - Log-Datei: ml_output/mapillary_download_20260216_010024.log

# %%
TQDM_ENABLED = os.environ.get("TQDM_DISABLE", "0") != "1"

# %%
### Helper function for loading tile lists

def load_tiles_from_json(bundesland_id, input_folder = TILES_CONFIG["cache_folder"]):
    path = os.path.join(input_folder, f"{bundesland_id}_tiles.json")
    with open(path, "r") as f:
        tile_list = json.load(f)
    return [mercantile.Tile(**t) for t in tile_list]

# %%
def export_geodata(gdfs, output_folder = PROCESSING_CONFIG["output_folder"], base_name="mapillary_coverage", region="ger", save_parquet=True, save_geojson_gz=True):
    """
    Export one or more GeoDataFrames into output files (.parquet only, ohne Datum im Namen).
    
    Args:
        gdfs (list or GeoDataFrame): List of GeoDataFrames or a single GeoDataFrame.
        output_folder (str): Output directory (created if it doesn't exist).
        base_name (str): Base filename prefix.
        region (str): Region tag for filename.
        save_parquet (bool): Save .parquet file.
        save_geojson_gz (bool): Save .geojson.gz file (not implemented).
    
    Returns:
        str: Timestamp when data was processed (ISO format)
    """
    if gdfs is None or (isinstance(gdfs, (gpd.GeoDataFrame, pd.DataFrame)) and gdfs.empty):
        logger.warning("No data to export.")
        return None

    # Concatenate if needed
    if isinstance(gdfs, list):
        gdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))
    else:
        gdf = gdfs

    os.makedirs(output_folder, exist_ok=True)
    
    # Aktueller Zeitstempel für Metadata
    current_timestamp = datetime.now(timezone.utc).isoformat()

    if save_parquet:
        # Dateiname OHNE Datum - nur "latest"
        parquet_path = os.path.join(output_folder, f"{base_name}_{region}_latest.parquet")
        gdf.to_parquet(parquet_path, index=False)
        logger.info(f"✔ Parquet saved to: {parquet_path}")
    
    return current_timestamp

# %%
def process_bundesland(bundesland_id, region_name=None, input_folder = TILES_CONFIG["cache_folder"], output_folder = PROCESSING_CONFIG["ml_output_folder"] , max_workers=3, limit_tiles=None):
    logger.info(f"▶️ Starte Verarbeitung für {bundesland_id}...")

    tiles = load_tiles_from_json(bundesland_id, input_folder=input_folder)
    if limit_tiles:
        tiles = tiles[:limit_tiles]
    
    total_tiles = len(tiles)
    logger.info(f"📊 {bundesland_id}: {total_tiles} Tiles zu verarbeiten")
    
    # genereal config
    # Load your access token
    ACCESS_TOKEN = MAPILLARY_CONFIG["access_token"]

    # Use existing variables
    tile_layer = "sequence"  # or 'image' for points
    tile_coverage = "mly1_computed_public"
    
    # Tracking für aufeinanderfolgende Fehler
    consecutive_parse_errors = 0
    MAX_CONSECUTIVE_ERRORS = 5
    
    # Tracking für Fortschritt
    processed_count = 0
    successful_count = 0

    def process_tile(tile, retry_count=0, max_retries=3):
        """
        Verarbeite ein Tile mit Retry-Logik bei Parsing-Fehlern.
        
        Args:
            tile: Mercantile Tile Objekt
            retry_count: Aktueller Retry-Versuch
            max_retries: Maximale Anzahl an Versuchen
        """
        nonlocal consecutive_parse_errors
        
        url = f"https://tiles.mapillary.com/maps/vtp/{tile_coverage}/2/{tile.z}/{tile.x}/{tile.y}?access_token={ACCESS_TOKEN}"
        
        try:
            response = requests.get(url, timeout=30)
            
            # Rate Limit Check
            if response.status_code == 429:
                logger.warning(f"⚠️ Rate Limit erreicht bei Tile {tile.x}/{tile.y}. Pausiere für 5 Minuten...")
                time.sleep(300)
                if retry_count < max_retries:
                    return process_tile(tile, retry_count + 1, max_retries)
                return None
            
            if response.status_code != 200:
                logger.warning(f"⚠️ HTTP {response.status_code} bei Tile {tile.x}/{tile.y}")
                return None
            
            # Versuche Vector Tile zu parsen
            geojson = vt_bytes_to_geojson(response.content, tile.x, tile.y, tile.z, layer=tile_layer)
            features = geojson.get("features", [])
            
            if not features:
                return None
            
            gdf_tile = gpd.GeoDataFrame.from_features(features, crs="EPSG:4326")
            gdf_tile['captured_at'] = gdf_tile['captured_at'].apply(lambda x: datetime.fromtimestamp(x / 1000, tz=timezone.utc))
            
            # Timefilter
            min_date_str = PROCESSING_CONFIG["min_capture_date"]
            min_dt = datetime.strptime(min_date_str, "%Y-%m-%d").replace(tzinfo=timezone.utc)
            gdf_tile = gdf_tile[gdf_tile['captured_at'] >= min_dt]
            gdf_tile['captured_at'] = gdf_tile['captured_at'].dt.strftime('%Y-%m-%d')

            gdf_tile['tile_x'] = tile.x
            gdf_tile['tile_y'] = tile.y
            
            # Erfolg → Fehler-Counter zurücksetzen
            consecutive_parse_errors = 0
            return gdf_tile
            
        except Exception as e:
            error_msg = str(e)
            
            # Prüfe ob es ein Parsing-Fehler ist (wahrscheinlich Rate Limit)
            if "Error parsing message" in error_msg or "vector_tile" in error_msg:
                consecutive_parse_errors += 1
                
                # Prüfe ob zu viele aufeinanderfolgende Fehler
                if consecutive_parse_errors >= MAX_CONSECUTIVE_ERRORS:
                    logger.error(f"🛑 {MAX_CONSECUTIVE_ERRORS} aufeinanderfolgende Parsing-Fehler! API scheint blockiert zu sein.")
                    logger.warning(f"⏸️  LANGE PAUSE: 30 Minuten warten...")
                    time.sleep(1800)  # 30 Minuten
                    consecutive_parse_errors = 0  # Counter zurücksetzen
                    logger.info(f"▶️ Setze Verarbeitung fort nach langer Pause...")
                
                if retry_count < max_retries:
                    logger.warning(f"⚠️ Parsing-Fehler bei Tile {tile.x}/{tile.y} (Versuch {retry_count + 1}/{max_retries}, konsekutiv: {consecutive_parse_errors}). Pausiere für 5 Minuten...")
                    time.sleep(300)  # 5 Minuten Pause
                    return process_tile(tile, retry_count + 1, max_retries)
                else:
                    logger.error(f"❌ Tile {tile.x}/{tile.y} nach {max_retries} Versuchen fehlgeschlagen: {error_msg}")
                    return None
            else:
                logger.error(f"❌ Fehler bei Tile {tile.x}/{tile.y}: {error_msg}")
                return None

    gdf_all = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(process_tile, tile): tile for tile in tiles}
        for future in tqdm(as_completed(futures), total=len(futures), desc=f"🧩 {bundesland_id}", disable=not TQDM_ENABLED):
            try:
                result = future.result()
                processed_count += 1
                
                if result is not None:
                    gdf_all.append(result)
                    successful_count += 1
                
                # Progress-Logging alle 1000 Tiles (nur wenn >= 1000 Tiles total)
                if total_tiles >= 1000 and processed_count % 1000 == 0:
                    logger.info(f"📈 {bundesland_id}: {processed_count}/{total_tiles} Tiles verarbeitet ({successful_count} erfolgreich)")
                    
            except SSLError as e:
                logger.warning(f"⚠️ SSLError: {e}. Pausiere für 5 Minuten...")
                time.sleep(300)
            except Exception as e:
                logger.error(f"⚠️ Unbekannter Fehler: {e}")
    
    # Final Summary
    logger.info(f"✅ {bundesland_id}: {processed_count}/{total_tiles} Tiles abgeschlossen ({successful_count} erfolgreich, {processed_count - successful_count} fehlgeschlagen)")

    if gdf_all:
        gdf_all = gpd.GeoDataFrame(pd.concat(gdf_all, ignore_index=True))
        timestamp = export_geodata(
            gdfs=gdf_all,
            output_folder=output_folder,
            region=bundesland_id,
            save_parquet=True,
            save_geojson_gz=False
        )
        return timestamp
    else:
        logger.warning(f"⚠️ Keine Daten für {bundesland_id}.")
        return None

# %%
# Verarbeitung der Bundesländer basierend auf config.py
# takes about ~6.5h for all 16 bundesländer (on lokal machine)

# Lade Bundesländer aus Cache (wurde in Notebook 0 heruntergeladen)
bundesland_cache_path = os.path.join("prep", "bundeslaender.geojson")

if not os.path.exists(bundesland_cache_path):
    logger.error(f"❌ Bundesland-Cache nicht gefunden: {bundesland_cache_path}")
    logger.error(f"   Bitte zuerst Notebook 0_prepare_tiles.ipynb ausführen!")
    raise FileNotFoundError(f"Bundesland-GeoJSON fehlt: {bundesland_cache_path}")

logger.info(f"📂 Lade Bundesländer aus: {bundesland_cache_path}")
bland = gpd.read_file(bundesland_cache_path)

# Filter Bundesländer basierend auf config.py
from config import GEOFABRIK_CONFIG

selected_bundeslaender = GEOFABRIK_CONFIG.get("bundeslaender")
if selected_bundeslaender:
    # Nur die ausgewählten Bundesländer verarbeiten
    bland_filtered = bland[bland['id'].isin(selected_bundeslaender)]
    logger.info(f"🎯 Verarbeite {len(bland_filtered)} ausgewählte Bundesländer: {', '.join(selected_bundeslaender)}")
else:
    # Alle Bundesländer verarbeiten
    bland_filtered = bland
    logger.info(f"📍 Verarbeite alle {len(bland_filtered)} Bundesländer")

# Sammle Timestamps für Metadata
ml_timestamps = {}

for _, row in bland_filtered.iterrows():
    b_id = row["id"]
    name = row["name"]

    # Nur verarbeiten, wenn eine JSON-Datei existiert
    tile_json_path = os.path.join(TILES_CONFIG["cache_folder"], f"{b_id}_tiles.json")
    if not os.path.exists(tile_json_path):
        logger.warning(f"⏩ Überspringe {b_id}, keine Tiles gefunden.")
        continue

    # Prüfe ob Parquet bereits existiert und noch aktuell ist
    output_folder = PROCESSING_CONFIG["ml_output_folder"]
    parquet_path = os.path.join(output_folder, f"mapillary_coverage_{b_id}_latest.parquet")
    max_age_days = PROCESSING_CONFIG.get('max_file_age_days', 4)
    
    if os.path.exists(parquet_path):
        file_mtime = os.path.getmtime(parquet_path)
        file_age_days = (datetime.now().timestamp() - file_mtime) / 86400  # Sekunden in Tage
        
        if file_age_days < max_age_days:
            logger.info(f"⏩ {b_id}: Datei ist {file_age_days:.1f} Tage alt, überspringe Download")
            # Timestamp aus existierender Datei für Metadata verwenden
            ml_timestamps[b_id] = datetime.fromtimestamp(file_mtime, tz=timezone.utc).isoformat()
            continue
        else:
            logger.info(f"🔄 {b_id}: Datei ist {file_age_days:.1f} Tage alt, lade neu")

    timestamp = process_bundesland(b_id, region_name=name)
    if timestamp:
        ml_timestamps[b_id] = timestamp

# Speichere Metadata ähnlich wie osm_metadata.json
if ml_timestamps:
    # Finde ältesten Timestamp
    oldest_ml_timestamp = min(ml_timestamps.values())
    
    metadata = {
        "ml_data_from": oldest_ml_timestamp,
        "bundeslaender": ml_timestamps,
        "processed_date": datetime.now(timezone.utc).isoformat()
    }
    
    with open("output/ml_metadata.json", "w", encoding="utf-8") as f:
        json.dump(metadata, f, ensure_ascii=False, indent=2)
    
    logger.info(f"\n📅 Ältester Mapillary-Timestamp: {oldest_ml_timestamp}")
    logger.info(f"💾 Metadata gespeichert: output/ml_metadata.json")
    logger.info(f"📄 Log-Datei: {log_file}")
else:
    logger.warning("\n⚠️  Keine Mapillary-Daten verarbeitet, keine Metadata erstellt.")

logger.info("=== Mapillary Coverage Download abgeschlossen ===")
# Out:
# 2026-02-16 01:00:25,031 - INFO - 📂 Lade Bundesländer aus: prep/bundeslaender.geojson
# 2026-02-16 01:00:25,726 - INFO - 📍 Verarbeite alle 16 Bundesländer
# 2026-02-16 01:00:25,730 - INFO - 🔄 DE-BW: Datei ist 7.0 Tage alt, lade neu
# 2026-02-16 01:00:25,732 - INFO - ▶️ Starte Verarbeitung für DE-BW...
# 2026-02-16 01:00:25,793 - INFO - 📊 DE-BW: 14160 Tiles zu verarbeiten
# 2026-02-16 01:00:25,831 - ERROR - ❌ Fehler bei Tile 8533/5708: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Max retries exceeded with url: /maps/vtp/mly1_computed_public/2/14/8533/5708?access_token=MLY%7C9298308523597911%7Cc4503f1224f08315f3877b3fa267e186 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x740b3305b860>: Failed to resolve 'tiles.mapillary.com' ([Errno -3] Temporary failure in name resolution)"))
# 2026-02-16 01:00:25,844 - ERROR - ❌ Fehler bei Tile 8533/5709: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Max retries exceeded with url: /maps/vtp/mly1_computed_public/2/14/8533/5709?access_token=MLY%7C9298308523597911%7Cc4503f1224f08315f3877b3fa267e186 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x740b3322a180>: Failed to resolve 'tiles.mapillary.com' ([Errno -3] Temporary failure in name resolution)"))
# 2026-02-16 01:00:25,857 - ERROR - ❌ Fehler bei Tile 8533/5711: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Max retries exceeded with url: /maps/vtp/mly1_computed_public/2/14/8533/5711?access_token=MLY%7C9298308523597911%7Cc4503f1224f08315f3877b3fa267e186 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x740b32e988f0>: Failed to resolve 'tiles.mapillary.com' ([Errno -3] Temporary failure in name resolution)"))
# 2026-02-16 01:00:25,858 - ERROR - ❌ Fehler bei Tile 8533/5710: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Max retries exceeded with url: /maps/vtp/mly1_computed_public/2/14/8533/5710?access_token=MLY%7C9298308523597911%7Cc4503f1224f08315f3877b3fa267e186 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x740b3322a510>: Failed to resolve 'tiles.mapillary.com' ([Errno -3] Temporary failure in name resolution)"))
# 2026-02-16 01:00:25,992 - ERROR - ❌ Fehler bei Tile 8533/5712: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Max retries exceeded with url: /maps/vtp/mly1_computed_public/2/14/8533/5712?access_token=MLY%7C9298308523597911%7Cc4503f1224f08315f3877b3fa267e186 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x740b3113d310>: Failed to resolve 'tiles.mapillary.com' ([Errno -3] Temporary failure in name resolution)"))
# 2026-02-16 01:00:26,043 - ERROR - ❌ Fehler bei Tile 8533/5713: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Max retries exceeded with url: /maps/vtp/mly1_computed_public/2/14/8533/5713?access_token=MLY%7C9298308523597911%7Cc4503f1224f08315f3877b3fa267e186 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x740b30e58fb0>: Failed to resolve 'tiles.mapillary.com' ([Errno -3] Temporary failure in name resolution)"))
# 2026-02-16 01:00:26,192 - ERROR - ❌ Fehler bei Tile 8533/5714: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Max retries exceeded with url: /maps/vtp/mly1_computed_public/2/14/8533/5714?access_token=MLY%7C9298308523597911%7Cc4503f1224f08315f3877b3fa267e186 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x740b30b89610>: Failed to resolve 'tiles.mapillary.com' ([Errno -3] Temporary failure in name resolution)"))
# 2026-02-16 01:00:26
- INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HE_latest.parquet
# 2026-02-16 03:52:05,764 - INFO - 🔄 DE-MV: Datei ist 7.0 Tage alt, lade neu
# 2026-02-16 03:52:05,776 - INFO - ▶️ Starte Verarbeitung für DE-MV...
# 2026-02-16 03:52:05,809 - INFO - 📊 DE-MV: 12294 Tiles zu verarbeiten
# 2026-02-16 03:53:44,866 - INFO - 📈 DE-MV: 1000/12294 Tiles verarbeitet (595 erfolgreich)
# 2026-02-16 03:55:18,030 - INFO - 📈 DE-MV: 2000/12294 Tiles verarbeitet (1158 erfolgreich)
# 2026-02-16 03:56:46,673 - INFO - 📈 DE-MV: 3000/12294 Tiles verarbeitet (1674 erfolgreich)
# 2026-02-16 03:58:10,921 - INFO - 📈 DE-MV: 4000/12294 Tiles verarbeitet (2038 erfolgreich)
# 2026-02-16 03:59:44,063 - INFO - 📈 DE-MV: 5000/12294 Tiles verarbeitet (2544 erfolgreich)
# 2026-02-16 04:01:18,885 - INFO - 📈 DE-MV: 6000/12294 Tiles verarbeitet (2979 erfolgreich)
# 2026-02-16 04:02:53,151 - INFO - 📈 DE-MV: 7000/12294 Tiles verarbeitet (3406 erfolgreich)
# 2026-02-16 04:04:26,796 - INFO - 📈 DE-MV: 8000/12294 Tiles verarbeitet (3731 erfolgreich)
# 2026-02-16 04:06:08,128 - INFO - 📈 DE-MV: 9000/12294 Tiles verarbeitet (4124 erfolgreich)
# 2026-02-16 04:07:48,298 - INFO - 📈 DE-MV: 10000/12294 Tiles verarbeitet (4627 erfolgreich)
# 2026-02-16 04:09:25,427 - INFO - 📈 DE-MV: 11000/12294 Tiles verarbeitet (5108 erfolgreich)
# 2026-02-16 04:11:03,744 - INFO - 📈 DE-MV: 12000/12294 Tiles verarbeitet (5610 erfolgreich)
# 2026-02-16 04:11:33,989 - INFO - ✅ DE-MV: 12294/12294 Tiles abgeschlossen (5799 erfolgreich, 6495 fehlgeschlagen)
# 2026-02-16 04:11:37,202 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-MV_latest.parquet
# 2026-02-16 04:11:37,503 - INFO - 🔄 DE-NI: Datei ist 6.9 Tage alt, lade neu
# 2026-02-16 04:11:37,508 - INFO - ▶️ Starte Verarbeitung für DE-NI...
# 2026-02-16 04:11:37,573 - INFO - 📊 DE-NI: 22844 Tiles zu verarbeiten
# 2026-02-16 04:14:00,092 - INFO - 📈 DE-NI: 1000/22844 Tiles verarbeitet (767 erfolgreich)
# 2026-02-16 04:15:50,047 - INFO - 📈 DE-NI: 2000/22844 Tiles verarbeitet (1494 erfolgreich)
# 2026-02-16 04:17:37,204 - INFO - 📈 DE-NI: 3000/22844 Tiles verarbeitet (2102 erfolgreich)
# 2026-02-16 04:19:12,052 - INFO - 📈 DE-NI: 4000/22844 Tiles verarbeitet (2468 erfolgreich)
# 2026-02-16 04:20:51,281 - INFO - 📈 DE-NI: 5000/22844 Tiles verarbeitet (3028 erfolgreich)
# 2026-02-16 04:22:49,826 - INFO - 📈 DE-NI: 6000/22844 Tiles verarbeitet (3715 erfolgreich)
# 2026-02-16 04:25:05,758 - INFO - 📈 DE-NI: 7000/22844 Tiles verarbeitet (4427 erfolgreich)
# 2026-02-16 04:26:59,287 - INFO - 📈 DE-NI: 8000/22844 Tiles verarbeitet (5033 erfolgreich)
- INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SL_latest.parquet
# 2026-02-16 06:21:23,138 - INFO - 🔄 DE-ST: Datei ist 7.0 Tage alt, lade neu
# 2026-02-16 06:21:23,142 - INFO - ▶️ Starte Verarbeitung für DE-ST...
# 2026-02-16 06:21:23,171 - INFO - 📊 DE-ST: 9077 Tiles zu verarbeiten
# 2026-02-16 06:23:07,336 - INFO - 📈 DE-ST: 1000/9077 Tiles verarbeitet (587 erfolgreich)
# 2026-02-16 06:24:51,219 - INFO - 📈 DE-ST: 2000/9077 Tiles verarbeitet (1225 erfolgreich)
# 2026-02-16 06:26:33,494 - INFO - 📈 DE-ST: 3000/9077 Tiles verarbeitet (1772 erfolgreich)
# 2026-02-16 06:28:19,141 - INFO - 📈 DE-ST: 4000/9077 Tiles verarbeitet (2315 erfolgreich)
# 2026-02-16 06:30:12,937 - INFO - 📈 DE-ST: 5000/9077 Tiles verarbeitet (2925 erfolgreich)
# 2026-02-16 06:32:13,404 - INFO - 📈 DE-ST: 6000/9077 Tiles verarbeitet (3613 erfolgreich)
# 2026-02-16 06:34:54,581 - INFO - 📈 DE-ST: 7000/9077 Tiles verarbeitet (4306 erfolgreich)
# 2026-02-16 06:37:19,052 - INFO - 📈 DE-ST: 8000/9077 Tiles verarbeitet (4913 erfolgreich)
# 2026-02-16 06:39:25,323 - INFO - 📈 DE-ST: 9000/9077 Tiles verarbeitet (5666 erfolgreich)
# 2026-02-16 06:39:33,634 - INFO - ✅ DE-ST: 9077/9077 Tiles abgeschlossen (5717 erfolgreich, 3360 fehlgeschlagen)
# 2026-02-16 06:39:37,078 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-ST_latest.parquet
# 2026-02-16 06:39:37,421 - INFO - 🔄 DE-SN: Datei ist 7.0 Tage alt, lade neu
# 2026-02-16 06:39:37,427 - INFO - ▶️ Starte Verarbeitung für DE-SN...
# 2026-02-16 06:39:37,461 - INFO - 📊 DE-SN: 8311 Tiles zu verarbeiten
# 2026-02-16 06:42:28,485 - INFO - 📈 DE-SN: 1000/8311 Tiles verarbeitet (801 erfolgreich)
# 2026-02-16 06:46:06,366 - INFO - 📈 DE-SN: 2000/8311 Tiles verarbeitet (1634 erfolgreich)
# 2026-02-16 06:48:26,407 - INFO - 📈 DE-SN: 3000/8311 Tiles verarbeitet (2420 erfolgreich)
# 2026-02-16 06:50:36,031 - INFO - 📈 DE-SN: 4000/8311 Tiles verarbeitet (3192 erfolgreich)
# 2026-02-16 06:52:29,150 - INFO - 📈 DE-SN: 5000/8311 Tiles verarbeitet (3951 erfolgreich)
# 2026-02-16 06:54:57,210 - INFO - 📈 DE-SN: 6000/8311 Tiles verarbeitet (4754 erfolgreich)
# 2026-02-16 06:56:43,885 - INFO - 📈 DE-SN: 7000/8311 Tiles verarbeitet (5486 erfolgreich)
# 2026-02-16 06:58:46,713 - INFO - 📈 DE-SN: 8000/8311 Tiles verarbeitet (6228 erfolgreich)
# 2026-02-16 06:59:47,380 - INFO - ✅ DE-SN: 8311/8311 Tiles abgeschlossen (6455 erfolgreich, 1856 fehlgeschlagen)
# 2026-02-16 06:59:51,436 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SN_latest.parquet
# 2026-02-16 06:59:51,812 - INFO - 🔄 DE-SH: Datei ist 7.0 Tage alt, lade neu
# 2026-02-16 06:59:51,817 - INFO - ▶️ Starte Verarbeitung für DE-SH...
# 2026-02-16 06:59:51,845 - INFO - 📊 DE-SH: 9101 Tiles zu verarbeiten
# 2026-02-16 07:01:55,117 - INFO - 📈 DE-SH: 1000/9101 Tiles verarbeitet (547 erfolgreich)
# 2026-02-16 07:03:33,602 - INFO - 📈 DE-SH: 2000/9101 Tiles verarbeitet (1055 erfolgreich)
# 2026-02-16 07:05:14,527 - INFO - 📈 DE-SH: 3000/9101 Tiles verarbeitet (1720 erfolgreich)
# 2026-02-16 07:07:11,691 - INFO - 📈 DE-SH: 4000/9101 Tiles verarbeitet (2332 erfolgreich)
# 2026-02-16 07:09:01,901 - INFO - 📈 DE-SH: 5000/9101 Tiles verarbeitet (2902 erfolgreich)
# 2026-02-16 07:11:20,138 - INFO - 📈 DE-SH: 6000/9101 Tiles verarbeitet (3532 erfolgreich)
# 2026-02-16 07:13:17,272 - INFO - 📈 DE-SH: 7000/9101 Tiles verarbeitet (4189 erfolgreich)
# 2026-02-16 07:15:25,772 - INFO - 📈 DE-SH: 8000/9101 Tiles verarbeitet (4970 erfolgreich)
# 2026-02-16 07:18:19,820 - INFO - 📈 DE-SH: 9000/9101 Tiles verarbeitet (5756 erfolgreich)
# 2026-02-16 07:18:31,154 - INFO - ✅ DE-SH: 9101/9101 Tiles abgeschlossen (5810 erfolgreich, 3291 fehlgeschlagen)
# 2026-02-16 07:18:34,600 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SH_latest.parquet
# 2026-02-16 07:18:34,916 - INFO - 🔄 DE-TH: Datei ist 7.0 Tage alt, lade neu
# 2026-02-16 07:18:34,921 - INFO - ▶️ Starte Verarbeitung für DE-TH...
# 2026-02-16 07:18:34,957 - INFO - 📊 DE-TH: 6819 Tiles zu verarbeiten
# 2026-02-16 07:20:19,703 - INFO - 📈 DE-TH: 1000/6819 Tiles verarbeitet (628 erfolgreich)
# 2026-02-16 07:22:33,001 - INFO - 📈 DE-TH: 2000/6819 Tiles verarbeitet (1363 erfolgreich)
# 2026-02-16 07:24:41,677 - INFO - 📈 DE-TH: 3000/6819 Tiles verarbeitet (2065 erfolgreich)
# 2026-02-16 07:26:29,635 - INFO - 📈 DE-TH: 4000/6819 Tiles verarbeitet (2693 erfolgreich)
# 2026-02-16 07:28:16,612 - INFO - 📈 DE-TH: 5000/6819 Tiles verarbeitet (3384 erfolgreich)
# 2026-02-16 07:31:03,219 - INFO - 📈 DE-TH: 6000/6819 Tiles verarbeitet (4218 erfolgreich)
# 2026-02-16 07:32:58,907 - INFO - ✅ DE-TH: 6819/6819 Tiles abgeschlossen (4786 erfolgreich, 2033 fehlgeschlagen)
# 2026-02-16 07:33:02,178 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-TH_latest.parquet
# 2026-02-16 07:33:02,515 - INFO -
# 📅 Ältester Mapillary-Timestamp: 2026-02-16T01:28:25.385777+00:00
# 2026-02-16 07:33:02,521 - INFO - 💾 Metadata gespeichert: output/ml_metadata.json
# 2026-02-16 07:33:02,526 - INFO - 📄 Log-Datei: ml_output/mapillary_download_20260216_010024.log
# 2026-02-16 07:33:02,531 - INFO - === Mapillary Coverage Download abgeschlossen ===
