# %% [markdown]
# # Was tut dieses Skript?
# Dieses Skript lädt die Mapillay coverage je Bundesland je Tiles herunter,
# filtert sie nach Aufnahmedatum,
# und exportiert die Ergebnisse als Parquet-Dateien.

# %%
# Standard library
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime, timezone
import json
import os
import time
import logging
import sys

# Third-party
import geopandas as gpd
import mercantile
import pandas as pd
import requests
from requests.exceptions import SSLError
from tqdm import tqdm
from vt2geojson.tools import vt_bytes_to_geojson


from config import TILES_CONFIG, PROCESSING_CONFIG, MAPILLARY_CONFIG

# Setup Logging
log_folder = PROCESSING_CONFIG["ml_output_folder"]
os.makedirs(log_folder, exist_ok=True)
log_file = os.path.join(log_folder, f"mapillary_download_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log")

# Konfiguriere Logger
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file, encoding='utf-8'),
        logging.StreamHandler(sys.stdout)  # Auch in Console ausgeben
    ]
)

logger = logging.getLogger(__name__)
logger.info(f"=== Mapillary Coverage Download gestartet ===")
logger.info(f"Log-Datei: {log_file}")
# Out:
# 2026-02-09 01:06:55,265 - INFO - === Mapillary Coverage Download gestartet ===
# 2026-02-09 01:06:55,267 - INFO - Log-Datei: ml_output/mapillary_download_20260209_010655.log

# %%
TQDM_ENABLED = os.environ.get("TQDM_DISABLE", "0") != "1"

# %%
### Helper function for loading tile lists

def load_tiles_from_json(bundesland_id, input_folder = TILES_CONFIG["cache_folder"]):
    path = os.path.join(input_folder, f"{bundesland_id}_tiles.json")
    with open(path, "r") as f:
        tile_list = json.load(f)
    return [mercantile.Tile(**t) for t in tile_list]

# %%
def export_geodata(gdfs, output_folder = PROCESSING_CONFIG["output_folder"], base_name="mapillary_coverage", region="ger", save_parquet=True, save_geojson_gz=True):
    """
    Export one or more GeoDataFrames into output files (.parquet only, ohne Datum im Namen).
    
    Args:
        gdfs (list or GeoDataFrame): List of GeoDataFrames or a single GeoDataFrame.
        output_folder (str): Output directory (created if it doesn't exist).
        base_name (str): Base filename prefix.
        region (str): Region tag for filename.
        save_parquet (bool): Save .parquet file.
        save_geojson_gz (bool): Save .geojson.gz file (not implemented).
    
    Returns:
        str: Timestamp when data was processed (ISO format)
    """
    if gdfs is None or (isinstance(gdfs, (gpd.GeoDataFrame, pd.DataFrame)) and gdfs.empty):
        logger.warning("No data to export.")
        return None

    # Concatenate if needed
    if isinstance(gdfs, list):
        gdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))
    else:
        gdf = gdfs

    os.makedirs(output_folder, exist_ok=True)
    
    # Aktueller Zeitstempel für Metadata
    current_timestamp = datetime.now(timezone.utc).isoformat()

    if save_parquet:
        # Dateiname OHNE Datum - nur "latest"
        parquet_path = os.path.join(output_folder, f"{base_name}_{region}_latest.parquet")
        gdf.to_parquet(parquet_path, index=False)
        logger.info(f"✔ Parquet saved to: {parquet_path}")
    
    return current_timestamp

# %%
def process_bundesland(bundesland_id, region_name=None, input_folder = TILES_CONFIG["cache_folder"], output_folder = PROCESSING_CONFIG["ml_output_folder"] , max_workers=3, limit_tiles=None):
    logger.info(f"▶️ Starte Verarbeitung für {bundesland_id}...")

    tiles = load_tiles_from_json(bundesland_id, input_folder=input_folder)
    if limit_tiles:
        tiles = tiles[:limit_tiles]
    
    total_tiles = len(tiles)
    logger.info(f"📊 {bundesland_id}: {total_tiles} Tiles zu verarbeiten")
    
    # genereal config
    # Load your access token
    ACCESS_TOKEN = MAPILLARY_CONFIG["access_token"]

    # Use existing variables
    tile_layer = "sequence"  # or 'image' for points
    tile_coverage = "mly1_computed_public"
    
    # Tracking für aufeinanderfolgende Fehler
    consecutive_parse_errors = 0
    MAX_CONSECUTIVE_ERRORS = 5
    
    # Tracking für Fortschritt
    processed_count = 0
    successful_count = 0

    def process_tile(tile, retry_count=0, max_retries=3):
        """
        Verarbeite ein Tile mit Retry-Logik bei Parsing-Fehlern.
        
        Args:
            tile: Mercantile Tile Objekt
            retry_count: Aktueller Retry-Versuch
            max_retries: Maximale Anzahl an Versuchen
        """
        nonlocal consecutive_parse_errors
        
        url = f"https://tiles.mapillary.com/maps/vtp/{tile_coverage}/2/{tile.z}/{tile.x}/{tile.y}?access_token={ACCESS_TOKEN}"
        
        try:
            response = requests.get(url, timeout=30)
            
            # Rate Limit Check
            if response.status_code == 429:
                logger.warning(f"⚠️ Rate Limit erreicht bei Tile {tile.x}/{tile.y}. Pausiere für 5 Minuten...")
                time.sleep(300)
                if retry_count < max_retries:
                    return process_tile(tile, retry_count + 1, max_retries)
                return None
            
            if response.status_code != 200:
                logger.warning(f"⚠️ HTTP {response.status_code} bei Tile {tile.x}/{tile.y}")
                return None
            
            # Versuche Vector Tile zu parsen
            geojson = vt_bytes_to_geojson(response.content, tile.x, tile.y, tile.z, layer=tile_layer)
            features = geojson.get("features", [])
            
            if not features:
                return None
            
            gdf_tile = gpd.GeoDataFrame.from_features(features, crs="EPSG:4326")
            gdf_tile['captured_at'] = gdf_tile['captured_at'].apply(lambda x: datetime.fromtimestamp(x / 1000, tz=timezone.utc))
            
            # Timefilter
            min_date_str = PROCESSING_CONFIG["min_capture_date"]
            min_dt = datetime.strptime(min_date_str, "%Y-%m-%d").replace(tzinfo=timezone.utc)
            gdf_tile = gdf_tile[gdf_tile['captured_at'] >= min_dt]
            gdf_tile['captured_at'] = gdf_tile['captured_at'].dt.strftime('%Y-%m-%d')

            gdf_tile['tile_x'] = tile.x
            gdf_tile['tile_y'] = tile.y
            
            # Erfolg → Fehler-Counter zurücksetzen
            consecutive_parse_errors = 0
            return gdf_tile
            
        except Exception as e:
            error_msg = str(e)
            
            # Prüfe ob es ein Parsing-Fehler ist (wahrscheinlich Rate Limit)
            if "Error parsing message" in error_msg or "vector_tile" in error_msg:
                consecutive_parse_errors += 1
                
                # Prüfe ob zu viele aufeinanderfolgende Fehler
                if consecutive_parse_errors >= MAX_CONSECUTIVE_ERRORS:
                    logger.error(f"🛑 {MAX_CONSECUTIVE_ERRORS} aufeinanderfolgende Parsing-Fehler! API scheint blockiert zu sein.")
                    logger.warning(f"⏸️  LANGE PAUSE: 30 Minuten warten...")
                    time.sleep(1800)  # 30 Minuten
                    consecutive_parse_errors = 0  # Counter zurücksetzen
                    logger.info(f"▶️ Setze Verarbeitung fort nach langer Pause...")
                
                if retry_count < max_retries:
                    logger.warning(f"⚠️ Parsing-Fehler bei Tile {tile.x}/{tile.y} (Versuch {retry_count + 1}/{max_retries}, konsekutiv: {consecutive_parse_errors}). Pausiere für 5 Minuten...")
                    time.sleep(300)  # 5 Minuten Pause
                    return process_tile(tile, retry_count + 1, max_retries)
                else:
                    logger.error(f"❌ Tile {tile.x}/{tile.y} nach {max_retries} Versuchen fehlgeschlagen: {error_msg}")
                    return None
            else:
                logger.error(f"❌ Fehler bei Tile {tile.x}/{tile.y}: {error_msg}")
                return None

    gdf_all = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(process_tile, tile): tile for tile in tiles}
        for future in tqdm(as_completed(futures), total=len(futures), desc=f"🧩 {bundesland_id}", disable=not TQDM_ENABLED):
            try:
                result = future.result()
                processed_count += 1
                
                if result is not None:
                    gdf_all.append(result)
                    successful_count += 1
                
                # Progress-Logging alle 1000 Tiles (nur wenn >= 1000 Tiles total)
                if total_tiles >= 1000 and processed_count % 1000 == 0:
                    logger.info(f"📈 {bundesland_id}: {processed_count}/{total_tiles} Tiles verarbeitet ({successful_count} erfolgreich)")
                    
            except SSLError as e:
                logger.warning(f"⚠️ SSLError: {e}. Pausiere für 5 Minuten...")
                time.sleep(300)
            except Exception as e:
                logger.error(f"⚠️ Unbekannter Fehler: {e}")
    
    # Final Summary
    logger.info(f"✅ {bundesland_id}: {processed_count}/{total_tiles} Tiles abgeschlossen ({successful_count} erfolgreich, {processed_count - successful_count} fehlgeschlagen)")

    if gdf_all:
        gdf_all = gpd.GeoDataFrame(pd.concat(gdf_all, ignore_index=True))
        timestamp = export_geodata(
            gdfs=gdf_all,
            output_folder=output_folder,
            region=bundesland_id,
            save_parquet=True,
            save_geojson_gz=False
        )
        return timestamp
    else:
        logger.warning(f"⚠️ Keine Daten für {bundesland_id}.")
        return None

# %%
# Verarbeitung der Bundesländer basierend auf config.py
# takes about ~6.5h for all 16 bundesländer (on lokal machine)

# Lade Bundesländer aus Cache (wurde in Notebook 0 heruntergeladen)
bundesland_cache_path = os.path.join("prep", "bundeslaender.geojson")

if not os.path.exists(bundesland_cache_path):
    logger.error(f"❌ Bundesland-Cache nicht gefunden: {bundesland_cache_path}")
    logger.error(f"   Bitte zuerst Notebook 0_prepare_tiles.ipynb ausführen!")
    raise FileNotFoundError(f"Bundesland-GeoJSON fehlt: {bundesland_cache_path}")

logger.info(f"📂 Lade Bundesländer aus: {bundesland_cache_path}")
bland = gpd.read_file(bundesland_cache_path)

# Filter Bundesländer basierend auf config.py
from config import GEOFABRIK_CONFIG

selected_bundeslaender = GEOFABRIK_CONFIG.get("bundeslaender")
if selected_bundeslaender:
    # Nur die ausgewählten Bundesländer verarbeiten
    bland_filtered = bland[bland['id'].isin(selected_bundeslaender)]
    logger.info(f"🎯 Verarbeite {len(bland_filtered)} ausgewählte Bundesländer: {', '.join(selected_bundeslaender)}")
else:
    # Alle Bundesländer verarbeiten
    bland_filtered = bland
    logger.info(f"📍 Verarbeite alle {len(bland_filtered)} Bundesländer")

# Sammle Timestamps für Metadata
ml_timestamps = {}

for _, row in bland_filtered.iterrows():
    b_id = row["id"]
    name = row["name"]

    # Nur verarbeiten, wenn eine JSON-Datei existiert
    tile_json_path = os.path.join(TILES_CONFIG["cache_folder"], f"{b_id}_tiles.json")
    if not os.path.exists(tile_json_path):
        logger.warning(f"⏩ Überspringe {b_id}, keine Tiles gefunden.")
        continue

    # Prüfe ob Parquet bereits existiert und noch aktuell ist
    output_folder = PROCESSING_CONFIG["ml_output_folder"]
    parquet_path = os.path.join(output_folder, f"mapillary_coverage_{b_id}_latest.parquet")
    max_age_days = PROCESSING_CONFIG.get('max_file_age_days', 4)
    
    if os.path.exists(parquet_path):
        file_mtime = os.path.getmtime(parquet_path)
        file_age_days = (datetime.now().timestamp() - file_mtime) / 86400  # Sekunden in Tage
        
        if file_age_days < max_age_days:
            logger.info(f"⏩ {b_id}: Datei ist {file_age_days:.1f} Tage alt, überspringe Download")
            # Timestamp aus existierender Datei für Metadata verwenden
            ml_timestamps[b_id] = datetime.fromtimestamp(file_mtime, tz=timezone.utc).isoformat()
            continue
        else:
            logger.info(f"🔄 {b_id}: Datei ist {file_age_days:.1f} Tage alt, lade neu")

    timestamp = process_bundesland(b_id, region_name=name)
    if timestamp:
        ml_timestamps[b_id] = timestamp

# Speichere Metadata ähnlich wie osm_metadata.json
if ml_timestamps:
    # Finde ältesten Timestamp
    oldest_ml_timestamp = min(ml_timestamps.values())
    
    metadata = {
        "ml_data_from": oldest_ml_timestamp,
        "bundeslaender": ml_timestamps,
        "processed_date": datetime.now(timezone.utc).isoformat()
    }
    
    with open("output/ml_metadata.json", "w", encoding="utf-8") as f:
        json.dump(metadata, f, ensure_ascii=False, indent=2)
    
    logger.info(f"\n📅 Ältester Mapillary-Timestamp: {oldest_ml_timestamp}")
    logger.info(f"💾 Metadata gespeichert: output/ml_metadata.json")
    logger.info(f"📄 Log-Datei: {log_file}")
else:
    logger.warning("\n⚠️  Keine Mapillary-Daten verarbeitet, keine Metadata erstellt.")

logger.info("=== Mapillary Coverage Download abgeschlossen ===")
# Out:
# 2026-02-09 01:06:55,395 - INFO - 📂 Lade Bundesländer aus: prep/bundeslaender.geojson
# 2026-02-09 01:06:55,968 - INFO - 📍 Verarbeite alle 16 Bundesländer
# 2026-02-09 01:06:55,973 - INFO - 🔄 DE-BW: Datei ist 7.0 Tage alt, lade neu
# 2026-02-09 01:06:55,974 - INFO - ▶️ Starte Verarbeitung für DE-BW...
# 2026-02-09 01:06:56,013 - INFO - 📊 DE-BW: 14160 Tiles zu verarbeiten
# 2026-02-09 01:09:40,177 - INFO - 📈 DE-BW: 1000/14160 Tiles verarbeitet (843 erfolgreich)
# 2026-02-09 01:11:53,577 - INFO - 📈 DE-BW: 2000/14160 Tiles verarbeitet (1592 erfolgreich)
# 2026-02-09 01:14:06,001 - INFO - 📈 DE-BW: 3000/14160 Tiles verarbeitet (2376 erfolgreich)
# 2026-02-09 01:17:03,992 - INFO - 📈 DE-BW: 4000/14160 Tiles verarbeitet (3226 erfolgreich)
# 2026-02-09 01:20:49,408 - INFO - 📈 DE-BW: 5000/14160 Tiles verarbeitet (4066 erfolgreich)
# 2026-02-09 01:23:28,743 - INFO - 📈 DE-BW: 6000/14160 Tiles verarbeitet (4901 erfolgreich)
# 2026-02-09 01:26:35,149 - INFO - 📈 DE-BW: 7000/14160 Tiles verarbeitet (5771 erfolgreich)
# 2026-02-09 01:31:23,145 - INFO - 📈 DE-BW: 8000/14160 Tiles verarbeitet (6671 erfolgreich)
# 2026-02-09 01:34:45,092 - INFO - 📈 DE-BW: 9000/14160 Tiles verarbeitet (7558 erfolgreich)
# 2026-02-09 01:37:14,119 - INFO - 📈 DE-BW: 10000/14160 Tiles verarbeitet (8395 erfolgreich)
# 2026-02-09 01:39:27,420 - INFO - 📈 DE-BW: 11000/14160 Tiles verarbeitet (9186 erfolgreich)
# 2026-02-09 01:40:18,590 - ERROR - ❌ Fehler bei Tile 8633/5625: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Read timed out. (read timeout=30)
# 2026-02-09 01:40:20,839 - ERROR - ❌ Fehler bei Tile 8633/5637: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Read timed out. (read timeout=30)
# 2026-02-09 01:40:21,574 - ERROR - ❌ Fehler bei Tile 8633/5640: HTTPSConnectionPool(host='tiles.mapillary.com', port=443): Read timed out. (read timeout=30)
# 2026-02-09 01:40:46,193 - WARNING - ⚠️ HTTP 502 bei Tile 8633/5693
# 2026-02-09 01:40:51,177 - WARNING - ⚠️ HTTP 502 bei Tile 8634/5597
# 2026-02-09 01:42:34,485 - INFO - 📈 DE-BW: 12000/14160 Tiles verarbeitet (9983 erfolgreich)
# 2026-02-09 01:45:03,103 - INFO - 📈 DE-BW: 13000/14160 Tiles verarbeitet (10795 erfolgreich)
# 2026-02-09 01:47:30,890 - INFO - 📈 DE-BW: 14000/14160 Tiles verarbeitet (11560 erfolgreich)
# 2026-02-09 01:47:49,483 - INFO - ✅ DE-BW: 14160/14160 Tiles abgeschlossen (11665 erfolgreich, 2495 fehlgeschlagen)
# 2026-02-09 01:47:56,784 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BW_latest.parquet
# 2026-02-09 01:47:57,603 - INFO - 🔄 DE-BY: Datei ist 7.0 Tage alt, lade neu
# 2026-02-09 01:47:57,605 - INFO - ▶️ Starte Verarbeitung für DE-BY...
# 2026-02-09 01:47:57,706 - INFO - 📊 DE-BY: 28376 Tiles zu verarbeiten
# 2026-02-09 01:50:30,318 - INFO - 📈 DE-BY: 1000/28376 Tiles verarbeitet (788 erfolgreich)
# 2026-02-09 01:52:56,163 - INFO - 📈 DE-BY: 2000/28376 Tiles verarbeitet (1522 erfolgreich)
# 2026-02-09 01:55:56,598 - INFO - 📈 DE-BY: 3000/28376 Tiles verarbeitet (2268 erfolgreich)
# 2026-02-09 01:58:16,158 - INFO - 📈 DE-BY: 4000/28376 Tiles verarbeitet (2982 erfolgreich)
# 2026-02-09 02:00:23,926 - INFO - 📈 DE-BY: 5000/28376 Tiles verarbeitet (3612 erfolgreich)
# 2026-02-09 02:02:36,277 - INFO - 📈 DE-BY: 6000/28376 Tiles verarbeitet (4216 erfolgreich)
# 2026-02-09 02:04:51,544 - INFO - 📈 DE-BY: 7000/28376 Tiles verarbeitet (4975 erfolgreich)
# 2026-02-09 02:07:17,722 - INFO - 📈 DE-BY: 8000/28376 Tiles verarbeitet (5663 erfolgreich)
# 2026-02-09 02:10:32,018 - INFO - 📈 DE-BY: 9000/28376 Tiles verarbeitet (6369 erfolgreich)
# 2026-02-09 02:16:28,668 - INFO - 📈 DE-BY: 10000/28376 Tiles verarbeitet (7076 erfolgreich)
# 2026-02-09 02:21:31,952 - INFO - 📈 DE-BY: 11000/28376 Tiles verarbeitet (7719 erfolgreich)
# 2026-02-09 02:23:55,746 - INFO - 📈 DE-BY: 12000/28376 Tiles verarbeitet (8410 erfolgreich)
# 2026-02-09 02:26:14,726 - INFO - 📈 DE-BY: 13000/28376 Tiles verarbeitet (9082 erfolgreich)
# 2026-02-09 02:28:27,672 - INFO - 📈 DE-BY: 14000/28376 Tiles verarbeitet (9764 erfolgreich)
# 2026-02-09 02:30:59,105 - INFO - 📈 DE-BY: 15000/28376 Tiles verarbeitet (10396 erfolgreich)
# 2026-02-09 02:34:19,674 - INFO - 📈 DE-BY: 16000/28376 Tiles verarbeitet (11043 erfolgreich)
# 2026-02-09 02:37:23,730 - INFO - 📈 DE-BY: 17000/28376 Tiles verarbeitet (11633 erfolgreich)
# 2026-02-09 02:39:55,530 - INFO - 📈 DE-BY: 18000/28376 Tiles verarbeitet (12222 erfolgreich)
# 2026-02-09 02:42:10,404 - INFO - 📈 DE-BY: 19000/28376 Tiles verarbeitet (12835 erfolgreich)
# 2026-02-09 02:44:33,626 - INFO - 📈 DE-BY: 20000/28376 Tiles verarbeitet (13469 erfolgreich)
# 2026-02-09 02:47:30,134 - INFO - 📈 DE-BY: 21000/28376 Tiles verarbeitet (14210 erfolgreich)
# 2026-02-09 02:49:57,900 - INFO - 📈 DE-BY: 22000/28376 Tiles verarbeitet (14953 erfolgreich)
# 2026-02-09 02:52:38,023 - INFO - 📈 DE-BY: 23000/28376 Tiles verarbeitet (15620 erfolgreich)
# 2026-02-09 02:56:03,764 - INFO - 📈 DE-BY: 24000/28376 Tiles verarbeitet (16198 erfolgreich)
# 2026-02-09 03:02:48,275 - INFO - 📈 DE-BY: 25000/28376 Tiles verarbeitet (16817 erfolgreich)
# 2026-02-09 03:05:45,968 - INFO - 📈 DE-BY: 26000/28376 Tiles verarbeitet (17430 erfolgreich)
# 2026-02-09 03:08:13,018 - INFO - 📈 DE-BY: 27000/28376 Tiles verarbeitet (18050 erfolgreich)
# 2026-02-09 03:10:06,418 - INFO - 📈 DE-BY: 28000/28376 Tiles verarbeitet (18563 erfolgreich)
# 2026-02-09 03:10:45,347 - INFO - ✅ DE-BY: 28376/28376 Tiles abgeschlossen (18718 erfolgreich, 9658 fehlgeschlagen)
# 2026-02-09 03:10:57,757 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BY_latest.parquet
# 2026-02-09 03:10:59,292 - INFO - 🔄 DE-BE: Datei ist 7.0 Tage alt, lade neu
# 2026-02-09 03:10:59,295 - INFO - ▶️ Starte Verarbeitung für DE-BE...
# 2026-02-09 03:10:59,301 - INFO - 📊 DE-BE: 399 Tiles zu verarbeiten
# 2026-02-09 03:20:35,412 - INFO - ✅ DE-BE: 399/399 Tiles abgeschlossen (398 erfolgreich, 1 fehlgeschlagen)
# 2026-02-09 03:20:36,061 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BE_latest.parquet
# 2026-02-09 03:20:36,230 - INFO - 🔄 DE-BB: Datei ist 7.0 Tage alt, lade neu
# 2026-02-09 03:20:36,232 - INFO - ▶️ Starte Verarbeitung für DE-BB...
# 2026-02-09 03:20:36,386 - INFO - 📊 DE-BB: 13585 Tiles zu verarbeiten
# 2026-02-09 03:23:01,555 - INFO - 📈 DE-BB: 1000/13585 Tiles verarbeitet (636 erfolgreich)
# 2026-02-09 03:24:50,098 - INFO - 📈 DE-BB: 2000/13585 Tiles verarbeitet (1286 erfolgreich)
# 2026-02-09 03:26:43,426 - INFO - 📈 DE-BB: 3000/13585 Tiles verarbeitet (1917 erfolgreich)
# 2026-02-09 03:28:49,590 - INFO - 📈 DE-BB: 4000/13585 Tiles verarbeitet (2656 erfolgreich)
# 2026-02-09 03:31:13,715 - INFO - 📈 DE-BB: 5000/13585 Tiles verarbeitet (3461 erfolgreich)
# 2026-02-09 03:33:46,521 - INFO - 📈 DE-BB: 6000/13585 Tiles verarbeitet (4323 erfolgreich)
# 2026-02-09 03:36:31,109 - INFO - 📈 DE-BB: 7000/13585 Tiles verarbeitet (5185 erfolgreich)
# 2026-02-09 03:39:11,285 - INFO - 📈 DE-BB: 8000/13585 Tiles verarbeitet (6063 erfolgreich)
# 2026-02-09 03:41:36,491 - INFO - 📈 DE-BB: 9000/13585 Tiles verarbeitet (6928 erfolgreich)
# 2026-02-09 03:43:49,731 - INFO - 📈 DE-BB: 10000/13585 Tiles verarbeitet (7785 erfolgreich)
# 2026-02-09 03:45:56,442 - INFO - 📈 DE-BB: 11000/13585 Tiles verarbeitet (8617 erfolgreich)
# 2026-02-09 03:48:00,281 - INFO - 📈 DE-BB: 12000/13585 Tiles verarbeitet (9395 erfolgreich)
# 2026-02-09 03:50:07,026 - INFO - 📈 DE-BB: 13000/13585 Tiles verarbeitet (10228 erfolgreich)
# 2026-02-09 03:51:20,843 - INFO - ✅ DE-BB: 13585/13585 Tiles abgeschlossen (10718 erfolgreich, 2867 fehlgeschlagen)
# 2026-02-09 03:51:26,939 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BB_latest.parquet
# 2026-02-09 03:51:27,474 - INFO - 🔄 DE-HB: Datei ist 7.0 Tage alt, lade neu
# 2026-02-09 03:51:27,475 - INFO - ▶️ Starte Verarbeitung für DE-HB...
# 2026-02-09 03:51:27,477 - INFO - 📊 DE-HB: 145 Tiles zu verarbeiten
# 2026-02-09 03:52:32,660 - INFO - ✅ DE-HB: 145/145 Tiles abgeschlossen (135 erfolgreich, 10 fehlgeschlagen)
# 2026-02-09 03:52:32,771 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HB_latest.parquet
# 2026-02-09 03:52:32,793 - INFO - 🔄 DE-HH: Datei ist 7.0 Tage alt, lade neu
# 2026-02-09 03:52:32,796 - INFO - ▶️ Starte Verarbeitung für DE-HH...
# 2026-02-09 03:52:32,802 - INFO - 📊 DE-HH: 361 Tiles zu verarbeiten
# 2026-02-09 03:56:02,114 - INFO - ✅ DE-HH: 361/361 Tiles abgeschlossen (359 erfolgreich, 2 fehlgeschlagen)
# 2026-02-09 03:56:02,417 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HH_latest.parquet
# 2026-02-09 03:56:02,473 - INFO - 🔄 DE-HE: Datei ist 7.0 Tage alt, lade neu
# 2026-02-09 03:56:02,475 - INFO - ▶️ Starte Verarbeitung für DE-HE...
# 2026-02-09 03:56:02,507 - INFO - 📊 DE-HE: 8704 Tiles zu verarbeiten
# 2026-02-09 03:58:59,009 - INFO - 📈 DE-HE: 1000/8704 Tiles verarbeitet (805 erfolgreich)
# 2026-02-09 04:02:25,616 - INFO - 📈 DE-HE: 2000/8704 Tiles verarbeitet (1650 erfolgreich)
# 2026-02-09 04:08:35,111 - INFO - 📈 DE-HE: 3000/8704 Tiles verarbeitet (2541 erfolgreich)
# 2026-02-09 04:11:16,696 - INFO - 📈 DE-HE: 4000/8704 Tiles verarbeitet (3344 erfolgreich)
# 2026-02-09 04:13:42,651 - INFO - 📈 DE-HE: 5000/8704 Tiles verarbeitet (4109 erfolgreich)
# 2026-02-09 04:16:05,528 - INFO - 📈 DE-HE: 6000/8704 Tiles verarbeitet (4780 erfolgreich)
# 2026-02-09 04:18:38,260 - INFO - 📈 DE-HE: 7000/8704 Tiles verarbeitet (5448 erfolgreich)
# 2026-02-09 04:21:10,707 - INFO - 📈 DE-HE: 8000/8704 Tiles verarbeitet (6089 erfolgreich)
# 2026-02-09 04:22:44,448 - INFO - ✅ DE-HE: 8704/8704 Tiles abgeschlossen (6639 erfolgreich, 2065 fehlgeschlagen)
# 2026-02-09 04:22:48,631 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HE_latest.parquet
# 2026-02-09 04:22:49,050 - INFO - 🔄 DE-MV: Datei ist 7.0 Tage alt, lade neu
# 2026-02-09 04:22:49,051 - INFO - ▶️ Starte Verarbeitung für DE-MV...
# 2026-02-09 04:22:49,083 - INFO - 📊 DE-MV: 12294 Tiles zu verarbeiten
# 2026-02-09 04:24:53,915 - INFO - 📈 DE-MV: 1000/12294 Tiles verarbeitet (595 erfolgreich)
# 2026-02-09 04:26:48,941 - INFO - 📈 DE-MV: 2000/12294 Tiles verarbeitet (1158 erfolgreich)
# 2026-02-09 04:28:36,128 - INFO - 📈 DE-MV: 3000/12294 Tiles verarbeitet (1674 erfolgreich)
# 2026-02-09 04:30:21,022 - INFO - 📈 DE-MV: 4000/12294 Tiles verarbeitet (2038 erfolgreich)
# 2026-02-09 04:32:11,337 - INFO - 📈 DE-MV: 5000/12294 Tiles verarbeitet (2544 erfolgreich)
# 2026-02-09 04:33:55,779 - INFO - 📈 DE-MV: 6000/12294 Tiles verarbeitet (2979 erfolgreich)
# 2026-02-09 04:35:40,200 - INFO - 📈 DE-MV: 7000/12294 Tiles verarbeitet (3405 erfolgreich)
# 2026-02-09 04:37:20,934 - INFO - 📈 DE-MV: 8000/12294 Tiles verarbeitet (3731 erfolgreich)
# 2026-02-09 04:39:08,635 - INFO - 📈 DE-MV: 9000/12294 Tiles verarbeitet (4124 erfolgreich)
# 2026-02-09 04:40:53,724 - INFO - 📈 DE-MV: 10000/12294 Tiles verarbeitet (4627 erfolgreich)
# 2026-02-09 04:42:31,377 - INFO - 📈 DE-MV: 11000/12294 Tiles verarbeitet (5108 erfolgreich)
# 2026-02-09 04:44:10,823 - INFO - 📈 DE-MV: 12000/12294 Tiles verarbeitet (5610 erfolgreich)
# 2026-02-09 04:44:41,587 - INFO - ✅ DE-MV: 12294/12294 Tiles abgeschlossen (5799 erfolgreich, 6495 fehlgeschlagen)
# 2026-02-09 04:44:44,451 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-MV_latest.parquet
# 2026-02-09 04:44:44,698 - INFO - 🔄 DE-NI: Datei ist 7.0 Tage alt, lade neu
# 2026-02-09 04:44:44,699 - INFO - ▶️ Starte Verarbeitung für DE-NI...
# 2026-02-09 04:44:44,751 - INFO - 📊 DE-NI: 22844 Tiles zu verarbeiten
# 2026-02-09 04:47:15,937 - INFO - 📈 DE-NI: 1000/22844 Tiles verarbeitet (767 erfolgreich)
# 2026-02-09 04:49:17,394 - INFO - 📈 DE-NI: 2000/22844 Tiles verarbeitet (1494 erfolgreich)
# 2026-02-09 04:51:01,971 - INFO - 📈 DE-NI: 3000/22844 Tiles verarbeitet (2102 erfolgreich)
# 2026-02-09 04:52:34,927 - INFO - 📈 DE-NI: 4000/22844 Tiles verarbeitet (2468 erfolgreich)
# 2026-02-09 04:54:13,054 - INFO - 📈 DE-NI: 5000/22844 Tiles verarbeitet (3028 erfolgreich)
# 2026-02-09 04:56:12,464 - INFO - 📈 DE-NI: 6000/22844 Tiles verarbeitet (3711 erfolgreich)
# 2026-02-09 04:58:23,262 - INFO - 📈 DE-NI: 7000/22844 Tiles verarbeitet (4424 erfolgreich)
# 2026-02-09 05:00:13,690 - INFO - 📈 DE-NI: 8000/22844 Tiles verarbeitet (5027 erfolgreich)
# 2026-02-09 05:02:07,856 - INFO - 📈 DE-NI: 9000/22844 Tiles verarbeitet (5661 erfolgreich)
# 2026-02-09 05:03:54,868 - INFO - 📈 DE-NI: 10000/22844 Tiles verarbeitet (6240 erfolgreich)
# 2026-02-09 05:05:43,111 - INFO - 📈 DE-NI: 11000/22844 Tiles verarbeitet (6856 erfolgreich)
# 2026-02-09 05:07:45,575 - INFO - 📈 DE-NI: 12000/22844 Tiles verarbeitet (7575 erfolgreich)
# 2026-02-09 05:09:45,974 - INFO - 📈 DE-NI: 13000/22844 Tiles verarbeitet (8262 erfolgreich)
# 2026-02-09 05:11:51,342 - INFO - 📈 DE-NI: 14000/22844 Tiles verarbeitet (9012 erfolgreich)
# 2026-02-09 05:14:16,017 - INFO - 📈 DE-NI: 15000/22844 Tiles verarbeitet (9797 erfolgreich)
# 2026-02-09 05:17:00,257 - INFO - 📈 DE-NI: 16000/22844 Tiles verarbeitet (10529 erfolgreich)
# 2026-02-09 05:19:51,715 - INFO - 📈 DE-NI: 17000/22844 Tiles verarbeitet (11375 erfolgreich)
# 2026-02-09 05:22:21,714 - INFO - 📈 DE-NI: 18000/22844 Tiles verarbeitet (12146 erfolgreich)
# 2026-02-09 05:24:33,012 - INFO - 📈 DE-NI: 19000/22844 Tiles verarbeitet (12932 erfolgreich)
# 2026-02-09 05:27:33,482 - INFO - 📈 DE-NI: 20000/22844 Tiles verarbeitet (13692 erfolgreich)
# 2026-02-09 05:30:56,835 - INFO - 📈 DE-NI: 21000/22844 Tiles verarbeitet (14545 erfolgreich)
# 2026-02-09 05:33:42,208 - INFO - 📈 DE-NI: 22000/22844 Tiles verarbeitet (15305 erfolgreich)
# 2026-02-09 05:35:28,618 - INFO - ✅ DE-NI: 22844/22844 Tiles abgeschlossen (15941 erfolgreich, 6903 fehlgeschlagen)
# 2026-02-09 05:35:37,590 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-NI_latest.parquet
# 2026-02-09 05:35:38,628 - INFO - 🔄 DE-NW: Datei ist 7.0 Tage alt, lade neu
# 2026-02-09 05:35:38,630 - INFO - ▶️ Starte Verarbeitung für DE-NW...
# 2026-02-09 05:35:38,693 - INFO - 📊 DE-NW: 15243 Tiles zu verarbeiten
# 2026-02-09 05:38:52,982 - INFO - 📈 DE-NW: 1000/15243 Tiles verarbeitet (690 erfolgreich)
# 2026-02-09 05:44:23,083 - INFO - 📈 DE-NW: 2000/15243 Tiles verarbeitet (1661 erfolgreich)
# 2026-02-09 05:47:59,347 - INFO - 📈 DE-NW: 3000/15243 Tiles verarbeitet (2585 erfolgreich)
# 2026-02-09 05:52:32,018 - INFO - 📈 DE-NW: 4000/15243 Tiles verarbeitet (3500 erfolgreich)
# 2026-02-09 05:57:05,629 - INFO - 📈 DE-NW: 5000/15243 Tiles verarbeitet (4410 erfolgreich)
# 2026-02-09 06:01:52,408 - INFO - 📈 DE-NW: 6000/15243 Tiles verarbeitet (5357 erfolgreich)
# 2026-02-09 06:06:26,203 - INFO - 📈 DE-NW: 7000/15243 Tiles verarbeitet (6285 erfolgreich)
# 2026-02-09 06:09:36,080 - INFO - 📈 DE-NW: 8000/15243 Tiles verarbeitet (7182 erfolgreich)
# 2026-02-09 06:12:45,783 - INFO - 📈 DE-NW: 9000/15243 Tiles verarbeitet (8060 erfolgreich)
# 2026-02-09 06:16:24,669 - INFO - 📈 DE-NW: 10000/15243 Tiles verarbeitet (8862 erfolgreich)
# 2026-02-09 06:18:53,987 - INFO - 📈 DE-NW: 11000/15243 Tiles verarbeitet (9627 erfolgreich)
# 2026-02-09 06:20:59,529 - INFO - 📈 DE-NW: 12000/15243 Tiles verarbeitet (10268 erfolgreich)
# 2026-02-09 06:23:51,614 - INFO - 📈 DE-NW: 13000/15243 Tiles verarbeitet (11022 erfolgreich)
# 2026-02-09 06:26:50,865 - INFO - 📈 DE-NW: 14000/15243 Tiles verarbeitet (11842 erfolgreich)
# 2026-02-09 06:30:04,356 - INFO - 📈 DE-NW: 15000/15243 Tiles verarbeitet (12689 erfolgreich)
# 2026-02-09 06:30:28,579 - INFO - ✅ DE-NW: 15243/15243 Tiles abgeschlossen (12862 erfolgreich, 2381 fehlgeschlagen)
# 2026-02-09 06:30:36,883 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-NW_latest.parquet
# 2026-02-09 06:30:37,758 - INFO - 🔄 DE-RP: Datei ist 7.0 Tage alt, lade neu
# 2026-02-09 06:30:37,760 - INFO - ▶️ Starte Verarbeitung für DE-RP...
# 2026-02-09 06:30:37,782 - INFO - 📊 DE-RP: 8240 Tiles zu verarbeiten
# 2026-02-09 06:33:13,834 - INFO - 📈 DE-RP: 1000/8240 Tiles verarbeitet (836 erfolgreich)
# 2026-02-09 06:35:16,608 - INFO - 📈 DE-RP: 2000/8240 Tiles verarbeitet (1756 erfolgreich)
# 2026-02-09 06:37:26,958 - INFO - 📈 DE-RP: 3000/8240 Tiles verarbeitet (2655 erfolgreich)
# 2026-02-09 06:39:50,527 - INFO - 📈 DE-RP: 4000/8240 Tiles verarbeitet (3558 erfolgreich)
# 2026-02-09 06:42:18,206 - INFO - 📈 DE-RP: 5000/8240 Tiles verarbeitet (4420 erfolgreich)
# 2026-02-09 06:44:39,099 - INFO - 📈 DE-RP: 6000/8240 Tiles verarbeitet (5222 erfolgreich)
# 2026-02-09 06:46:56,072 - INFO - 📈 DE-RP: 7000/8240 Tiles verarbeitet (6031 erfolgreich)
# 2026-02-09 06:49:41,913 - INFO - 📈 DE-RP: 8000/8240 Tiles verarbeitet (6933 erfolgreich)
# 2026-02-09 06:50:34,773 - INFO - ✅ DE-RP: 8240/8240 Tiles abgeschlossen (7155 erfolgreich, 1085 fehlgeschlagen)
# 2026-02-09 06:50:39,032 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-RP_latest.parquet
# 2026-02-09 06:50:39,414 - INFO - 🔄 DE-SL: Datei ist 7.0 Tage alt, lade neu
# 2026-02-09 06:50:39,416 - INFO - ▶️ Starte Verarbeitung für DE-SL...
# 2026-02-09 06:50:39,426 - INFO - 📊 DE-SL: 1170 Tiles zu verarbeiten
# 2026-02-09 06:53:32,575 - INFO - 📈 DE-SL: 1000/1170 Tiles verarbeitet (883 erfolgreich)
# 2026-02-09 06:54:15,330 - INFO - ✅ DE-SL: 1170/1170 Tiles abgeschlossen (1035 erfolgreich, 135 fehlgeschlagen)
# 2026-02-09 06:54:15,940 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SL_latest.parquet
# 2026-02-09 06:54:16,007 - INFO - 🔄 DE-ST: Datei ist 7.0 Tage alt, lade neu
# 2026-02-09 06:54:16,009 - INFO - ▶️ Starte Verarbeitung für DE-ST...
# 2026-02-09 06:54:16,049 - INFO - 📊 DE-ST: 9077 Tiles zu verarbeiten
# 2026-02-09 06:55:57,508 - INFO - 📈 DE-ST: 1000/9077 Tiles verarbeitet (587 erfolgreich)
# 2026-02-09 06:57:39,092 - INFO - 📈 DE-ST: 2000/9077 Tiles verarbeitet (1224 erfolgreich)
# 2026-02-09 06:59:19,313 - INFO - 📈 DE-ST: 3000/9077 Tiles verarbeitet (1772 erfolgreich)
# 2026-02-09 07:01:02,444 - INFO - 📈 DE-ST: 4000/9077 Tiles verarbeitet (2315 erfolgreich)
# 2026-02-09 07:02:54,128 - INFO - 📈 DE-ST: 5000/9077 Tiles verarbeitet (2925 erfolgreich)
# 2026-02-09 07:04:55,380 - INFO - 📈 DE-ST: 6000/9077 Tiles verarbeitet (3613 erfolgreich)
# 2026-02-09 07:07:42,297 - INFO - 📈 DE-ST: 7000/9077 Tiles verarbeitet (4306 erfolgreich)
# 2026-02-09 07:10:03,813 - INFO - 📈 DE-ST: 8000/9077 Tiles verarbeitet (4913 erfolgreich)
# 2026-02-09 07:12:04,155 - INFO - 📈 DE-ST: 9000/9077 Tiles verarbeitet (5666 erfolgreich)
# 2026-02-09 07:12:12,256 - INFO - ✅ DE-ST: 9077/9077 Tiles abgeschlossen (5717 erfolgreich, 3360 fehlgeschlagen)
# 2026-02-09 07:12:15,776 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-ST_latest.parquet
# 2026-02-09 07:12:16,120 - INFO - 🔄 DE-SN: Datei ist 7.0 Tage alt, lade neu
# 2026-02-09 07:12:16,123 - INFO - ▶️ Starte Verarbeitung für DE-SN...
# 2026-02-09 07:12:16,158 - INFO - 📊 DE-SN: 8311 Tiles zu verarbeiten
# 2026-02-09 07:15:09,801 - INFO - 📈 DE-SN: 1000/8311 Tiles verarbeitet (801 erfolgreich)
# 2026-02-09 07:18:50,780 - INFO - 📈 DE-SN: 2000/8311 Tiles verarbeitet (1634 erfolgreich)
# 2026-02-09 07:21:09,084 - INFO - 📈 DE-SN: 3000/8311 Tiles verarbeitet (2420 erfolgreich)
# 2026-02-09 07:23:14,688 - INFO - 📈 DE-SN: 4000/8311 Tiles verarbeitet (3192 erfolgreich)
# 2026-02-09 07:25:01,073 - INFO - 📈 DE-SN: 5000/8311 Tiles verarbeitet (3951 erfolgreich)
# 2026-02-09 07:27:27,396 - INFO - 📈 DE-SN: 6000/8311 Tiles verarbeitet (4755 erfolgreich)
# 2026-02-09 07:29:10,689 - INFO - 📈 DE-SN: 7000/8311 Tiles verarbeitet (5486 erfolgreich)
# 2026-02-09 07:31:10,146 - INFO - 📈 DE-SN: 8000/8311 Tiles verarbeitet (6228 erfolgreich)
# 2026-02-09 07:32:07,595 - INFO - ✅ DE-SN: 8311/8311 Tiles abgeschlossen (6455 erfolgreich, 1856 fehlgeschlagen)
# 2026-02-09 07:32:11,581 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SN_latest.parquet
# 2026-02-09 07:32:11,953 - INFO - 🔄 DE-SH: Datei ist 7.0 Tage alt, lade neu
# 2026-02-09 07:32:11,955 - INFO - ▶️ Starte Verarbeitung für DE-SH...
# 2026-02-09 07:32:11,995 - INFO - 📊 DE-SH: 9101 Tiles zu verarbeiten
# 2026-02-09 07:34:08,519 - INFO - 📈 DE-SH: 1000/9101 Tiles verarbeitet (546 erfolgreich)
# 2026-02-09 07:35:42,184 - INFO - 📈 DE-SH: 2000/9101 Tiles verarbeitet (1065 erfolgreich)
# 2026-02-09 07:37:22,784 - INFO - 📈 DE-SH: 3000/9101 Tiles verarbeitet (1735 erfolgreich)
# 2026-02-09 07:39:16,483 - INFO - 📈 DE-SH: 4000/9101 Tiles verarbeitet (2354 erfolgreich)
# 2026-02-09 07:41:02,586 - INFO - 📈 DE-SH: 5000/9101 Tiles verarbeitet (2924 erfolgreich)
# 2026-02-09 07:43:19,322 - INFO - 📈 DE-SH: 6000/9101 Tiles verarbeitet (3554 erfolgreich)
# 2026-02-09 07:45:11,624 - INFO - 📈 DE-SH: 7000/9101 Tiles verarbeitet (4210 erfolgreich)
# 2026-02-09 07:47:14,811 - INFO - 📈 DE-SH: 8000/9101 Tiles verarbeitet (4991 erfolgreich)
# 2026-02-09 07:50:01,114 - INFO - 📈 DE-SH: 9000/9101 Tiles verarbeitet (5777 erfolgreich)
# 2026-02-09 07:50:11,704 - INFO - ✅ DE-SH: 9101/9101 Tiles abgeschlossen (5831 erfolgreich, 3270 fehlgeschlagen)
# 2026-02-09 07:50:15,382 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SH_latest.parquet
# 2026-02-09 07:50:15,683 - INFO - 🔄 DE-TH: Datei ist 7.0 Tage alt, lade neu
# 2026-02-09 07:50:15,686 - INFO - ▶️ Starte Verarbeitung für DE-TH...
# 2026-02-09 07:50:15,722 - INFO - 📊 DE-TH: 6819 Tiles zu verarbeiten
# 2026-02-09 07:51:59,107 - INFO - 📈 DE-TH: 1000/6819 Tiles verarbeitet (628 erfolgreich)
# 2026-02-09 07:54:09,677 - INFO - 📈 DE-TH: 2000/6819 Tiles verarbeitet (1363 erfolgreich)
# 2026-02-09 07:56:16,238 - INFO - 📈 DE-TH: 3000/6819 Tiles verarbeitet (2064 erfolgreich)
# 2026-02-09 07:58:04,189 - INFO - 📈 DE-TH: 4000/6819 Tiles verarbeitet (2692 erfolgreich)
# 2026-02-09 07:59:50,952 - INFO - 📈 DE-TH: 5000/6819 Tiles verarbeitet (3383 erfolgreich)
# 2026-02-09 08:02:35,289 - INFO - 📈 DE-TH: 6000/6819 Tiles verarbeitet (4217 erfolgreich)
# 2026-02-09 08:04:29,122 - INFO - ✅ DE-TH: 6819/6819 Tiles abgeschlossen (4785 erfolgreich, 2034 fehlgeschlagen)
# 2026-02-09 08:04:31,947 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-TH_latest.parquet
# 2026-02-09 08:04:32,195 - INFO -
# 📅 Ältester Mapillary-Timestamp: 2026-02-09T01:47:55.751355+00:00
# 2026-02-09 08:04:32,196 - INFO - 💾 Metadata gespeichert: output/ml_metadata.json
# 2026-02-09 08:04:32,197 - INFO - 📄 Log-Datei: ml_output/mapillary_download_20260209_010655.log
# 2026-02-09 08:04:32,199 - INFO - === Mapillary Coverage Download abgeschlossen ===
