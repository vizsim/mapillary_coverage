# %% [markdown]
# # Was tut dieses Skript?
# Dieses Skript lädt die Mapillay coverage je Bundesland je Tiles herunter,
# filtert sie nach Aufnahmedatum,
# und exportiert die Ergebnisse als Parquet-Dateien.

# %%
# Standard library
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime, timezone
import json
import os
import time
import logging
import sys

# Third-party
import geopandas as gpd
import mercantile
import pandas as pd
import requests
from requests.exceptions import SSLError
from tqdm import tqdm
from vt2geojson.tools import vt_bytes_to_geojson


from config import TILES_CONFIG, PROCESSING_CONFIG, MAPILLARY_CONFIG

# Setup Logging
log_folder = PROCESSING_CONFIG["ml_output_folder"]
os.makedirs(log_folder, exist_ok=True)
log_file = os.path.join(log_folder, f"mapillary_download_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log")

# Konfiguriere Logger
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file, encoding='utf-8'),
        logging.StreamHandler(sys.stdout)  # Auch in Console ausgeben
    ]
)

logger = logging.getLogger(__name__)
logger.info(f"=== Mapillary Coverage Download gestartet ===")
logger.info(f"Log-Datei: {log_file}")
# Out:
# 2026-01-01 15:10:49,882 - INFO - === Mapillary Coverage Download gestartet ===
# 2026-01-01 15:10:49,884 - INFO - Log-Datei: ml_output/mapillary_download_20260101_151049.log

# %%
TQDM_ENABLED = os.environ.get("TQDM_DISABLE", "0") != "1"

# %%
### Helper function for loading tile lists

def load_tiles_from_json(bundesland_id, input_folder = TILES_CONFIG["cache_folder"]):
    path = os.path.join(input_folder, f"{bundesland_id}_tiles.json")
    with open(path, "r") as f:
        tile_list = json.load(f)
    return [mercantile.Tile(**t) for t in tile_list]

# %%
def export_geodata(gdfs, output_folder = PROCESSING_CONFIG["output_folder"], base_name="mapillary_coverage", region="ger", save_parquet=True, save_geojson_gz=True):
    """
    Export one or more GeoDataFrames into output files (.parquet only, ohne Datum im Namen).
    
    Args:
        gdfs (list or GeoDataFrame): List of GeoDataFrames or a single GeoDataFrame.
        output_folder (str): Output directory (created if it doesn't exist).
        base_name (str): Base filename prefix.
        region (str): Region tag for filename.
        save_parquet (bool): Save .parquet file.
        save_geojson_gz (bool): Save .geojson.gz file (not implemented).
    
    Returns:
        str: Timestamp when data was processed (ISO format)
    """
    if gdfs is None or (isinstance(gdfs, (gpd.GeoDataFrame, pd.DataFrame)) and gdfs.empty):
        logger.warning("No data to export.")
        return None

    # Concatenate if needed
    if isinstance(gdfs, list):
        gdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))
    else:
        gdf = gdfs

    os.makedirs(output_folder, exist_ok=True)
    
    # Aktueller Zeitstempel für Metadata
    current_timestamp = datetime.now(timezone.utc).isoformat()

    if save_parquet:
        # Dateiname OHNE Datum - nur "latest"
        parquet_path = os.path.join(output_folder, f"{base_name}_{region}_latest.parquet")
        gdf.to_parquet(parquet_path, index=False)
        logger.info(f"✔ Parquet saved to: {parquet_path}")
    
    return current_timestamp

# %%
def process_bundesland(bundesland_id, region_name=None, input_folder = TILES_CONFIG["cache_folder"], output_folder = PROCESSING_CONFIG["ml_output_folder"] , max_workers=3, limit_tiles=None):
    logger.info(f"▶️ Starte Verarbeitung für {bundesland_id}...")

    tiles = load_tiles_from_json(bundesland_id, input_folder=input_folder)
    if limit_tiles:
        tiles = tiles[:limit_tiles]
    
    total_tiles = len(tiles)
    logger.info(f"📊 {bundesland_id}: {total_tiles} Tiles zu verarbeiten")
    
    # genereal config
    # Load your access token
    ACCESS_TOKEN = MAPILLARY_CONFIG["access_token"]

    # Use existing variables
    tile_layer = "sequence"  # or 'image' for points
    tile_coverage = "mly1_computed_public"
    
    # Tracking für aufeinanderfolgende Fehler
    consecutive_parse_errors = 0
    MAX_CONSECUTIVE_ERRORS = 5
    
    # Tracking für Fortschritt
    processed_count = 0
    successful_count = 0

    def process_tile(tile, retry_count=0, max_retries=3):
        """
        Verarbeite ein Tile mit Retry-Logik bei Parsing-Fehlern.
        
        Args:
            tile: Mercantile Tile Objekt
            retry_count: Aktueller Retry-Versuch
            max_retries: Maximale Anzahl an Versuchen
        """
        nonlocal consecutive_parse_errors
        
        url = f"https://tiles.mapillary.com/maps/vtp/{tile_coverage}/2/{tile.z}/{tile.x}/{tile.y}?access_token={ACCESS_TOKEN}"
        
        try:
            response = requests.get(url, timeout=30)
            
            # Rate Limit Check
            if response.status_code == 429:
                logger.warning(f"⚠️ Rate Limit erreicht bei Tile {tile.x}/{tile.y}. Pausiere für 5 Minuten...")
                time.sleep(300)
                if retry_count < max_retries:
                    return process_tile(tile, retry_count + 1, max_retries)
                return None
            
            if response.status_code != 200:
                logger.warning(f"⚠️ HTTP {response.status_code} bei Tile {tile.x}/{tile.y}")
                return None
            
            # Versuche Vector Tile zu parsen
            geojson = vt_bytes_to_geojson(response.content, tile.x, tile.y, tile.z, layer=tile_layer)
            features = geojson.get("features", [])
            
            if not features:
                return None
            
            gdf_tile = gpd.GeoDataFrame.from_features(features, crs="EPSG:4326")
            gdf_tile['captured_at'] = gdf_tile['captured_at'].apply(lambda x: datetime.fromtimestamp(x / 1000, tz=timezone.utc))
            
            # Timefilter
            min_date_str = PROCESSING_CONFIG["min_capture_date"]
            min_dt = datetime.strptime(min_date_str, "%Y-%m-%d").replace(tzinfo=timezone.utc)
            gdf_tile = gdf_tile[gdf_tile['captured_at'] >= min_dt]
            gdf_tile['captured_at'] = gdf_tile['captured_at'].dt.strftime('%Y-%m-%d')

            gdf_tile['tile_x'] = tile.x
            gdf_tile['tile_y'] = tile.y
            
            # Erfolg → Fehler-Counter zurücksetzen
            consecutive_parse_errors = 0
            return gdf_tile
            
        except Exception as e:
            error_msg = str(e)
            
            # Prüfe ob es ein Parsing-Fehler ist (wahrscheinlich Rate Limit)
            if "Error parsing message" in error_msg or "vector_tile" in error_msg:
                consecutive_parse_errors += 1
                
                # Prüfe ob zu viele aufeinanderfolgende Fehler
                if consecutive_parse_errors >= MAX_CONSECUTIVE_ERRORS:
                    logger.error(f"🛑 {MAX_CONSECUTIVE_ERRORS} aufeinanderfolgende Parsing-Fehler! API scheint blockiert zu sein.")
                    logger.warning(f"⏸️  LANGE PAUSE: 30 Minuten warten...")
                    time.sleep(1800)  # 30 Minuten
                    consecutive_parse_errors = 0  # Counter zurücksetzen
                    logger.info(f"▶️ Setze Verarbeitung fort nach langer Pause...")
                
                if retry_count < max_retries:
                    logger.warning(f"⚠️ Parsing-Fehler bei Tile {tile.x}/{tile.y} (Versuch {retry_count + 1}/{max_retries}, konsekutiv: {consecutive_parse_errors}). Pausiere für 5 Minuten...")
                    time.sleep(300)  # 5 Minuten Pause
                    return process_tile(tile, retry_count + 1, max_retries)
                else:
                    logger.error(f"❌ Tile {tile.x}/{tile.y} nach {max_retries} Versuchen fehlgeschlagen: {error_msg}")
                    return None
            else:
                logger.error(f"❌ Fehler bei Tile {tile.x}/{tile.y}: {error_msg}")
                return None

    gdf_all = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(process_tile, tile): tile for tile in tiles}
        for future in tqdm(as_completed(futures), total=len(futures), desc=f"🧩 {bundesland_id}", disable=not TQDM_ENABLED):
            try:
                result = future.result()
                processed_count += 1
                
                if result is not None:
                    gdf_all.append(result)
                    successful_count += 1
                
                # Progress-Logging alle 1000 Tiles (nur wenn >= 1000 Tiles total)
                if total_tiles >= 1000 and processed_count % 1000 == 0:
                    logger.info(f"📈 {bundesland_id}: {processed_count}/{total_tiles} Tiles verarbeitet ({successful_count} erfolgreich)")
                    
            except SSLError as e:
                logger.warning(f"⚠️ SSLError: {e}. Pausiere für 5 Minuten...")
                time.sleep(300)
            except Exception as e:
                logger.error(f"⚠️ Unbekannter Fehler: {e}")
    
    # Final Summary
    logger.info(f"✅ {bundesland_id}: {processed_count}/{total_tiles} Tiles abgeschlossen ({successful_count} erfolgreich, {processed_count - successful_count} fehlgeschlagen)")

    if gdf_all:
        gdf_all = gpd.GeoDataFrame(pd.concat(gdf_all, ignore_index=True))
        timestamp = export_geodata(
            gdfs=gdf_all,
            output_folder=output_folder,
            region=bundesland_id,
            save_parquet=True,
            save_geojson_gz=False
        )
        return timestamp
    else:
        logger.warning(f"⚠️ Keine Daten für {bundesland_id}.")
        return None

# %%
# Verarbeitung der Bundesländer basierend auf config.py
# takes about ~6.5h for all 16 bundesländer (on lokal machine)

# Lade Bundesländer aus Cache (wurde in Notebook 0 heruntergeladen)
bundesland_cache_path = os.path.join("prep", "bundeslaender.geojson")

if not os.path.exists(bundesland_cache_path):
    logger.error(f"❌ Bundesland-Cache nicht gefunden: {bundesland_cache_path}")
    logger.error(f"   Bitte zuerst Notebook 0_prepare_tiles.ipynb ausführen!")
    raise FileNotFoundError(f"Bundesland-GeoJSON fehlt: {bundesland_cache_path}")

logger.info(f"📂 Lade Bundesländer aus: {bundesland_cache_path}")
bland = gpd.read_file(bundesland_cache_path)

# Filter Bundesländer basierend auf config.py
from config import GEOFABRIK_CONFIG

selected_bundeslaender = GEOFABRIK_CONFIG.get("bundeslaender")
if selected_bundeslaender:
    # Nur die ausgewählten Bundesländer verarbeiten
    bland_filtered = bland[bland['id'].isin(selected_bundeslaender)]
    logger.info(f"🎯 Verarbeite {len(bland_filtered)} ausgewählte Bundesländer: {', '.join(selected_bundeslaender)}")
else:
    # Alle Bundesländer verarbeiten
    bland_filtered = bland
    logger.info(f"📍 Verarbeite alle {len(bland_filtered)} Bundesländer")

# Sammle Timestamps für Metadata
ml_timestamps = {}

for _, row in bland_filtered.iterrows():
    b_id = row["id"]
    name = row["name"]

    # Nur verarbeiten, wenn eine JSON-Datei existiert
    tile_json_path = os.path.join(TILES_CONFIG["cache_folder"], f"{b_id}_tiles.json")
    if not os.path.exists(tile_json_path):
        logger.warning(f"⏩ Überspringe {b_id}, keine Tiles gefunden.")
        continue

    # Prüfe ob Parquet bereits existiert und noch aktuell ist
    output_folder = PROCESSING_CONFIG["ml_output_folder"]
    parquet_path = os.path.join(output_folder, f"mapillary_coverage_{b_id}_latest.parquet")
    max_age_days = PROCESSING_CONFIG.get('max_file_age_days', 4)
    
    if os.path.exists(parquet_path):
        file_mtime = os.path.getmtime(parquet_path)
        file_age_days = (datetime.now().timestamp() - file_mtime) / 86400  # Sekunden in Tage
        
        if file_age_days < max_age_days:
            logger.info(f"⏩ {b_id}: Datei ist {file_age_days:.1f} Tage alt, überspringe Download")
            # Timestamp aus existierender Datei für Metadata verwenden
            ml_timestamps[b_id] = datetime.fromtimestamp(file_mtime, tz=timezone.utc).isoformat()
            continue
        else:
            logger.info(f"🔄 {b_id}: Datei ist {file_age_days:.1f} Tage alt, lade neu")

    timestamp = process_bundesland(b_id, region_name=name)
    if timestamp:
        ml_timestamps[b_id] = timestamp

# Speichere Metadata ähnlich wie osm_metadata.json
if ml_timestamps:
    # Finde ältesten Timestamp
    oldest_ml_timestamp = min(ml_timestamps.values())
    
    metadata = {
        "ml_data_from": oldest_ml_timestamp,
        "bundeslaender": ml_timestamps,
        "processed_date": datetime.now(timezone.utc).isoformat()
    }
    
    with open("output/ml_metadata.json", "w", encoding="utf-8") as f:
        json.dump(metadata, f, ensure_ascii=False, indent=2)
    
    logger.info(f"\n📅 Ältester Mapillary-Timestamp: {oldest_ml_timestamp}")
    logger.info(f"💾 Metadata gespeichert: output/ml_metadata.json")
    logger.info(f"📄 Log-Datei: {log_file}")
else:
    logger.warning("\n⚠️  Keine Mapillary-Daten verarbeitet, keine Metadata erstellt.")

logger.info("=== Mapillary Coverage Download abgeschlossen ===")
# Out:
# 2026-01-01 15:10:49,969 - INFO - 📂 Lade Bundesländer aus: prep/bundeslaender.geojson
# 2026-01-01 15:10:50,582 - INFO - 📍 Verarbeite alle 16 Bundesländer
# 2026-01-01 15:10:50,585 - INFO - 🔄 DE-BW: Datei ist 17.2 Tage alt, lade neu
# 2026-01-01 15:10:50,588 - INFO - ▶️ Starte Verarbeitung für DE-BW...
# 2026-01-01 15:10:50,648 - INFO - 📊 DE-BW: 14160 Tiles zu verarbeiten
# 2026-01-01 15:13:41,008 - INFO - 📈 DE-BW: 1000/14160 Tiles verarbeitet (831 erfolgreich)
# 2026-01-01 15:15:59,669 - INFO - 📈 DE-BW: 2000/14160 Tiles verarbeitet (1579 erfolgreich)
# 2026-01-01 15:18:05,736 - INFO - 📈 DE-BW: 3000/14160 Tiles verarbeitet (2364 erfolgreich)
# 2026-01-01 15:20:58,294 - INFO - 📈 DE-BW: 4000/14160 Tiles verarbeitet (3213 erfolgreich)
# 2026-01-01 15:24:41,666 - INFO - 📈 DE-BW: 5000/14160 Tiles verarbeitet (4053 erfolgreich)
# 2026-01-01 15:27:13,775 - INFO - 📈 DE-BW: 6000/14160 Tiles verarbeitet (4888 erfolgreich)
# 2026-01-01 15:30:21,844 - INFO - 📈 DE-BW: 7000/14160 Tiles verarbeitet (5758 erfolgreich)
# 2026-01-01 15:35:08,060 - INFO - 📈 DE-BW: 8000/14160 Tiles verarbeitet (6657 erfolgreich)
# 2026-01-01 15:38:22,184 - INFO - 📈 DE-BW: 9000/14160 Tiles verarbeitet (7534 erfolgreich)
# 2026-01-01 15:40:44,903 - INFO - 📈 DE-BW: 10000/14160 Tiles verarbeitet (8363 erfolgreich)
# 2026-01-01 15:42:48,142 - INFO - 📈 DE-BW: 11000/14160 Tiles verarbeitet (9153 erfolgreich)
# 2026-01-01 15:45:01,823 - INFO - 📈 DE-BW: 12000/14160 Tiles verarbeitet (9955 erfolgreich)
# 2026-01-01 15:47:21,347 - INFO - 📈 DE-BW: 13000/14160 Tiles verarbeitet (10766 erfolgreich)
# 2026-01-01 15:49:38,018 - INFO - 📈 DE-BW: 14000/14160 Tiles verarbeitet (11531 erfolgreich)
# 2026-01-01 15:49:55,148 - INFO - ✅ DE-BW: 14160/14160 Tiles abgeschlossen (11634 erfolgreich, 2526 fehlgeschlagen)
# 2026-01-01 15:50:02,671 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BW_latest.parquet
# 2026-01-01 15:50:03,471 - INFO - 🔄 DE-BY: Datei ist 17.2 Tage alt, lade neu
# 2026-01-01 15:50:03,472 - INFO - ▶️ Starte Verarbeitung für DE-BY...
# 2026-01-01 15:50:03,545 - INFO - 📊 DE-BY: 28376 Tiles zu verarbeiten
# 2026-01-01 15:52:26,606 - INFO - 📈 DE-BY: 1000/28376 Tiles verarbeitet (789 erfolgreich)
# 2026-01-01 15:54:47,761 - INFO - 📈 DE-BY: 2000/28376 Tiles verarbeitet (1522 erfolgreich)
# 2026-01-01 15:57:46,890 - INFO - 📈 DE-BY: 3000/28376 Tiles verarbeitet (2268 erfolgreich)
# 2026-01-01 15:59:52,760 - INFO - 📈 DE-BY: 4000/28376 Tiles verarbeitet (2982 erfolgreich)
# 2026-01-01 16:01:41,060 - INFO - 📈 DE-BY: 5000/28376 Tiles verarbeitet (3613 erfolgreich)
# 2026-01-01 16:03:23,338 - INFO - 📈 DE-BY: 6000/28376 Tiles verarbeitet (4216 erfolgreich)
# 2026-01-01 16:05:18,035 - INFO - 📈 DE-BY: 7000/28376 Tiles verarbeitet (4974 erfolgreich)
# 2026-01-01 16:06:34,203 - ERROR - ❌ Fehler bei Tile 8679/5690: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2026-01-01 16:07:25,637 - INFO - 📈 DE-BY: 8000/28376 Tiles verarbeitet (5662 erfolgreich)
# 2026-01-01 16:10:21,311 - INFO - 📈 DE-BY: 9000/28376 Tiles verarbeitet (6368 erfolgreich)
# 2026-01-01 16:15:43,118 - INFO - 📈 DE-BY: 10000/28376 Tiles verarbeitet (7075 erfolgreich)
# 2026-01-01 16:20:35,301 - INFO - 📈 DE-BY: 11000/28376 Tiles verarbeitet (7717 erfolgreich)
# 2026-01-01 16:22:49,868 - INFO - 📈 DE-BY: 12000/28376 Tiles verarbeitet (8408 erfolgreich)
# 2026-01-01 16:24:53,178 - INFO - 📈 DE-BY: 13000/28376 Tiles verarbeitet (9079 erfolgreich)
# 2026-01-01 16:26:58,419 - INFO - 📈 DE-BY: 14000/28376 Tiles verarbeitet (9760 erfolgreich)
# 2026-01-01 16:29:21,173 - INFO - 📈 DE-BY: 15000/28376 Tiles verarbeitet (10392 erfolgreich)
# 2026-01-01 16:32:25,707 - INFO - 📈 DE-BY: 16000/28376 Tiles verarbeitet (11038 erfolgreich)
# 2026-01-01 16:35:19,498 - INFO - 📈 DE-BY: 17000/28376 Tiles verarbeitet (11628 erfolgreich)
# 2026-01-01 16:37:43,596 - INFO - 📈 DE-BY: 18000/28376 Tiles verarbeitet (12217 erfolgreich)
# 2026-01-01 16:39:43,328 - INFO - 📈 DE-BY: 19000/28376 Tiles verarbeitet (12830 erfolgreich)
# 2026-01-01 16:41:56,255 - INFO - 📈 DE-BY: 20000/28376 Tiles verarbeitet (13464 erfolgreich)
# 2026-01-01 16:44:55,116 - INFO - 📈 DE-BY: 21000/28376 Tiles verarbeitet (14202 erfolgreich)
# 2026-01-01 16:47:27,649 - INFO - 📈 DE-BY: 22000/28376 Tiles verarbeitet (14939 erfolgreich)
# 2026-01-01 16:50:10,319 - INFO - 📈 DE-BY: 23000/28376 Tiles verarbeitet (15606 erfolgreich)
# 2026-01-01 16:53:42,454 - INFO - 📈 DE-BY: 24000/28376 Tiles verarbeitet (16183 erfolgreich)
# 2026-01-01 17:00:23,444 - INFO - 📈 DE-BY: 25000/28376 Tiles verarbeitet (16799 erfolgreich)
# 2026-01-01 17:03:19,044 - INFO - 📈 DE-BY: 26000/28376 Tiles verarbeitet (17412 erfolgreich)
# 2026-01-01 17:05:35,307 - INFO - 📈 DE-BY: 27000/28376 Tiles verarbeitet (18026 erfolgreich)
# 2026-01-01 17:07:20,586 - INFO - 📈 DE-BY: 28000/28376 Tiles verarbeitet (18540 erfolgreich)
# 2026-01-01 17:07:53,787 - INFO - ✅ DE-BY: 28376/28376 Tiles abgeschlossen (18695 erfolgreich, 9681 fehlgeschlagen)
# 2026-01-01 17:08:06,967 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BY_latest.parquet
# 2026-01-01 17:08:08,611 - INFO - 🔄 DE-BE: Datei ist 17.3 Tage alt, lade neu
# 2026-01-01 17:08:08,613 - INFO - ▶️ Starte Verarbeitung für DE-BE...
# 2026-01-01 17:08:08,618 - INFO - 📊 DE-BE: 399 Tiles zu verarbeiten
# 2026-01-01 17:17:32,035 - INFO - ✅ DE-BE: 399/399 Tiles abgeschlossen (398 erfolgreich, 1 fehlgeschlagen)
# 2026-01-01 17:17:32,657 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BE_latest.parquet
# 2026-01-01 17:17:32,804 - INFO - 🔄 DE-BB: Datei ist 17.2 Tage alt, lade neu
# 2026-01-01 17:17:32,806 - INFO - ▶️ Starte Verarbeitung für DE-BB...
# 2026-01-01 17:17:32,856 - INFO - 📊 DE-BB: 13585 Tiles zu verarbeiten
# 2026-01-01 17:19:56,666 - INFO - 📈 DE-BB: 1000/13585 Tiles verarbeitet (636 erfolgreich)
# 2026-01-01 17:21:33,677 - INFO - 📈 DE-BB: 2000/13585 Tiles verarbeitet (1286 erfolgreich)
# 2026-01-01 17:23:17,143 - INFO - 📈 DE-BB: 3000/13585 Tiles verarbeitet (1917 erfolgreich)
# 2026-01-01 17:25:17,044 - INFO - 📈 DE-BB: 4000/13585 Tiles verarbeitet (2656 erfolgreich)
# 2026-01-01 17:27:40,659 - INFO - 📈 DE-BB: 5000/13585 Tiles verarbeitet (3461 erfolgreich)
# 2026-01-01 17:30:09,202 - INFO - 📈 DE-BB: 6000/13585 Tiles verarbeitet (4323 erfolgreich)
# 2026-01-01 17:32:45,807 - INFO - 📈 DE-BB: 7000/13585 Tiles verarbeitet (5185 erfolgreich)
# 2026-01-01 17:35:21,007 - INFO - 📈 DE-BB: 8000/13585 Tiles verarbeitet (6063 erfolgreich)
# 2026-01-01 17:37:36,160 - INFO - 📈 DE-BB: 9000/13585 Tiles verarbeitet (6928 erfolgreich)
# 2026-01-01 17:39:34,988 - INFO - 📈 DE-BB: 10000/13585 Tiles verarbeitet (7784 erfolgreich)
# 2026-01-01 17:41:27,048 - INFO - 📈 DE-BB: 11000/13585 Tiles verarbeitet (8617 erfolgreich)
# 2026-01-01 17:43:21,086 - INFO - 📈 DE-BB: 12000/13585 Tiles verarbeitet (9392 erfolgreich)
# 2026-01-01 17:45:15,859 - INFO - 📈 DE-BB: 13000/13585 Tiles verarbeitet (10224 erfolgreich)
# 2026-01-01 17:46:20,235 - INFO - ✅ DE-BB: 13585/13585 Tiles abgeschlossen (10714 erfolgreich, 2871 fehlgeschlagen)
# 2026-01-01 17:46:26,437 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BB_latest.parquet
# 2026-01-01 17:46:27,013 - INFO - 🔄 DE-HB: Datei ist 17.3 Tage alt, lade neu
# 2026-01-01 17:46:27,014 - INFO - ▶️ Starte Verarbeitung für DE-HB...
# 2026-01-01 17:46:27,017 - INFO - 📊 DE-HB: 145 Tiles zu verarbeiten
# 2026-01-01 17:47:35,794 - INFO - ✅ DE-HB: 145/145 Tiles abgeschlossen (135 erfolgreich, 10 fehlgeschlagen)
# 2026-01-01 17:47:35,909 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HB_latest.parquet
# 2026-01-01 17:47:35,933 - INFO - 🔄 DE-HH: Datei ist 17.3 Tage alt, lade neu
# 2026-01-01 17:47:35,935 - INFO - ▶️ Starte Verarbeitung für DE-HH...
# 2026-01-01 17:47:35,939 - INFO - 📊 DE-HH: 361 Tiles zu verarbeiten
# 2026-01-01 17:51:08,156 - INFO - ✅ DE-HH: 361/361 Tiles abgeschlossen (359 erfolgreich, 2 fehlgeschlagen)
# 2026-01-01 17:51:08,654 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HH_latest.parquet
# 2026-01-01 17:51:08,715 - INFO - 🔄 DE-HE: Datei ist 17.3 Tage alt, lade neu
# 2026-01-01 17:51:08,719 - INFO - ▶️ Starte Verarbeitung für DE-HE...
# 2026-01-01 17:51:08,747 - INFO - 📊 DE-HE: 8704 Tiles zu verarbeiten
# 2026-01-01 17:53:55,251 - INFO - 📈 DE-HE: 1000/8704 Tiles verarbeitet (805 erfolgreich)
# 2026-01-01 17:57:15,304 - INFO - 📈 DE-HE: 2000/8704 Tiles verarbeitet (1650 erfolgreich)
# 2026-01-01 18:03:31,215 - INFO - 📈 DE-HE: 3000/8704 Tiles verarbeitet (2541 erfolgreich)
# 2026-01-01 18:06:03,459 - INFO - 📈 DE-HE: 4000/8704 Tiles verarbeitet (3344 erfolgreich)
# 2026-01-01 18:08:26,925 - INFO - 📈 DE-HE: 5000/8704 Tiles verarbeitet (4107 erfolgreich)
# 2026-01-01 18:10:39,651 - INFO - 📈 DE-HE: 6000/8704 Tiles verarbeitet (4779 erfolgreich)
# 2026-01-01 18:13:11,406 - INFO - 📈 DE-HE: 7000/8704 Tiles verarbeitet (5445 erfolgreich)
# 2026-01-01 18:15:46,492 - INFO - 📈 DE-HE: 8000/8704 Tiles verarbeitet (6086 erfolgreich)
# 2026-01-01 18:17:20,610 - INFO - ✅ DE-HE: 8704/8704 Tiles abgeschlossen (6636 erfolgreich, 2068 fehlgeschlagen)
# 2026-01-01 18:17:25,618 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HE_latest.parquet
# 2026-01-01 18:17:26,038 - INFO - 🔄 DE-MV: Datei ist 17.3 Tage alt, lade neu
# 2026-01-01 18:17:26,039 - INFO - ▶️ Starte Verarbeitung für DE-MV...
# 2026-01-01 18:17:26,077 - INFO - 📊 DE-MV: 12294 Tiles zu verarbeiten
# 2026-01-01 18:19:29,476 - INFO - 📈 DE-MV: 1000/12294 Tiles verarbeitet (595 erfolgreich)
# 2026-01-01 18:21:21,982 - INFO - 📈 DE-MV: 2000/12294 Tiles verarbeitet (1158 erfolgreich)
# 2026-01-01 18:23:16,666 - INFO - 📈 DE-MV: 3000/12294 Tiles verarbeitet (1674 erfolgreich)
# 2026-01-01 18:24:58,380 - INFO - 📈 DE-MV: 4000/12294 Tiles verarbeitet (2038 erfolgreich)
# 2026-01-01 18:26:48,410 - INFO - 📈 DE-MV: 5000/12294 Tiles verarbeitet (2544 erfolgreich)
# 2026-01-01 18:28:26,034 - INFO - 📈 DE-MV: 6000/12294 Tiles verarbeitet (2979 erfolgreich)
# 2026-01-01 18:29:58,281 - INFO - 📈 DE-MV: 7000/12294 Tiles verarbeitet (3406 erfolgreich)
# 2026-01-01 18:31:27,820 - INFO - 📈 DE-MV: 8000/12294 Tiles verarbeitet (3731 erfolgreich)
# 2026-01-01 18:33:03,866 - INFO - 📈 DE-MV: 9000/12294 Tiles verarbeitet (4124 erfolgreich)
# 2026-01-01 18:34:40,797 - INFO - 📈 DE-MV: 10000/12294 Tiles verarbeitet (4627 erfolgreich)
# 2026-01-01 18:36:15,680 - INFO - 📈 DE-MV: 11000/12294 Tiles verarbeitet (5108 erfolgreich)
# 2026-01-01 18:37:55,992 - INFO - 📈 DE-MV: 12000/12294 Tiles verarbeitet (5610 erfolgreich)
# 2026-01-01 18:38:24,605 - INFO - ✅ DE-MV: 12294/12294 Tiles abgeschlossen (5799 erfolgreich, 6495 fehlgeschlagen)
# 2026-01-01 18:38:27,883 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-MV_latest.parquet
# 2026-01-01 18:38:28,160 - INFO - 🔄 DE-NI: Datei ist 17.2 Tage alt, lade neu
# 2026-01-01 18:38:28,162 - INFO - ▶️ Starte Verarbeitung für DE-NI...
# 2026-01-01 18:38:28,221 - INFO - 📊 DE-NI: 22844 Tiles zu verarbeiten
# 2026-01-01 18:40:44,938 - INFO - 📈 DE-NI: 1000/22844 Tiles verarbeitet (767 erfolgreich)
# 2026-01-01 18:42:46,727 - INFO - 📈 DE-NI: 2000/22844 Tiles verarbeitet (1484 erfolgreich)
# 2026-01-01 18:44:30,480 - INFO - 📈 DE-NI: 3000/22844 Tiles verarbeitet (2092 erfolgreich)
# 2026-01-01 18:46:02,579 - INFO - 📈 DE-NI: 4000/22844 Tiles verarbeitet (2458 erfolgreich)
# 2026-01-01 18:47:43,008 - INFO - 📈 DE-NI: 5000/22844 Tiles verarbeitet (3019 erfolgreich)
# 2026-01-01 18:49:40,115 - INFO - 📈 DE-NI: 6000/22844 Tiles verarbeitet (3701 erfolgreich)
# 2026-01-01 18:51:46,233 - INFO - 📈 DE-NI: 7000/22844 Tiles verarbeitet (4413 erfolgreich)
# 2026-01-01 18:53:33,416 - INFO - 📈 DE-NI: 8000/22844 Tiles verarbeitet (5017 erfolgreich)
# 2026-01-01 18:55:25,110 - INFO - 📈 DE-NI: 9000/22844 Tiles verarbeitet (5651 erfolgreich)
# 2026-01-01 18:57:08,634 - INFO - 📈 DE-NI: 10000/22844 Tiles verarbeitet (6230 erfolgreich)
# 2026-01-01 18:58:50,437 - INFO - 📈 DE-NI: 11000/22844 Tiles verarbeitet (6841 erfolgreich)
# 2026-01-01 19:00:43,768 - INFO - 📈 DE-NI: 12000/22844 Tiles verarbeitet (7553 erfolgreich)
# 2026-01-01 19:02:35,530 - INFO - 📈 DE-NI: 13000/22844 Tiles verarbeitet (8238 erfolgreich)
# 2026-01-01 19:04:33,866 - INFO - 📈 DE-NI: 14000/22844 Tiles verarbeitet (8988 erfolgreich)
# 2026-01-01 19:06:53,408 - INFO - 📈 DE-NI: 15000/22844 Tiles verarbeitet (9773 erfolgreich)
# 2026-01-01 19:09:29,688 - INFO - 📈 DE-NI: 16000/22844 Tiles verarbeitet (10505 erfolgreich)
# 2026-01-01 19:12:17,578 - INFO - 📈 DE-NI: 17000/22844 Tiles verarbeitet (11351 erfolgreich)
# 2026-01-01 19:14:45,262 - INFO - 📈 DE-NI: 18000/22844 Tiles verarbeitet (12124 erfolgreich)
# 2026-01-01 19:16:47,641 - INFO - 📈 DE-NI: 19000/22844 Tiles verarbeitet (12909 erfolgreich)
# 2026-01-01 19:19:24,275 - INFO - 📈 DE-NI: 20000/22844 Tiles verarbeitet (13667 erfolgreich)
# 2026-01-01 19:22:23,101 - INFO - 📈 DE-NI: 21000/22844 Tiles verarbeitet (14520 erfolgreich)
# 2026-01-01 19:23:48,422 - WARNING - ⚠️ HTTP 404 bei Tile 8680/5388
# 2026-01-01 19:24:50,596 - INFO - 📈 DE-NI: 22000/22844 Tiles verarbeitet (15279 erfolgreich)
# 2026-01-01 19:26:23,570 - INFO - ✅ DE-NI: 22844/22844 Tiles abgeschlossen (15915 erfolgreich, 6929 fehlgeschlagen)
# 2026-01-01 19:26:35,186 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-NI_latest.parquet
# 2026-01-01 19:26:36,117 - INFO - 🔄 DE-NW: Datei ist 17.2 Tage alt, lade neu
# 2026-01-01 19:26:36,120 - INFO - ▶️ Starte Verarbeitung für DE-NW...
# 2026-01-01 19:26:36,182 - INFO - 📊 DE-NW: 15243 Tiles zu verarbeiten
# 2026-01-01 19:29:32,320 - INFO - 📈 DE-NW: 1000/15243 Tiles verarbeitet (687 erfolgreich)
# 2026-01-01 19:34:53,573 - INFO - 📈 DE-NW: 2000/15243 Tiles verarbeitet (1658 erfolgreich)
# 2026-01-01 19:38:12,971 - INFO - 📈 DE-NW: 3000/15243 Tiles verarbeitet (2578 erfolgreich)
# 2026-01-01 19:42:38,384 - INFO - 📈 DE-NW: 4000/15243 Tiles verarbeitet (3490 erfolgreich)
# 2026-01-01 19:47:05,918 - INFO - 📈 DE-NW: 5000/15243 Tiles verarbeitet (4396 erfolgreich)
# 2026-01-01 19:51:53,590 - INFO - 📈 DE-NW: 6000/15243 Tiles verarbeitet (5343 erfolgreich)
# 2026-01-01 19:56:41,440 - INFO - 📈 DE-NW: 7000/15243 Tiles verarbeitet (6270 erfolgreich)
# 2026-01-01 19:59:53,086 - INFO - 📈 DE-NW: 8000/15243 Tiles verarbeitet (7167 erfolgreich)
# 2026-01-01 20:03:00,536 - INFO - 📈 DE-NW: 9000/15243 Tiles verarbeitet (8045 erfolgreich)
# 2026-01-01 20:06:39,045 - INFO - 📈 DE-NW: 10000/15243 Tiles verarbeitet (8847 erfolgreich)
# 2026-01-01 20:09:06,261 - INFO - 📈 DE-NW: 11000/15243 Tiles verarbeitet (9612 erfolgreich)
# 2026-01-01 20:11:07,156 - INFO - 📈 DE-NW: 12000/15243 Tiles verarbeitet (10252 erfolgreich)
# 2026-01-01 20:14:06,818 - INFO - 📈 DE-NW: 13000/15243 Tiles verarbeitet (11001 erfolgreich)
# 2026-01-01 20:17:11,984 - INFO - 📈 DE-NW: 14000/15243 Tiles verarbeitet (11821 erfolgreich)
# 2026-01-01 20:20:23,170 - INFO - 📈 DE-NW: 15000/15243 Tiles verarbeitet (12667 erfolgreich)
# 2026-01-01 20:20:46,491 - INFO - ✅ DE-NW: 15243/15243 Tiles abgeschlossen (12840 erfolgreich, 2403 fehlgeschlagen)
# 2026-01-01 20:20:55,436 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-NW_latest.parquet
# 2026-01-01 20:20:56,485 - INFO - 🔄 DE-RP: Datei ist 17.3 Tage alt, lade neu
# 2026-01-01 20:20:56,488 - INFO - ▶️ Starte Verarbeitung für DE-RP...
# 2026-01-01 20:20:56,528 - INFO - 📊 DE-RP: 8240 Tiles zu verarbeiten
# 2026-01-01 20:23:31,915 - INFO - 📈 DE-RP: 1000/8240 Tiles verarbeitet (833 erfolgreich)
# 2026-01-01 20:25:35,055 - INFO - 📈 DE-RP: 2000/8240 Tiles verarbeitet (1753 erfolgreich)
# 2026-01-01 20:27:46,545 - INFO - 📈 DE-RP: 3000/8240 Tiles verarbeitet (2652 erfolgreich)
# 2026-01-01 20:30:05,766 - INFO - 📈 DE-RP: 4000/8240 Tiles verarbeitet (3555 erfolgreich)
# 2026-01-01 20:32:25,059 - INFO - 📈 DE-RP: 5000/8240 Tiles verarbeitet (4417 erfolgreich)
# 2026-01-01 20:34:48,340 - INFO - 📈 DE-RP: 6000/8240 Tiles verarbeitet (5219 erfolgreich)
# 2026-01-01 20:37:07,368 - INFO - 📈 DE-RP: 7000/8240 Tiles verarbeitet (6027 erfolgreich)
# 2026-01-01 20:39:52,137 - INFO - 📈 DE-RP: 8000/8240 Tiles verarbeitet (6929 erfolgreich)
# 2026-01-01 20:40:46,246 - INFO - ✅ DE-RP: 8240/8240 Tiles abgeschlossen (7151 erfolgreich, 1089 fehlgeschlagen)
# 2026-01-01 20:40:51,424 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-RP_latest.parquet
# 2026-01-01 20:40:51,843 - INFO - 🔄 DE-SL: Datei ist 17.3 Tage alt, lade neu
# 2026-01-01 20:40:51,844 - INFO - ▶️ Starte Verarbeitung für DE-SL...
# 2026-01-01 20:40:51,850 - INFO - 📊 DE-SL: 1170 Tiles zu verarbeiten
# 2026-01-01 20:43:53,095 - INFO - 📈 DE-SL: 1000/1170 Tiles verarbeitet (883 erfolgreich)
# 2026-01-01 20:44:37,550 - INFO - ✅ DE-SL: 1170/1170 Tiles abgeschlossen (1035 erfolgreich, 135 fehlgeschlagen)
# 2026-01-01 20:44:38,285 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SL_latest.parquet
# 2026-01-01 20:44:38,365 - INFO - 🔄 DE-ST: Datei ist 17.3 Tage alt, lade neu
# 2026-01-01 20:44:38,367 - INFO - ▶️ Starte Verarbeitung für DE-ST...
# 2026-01-01 20:44:38,396 - INFO - 📊 DE-ST: 9077 Tiles zu verarbeiten
# 2026-01-01 20:46:28,339 - INFO - 📈 DE-ST: 1000/9077 Tiles verarbeitet (587 erfolgreich)
# 2026-01-01 20:48:11,863 - INFO - 📈 DE-ST: 2000/9077 Tiles verarbeitet (1224 erfolgreich)
# 2026-01-01 20:49:50,131 - INFO - 📈 DE-ST: 3000/9077 Tiles verarbeitet (1772 erfolgreich)
# 2026-01-01 20:51:39,885 - INFO - 📈 DE-ST: 4000/9077 Tiles verarbeitet (2315 erfolgreich)
# 2026-01-01 20:53:33,187 - INFO - 📈 DE-ST: 5000/9077 Tiles verarbeitet (2925 erfolgreich)
# 2026-01-01 20:55:37,664 - INFO - 📈 DE-ST: 6000/9077 Tiles verarbeitet (3613 erfolgreich)
# 2026-01-01 20:58:19,938 - INFO - 📈 DE-ST: 7000/9077 Tiles verarbeitet (4306 erfolgreich)
# 2026-01-01 21:00:36,348 - INFO - 📈 DE-ST: 8000/9077 Tiles verarbeitet (4913 erfolgreich)
# 2026-01-01 21:02:34,004 - INFO - 📈 DE-ST: 9000/9077 Tiles verarbeitet (5666 erfolgreich)
# 2026-01-01 21:02:41,437 - INFO - ✅ DE-ST: 9077/9077 Tiles abgeschlossen (5717 erfolgreich, 3360 fehlgeschlagen)
# 2026-01-01 21:02:45,359 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-ST_latest.parquet
# 2026-01-01 21:02:45,737 - INFO - 🔄 DE-SN: Datei ist 17.3 Tage alt, lade neu
# 2026-01-01 21:02:45,739 - INFO - ▶️ Starte Verarbeitung für DE-SN...
# 2026-01-01 21:02:45,768 - INFO - 📊 DE-SN: 8311 Tiles zu verarbeiten
# 2026-01-01 21:05:30,943 - INFO - 📈 DE-SN: 1000/8311 Tiles verarbeitet (800 erfolgreich)
# 2026-01-01 21:09:04,656 - INFO - 📈 DE-SN: 2000/8311 Tiles verarbeitet (1633 erfolgreich)
# 2026-01-01 21:11:20,935 - INFO - 📈 DE-SN: 3000/8311 Tiles verarbeitet (2419 erfolgreich)
# 2026-01-01 21:13:21,423 - INFO - 📈 DE-SN: 4000/8311 Tiles verarbeitet (3189 erfolgreich)
# 2026-01-01 21:15:13,217 - INFO - 📈 DE-SN: 5000/8311 Tiles verarbeitet (3948 erfolgreich)
# 2026-01-01 21:17:40,923 - INFO - 📈 DE-SN: 6000/8311 Tiles verarbeitet (4751 erfolgreich)
# 2026-01-01 21:19:31,159 - INFO - 📈 DE-SN: 7000/8311 Tiles verarbeitet (5483 erfolgreich)
# 2026-01-01 21:21:34,536 - INFO - 📈 DE-SN: 8000/8311 Tiles verarbeitet (6225 erfolgreich)
# 2026-01-01 21:22:34,872 - INFO - ✅ DE-SN: 8311/8311 Tiles abgeschlossen (6452 erfolgreich, 1859 fehlgeschlagen)
# 2026-01-01 21:22:39,919 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SN_latest.parquet
# 2026-01-01 21:22:40,372 - INFO - 🔄 DE-SH: Datei ist 17.3 Tage alt, lade neu
# 2026-01-01 21:22:40,374 - INFO - ▶️ Starte Verarbeitung für DE-SH...
# 2026-01-01 21:22:40,407 - INFO - 📊 DE-SH: 9101 Tiles zu verarbeiten
# 2026-01-01 21:24:39,103 - INFO - 📈 DE-SH: 1000/9101 Tiles verarbeitet (546 erfolgreich)
# 2026-01-01 21:26:11,151 - INFO - 📈 DE-SH: 2000/9101 Tiles verarbeitet (1054 erfolgreich)
# 2026-01-01 21:27:53,701 - INFO - 📈 DE-SH: 3000/9101 Tiles verarbeitet (1719 erfolgreich)
# 2026-01-01 21:29:44,903 - INFO - 📈 DE-SH: 4000/9101 Tiles verarbeitet (2331 erfolgreich)
# 2026-01-01 21:31:33,392 - INFO - 📈 DE-SH: 5000/9101 Tiles verarbeitet (2901 erfolgreich)
# 2026-01-01 21:33:47,758 - INFO - 📈 DE-SH: 6000/9101 Tiles verarbeitet (3530 erfolgreich)
# 2026-01-01 21:35:42,343 - INFO - 📈 DE-SH: 7000/9101 Tiles verarbeitet (4186 erfolgreich)
# 2026-01-01 21:37:50,537 - INFO - 📈 DE-SH: 8000/9101 Tiles verarbeitet (4967 erfolgreich)
# 2026-01-01 21:40:50,960 - INFO - 📈 DE-SH: 9000/9101 Tiles verarbeitet (5753 erfolgreich)
# 2026-01-01 21:41:03,187 - INFO - ✅ DE-SH: 9101/9101 Tiles abgeschlossen (5807 erfolgreich, 3294 fehlgeschlagen)
# 2026-01-01 21:41:07,731 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SH_latest.parquet
# 2026-01-01 21:41:08,191 - INFO - 🔄 DE-TH: Datei ist 17.1 Tage alt, lade neu
# 2026-01-01 21:41:08,192 - INFO - ▶️ Starte Verarbeitung für DE-TH...
# 2026-01-01 21:41:08,229 - INFO - 📊 DE-TH: 6819 Tiles zu verarbeiten
# 2026-01-01 21:43:05,867 - INFO - 📈 DE-TH: 1000/6819 Tiles verarbeitet (628 erfolgreich)
# 2026-01-01 21:45:31,541 - INFO - 📈 DE-TH: 2000/6819 Tiles verarbeitet (1363 erfolgreich)
# 2026-01-01 21:47:55,037 - INFO - 📈 DE-TH: 3000/6819 Tiles verarbeitet (2064 erfolgreich)
# 2026-01-01 21:49:49,276 - INFO - 📈 DE-TH: 4000/6819 Tiles verarbeitet (2691 erfolgreich)
# 2026-01-01 21:51:41,096 - INFO - 📈 DE-TH: 5000/6819 Tiles verarbeitet (3382 erfolgreich)
# 2026-01-01 21:54:26,994 - INFO - 📈 DE-TH: 6000/6819 Tiles verarbeitet (4216 erfolgreich)
# 2026-01-01 21:56:28,669 - INFO - ✅ DE-TH: 6819/6819 Tiles abgeschlossen (4784 erfolgreich, 2035 fehlgeschlagen)
# 2026-01-01 21:56:31,805 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-TH_latest.parquet
# 2026-01-01 21:56:32,097 - INFO -
# 📅 Ältester Mapillary-Timestamp: 2026-01-01T15:50:01.558252+00:00
# 2026-01-01 21:56:32,101 - INFO - 💾 Metadata gespeichert: output/ml_metadata.json
# 2026-01-01 21:56:32,103 - INFO - 📄 Log-Datei: ml_output/mapillary_download_20260101_151049.log
# 2026-01-01 21:56:32,104 - INFO - === Mapillary Coverage Download abgeschlossen ===
