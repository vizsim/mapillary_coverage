# %% [markdown]
# # Was tut dieses Skript?
# Dieses Skript lädt die Mapillay coverage je Bundesland je Tiles herunter,
# filtert sie nach Aufnahmedatum,
# und exportiert die Ergebnisse als Parquet-Dateien.

# %%
# Standard library
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime, timezone
import json
import os
import time
import logging
import sys

# Third-party
import geopandas as gpd
import mercantile
import pandas as pd
import requests
from requests.exceptions import SSLError
from tqdm import tqdm
from vt2geojson.tools import vt_bytes_to_geojson


from config import TILES_CONFIG, PROCESSING_CONFIG, MAPILLARY_CONFIG

# Setup Logging
log_folder = PROCESSING_CONFIG["ml_output_folder"]
os.makedirs(log_folder, exist_ok=True)
log_file = os.path.join(log_folder, f"mapillary_download_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log")

# Konfiguriere Logger
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file, encoding='utf-8'),
        logging.StreamHandler(sys.stdout)  # Auch in Console ausgeben
    ]
)

logger = logging.getLogger(__name__)
logger.info(f"=== Mapillary Coverage Download gestartet ===")
logger.info(f"Log-Datei: {log_file}")
# Out:
# 2025-12-09 12:42:37,593 - INFO - === Mapillary Coverage Download gestartet ===
# 2025-12-09 12:42:37,596 - INFO - Log-Datei: ml_output/mapillary_download_20251209_124237.log

# %%
TQDM_ENABLED = os.environ.get("TQDM_DISABLE", "0") != "1"

# %%
### Helper function for loading tile lists

def load_tiles_from_json(bundesland_id, input_folder = TILES_CONFIG["cache_folder"]):
    path = os.path.join(input_folder, f"{bundesland_id}_tiles.json")
    with open(path, "r") as f:
        tile_list = json.load(f)
    return [mercantile.Tile(**t) for t in tile_list]

# %%
def export_geodata(gdfs, output_folder = PROCESSING_CONFIG["output_folder"], base_name="mapillary_coverage", region="ger", save_parquet=True, save_geojson_gz=True):
    """
    Export one or more GeoDataFrames into output files (.parquet only, ohne Datum im Namen).
    
    Args:
        gdfs (list or GeoDataFrame): List of GeoDataFrames or a single GeoDataFrame.
        output_folder (str): Output directory (created if it doesn't exist).
        base_name (str): Base filename prefix.
        region (str): Region tag for filename.
        save_parquet (bool): Save .parquet file.
        save_geojson_gz (bool): Save .geojson.gz file (not implemented).
    
    Returns:
        str: Timestamp when data was processed (ISO format)
    """
    if gdfs is None or (isinstance(gdfs, (gpd.GeoDataFrame, pd.DataFrame)) and gdfs.empty):
        logger.warning("No data to export.")
        return None

    # Concatenate if needed
    if isinstance(gdfs, list):
        gdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))
    else:
        gdf = gdfs

    os.makedirs(output_folder, exist_ok=True)
    
    # Aktueller Zeitstempel für Metadata
    current_timestamp = datetime.now(timezone.utc).isoformat()

    if save_parquet:
        # Dateiname OHNE Datum - nur "latest"
        parquet_path = os.path.join(output_folder, f"{base_name}_{region}_latest.parquet")
        gdf.to_parquet(parquet_path, index=False)
        logger.info(f"✔ Parquet saved to: {parquet_path}")
    
    return current_timestamp

# %%
def process_bundesland(bundesland_id, region_name=None, input_folder = TILES_CONFIG["cache_folder"], output_folder = PROCESSING_CONFIG["ml_output_folder"] , max_workers=3, limit_tiles=None):
    logger.info(f"▶️ Starte Verarbeitung für {bundesland_id}...")

    tiles = load_tiles_from_json(bundesland_id, input_folder=input_folder)
    if limit_tiles:
        tiles = tiles[:limit_tiles]
    
    total_tiles = len(tiles)
    logger.info(f"📊 {bundesland_id}: {total_tiles} Tiles zu verarbeiten")
    
    # genereal config
    # Load your access token
    ACCESS_TOKEN = MAPILLARY_CONFIG["access_token"]

    # Use existing variables
    tile_layer = "sequence"  # or 'image' for points
    tile_coverage = "mly1_computed_public"
    
    # Tracking für aufeinanderfolgende Fehler
    consecutive_parse_errors = 0
    MAX_CONSECUTIVE_ERRORS = 5
    
    # Tracking für Fortschritt
    processed_count = 0
    successful_count = 0

    def process_tile(tile, retry_count=0, max_retries=3):
        """
        Verarbeite ein Tile mit Retry-Logik bei Parsing-Fehlern.
        
        Args:
            tile: Mercantile Tile Objekt
            retry_count: Aktueller Retry-Versuch
            max_retries: Maximale Anzahl an Versuchen
        """
        nonlocal consecutive_parse_errors
        
        url = f"https://tiles.mapillary.com/maps/vtp/{tile_coverage}/2/{tile.z}/{tile.x}/{tile.y}?access_token={ACCESS_TOKEN}"
        
        try:
            response = requests.get(url, timeout=30)
            
            # Rate Limit Check
            if response.status_code == 429:
                logger.warning(f"⚠️ Rate Limit erreicht bei Tile {tile.x}/{tile.y}. Pausiere für 5 Minuten...")
                time.sleep(300)
                if retry_count < max_retries:
                    return process_tile(tile, retry_count + 1, max_retries)
                return None
            
            if response.status_code != 200:
                logger.warning(f"⚠️ HTTP {response.status_code} bei Tile {tile.x}/{tile.y}")
                return None
            
            # Versuche Vector Tile zu parsen
            geojson = vt_bytes_to_geojson(response.content, tile.x, tile.y, tile.z, layer=tile_layer)
            features = geojson.get("features", [])
            
            if not features:
                return None
            
            gdf_tile = gpd.GeoDataFrame.from_features(features, crs="EPSG:4326")
            gdf_tile['captured_at'] = gdf_tile['captured_at'].apply(lambda x: datetime.fromtimestamp(x / 1000, tz=timezone.utc))
            
            # Timefilter
            min_date_str = PROCESSING_CONFIG["min_capture_date"]
            min_dt = datetime.strptime(min_date_str, "%Y-%m-%d").replace(tzinfo=timezone.utc)
            gdf_tile = gdf_tile[gdf_tile['captured_at'] >= min_dt]
            gdf_tile['captured_at'] = gdf_tile['captured_at'].dt.strftime('%Y-%m-%d')

            gdf_tile['tile_x'] = tile.x
            gdf_tile['tile_y'] = tile.y
            
            # Erfolg → Fehler-Counter zurücksetzen
            consecutive_parse_errors = 0
            return gdf_tile
            
        except Exception as e:
            error_msg = str(e)
            
            # Prüfe ob es ein Parsing-Fehler ist (wahrscheinlich Rate Limit)
            if "Error parsing message" in error_msg or "vector_tile" in error_msg:
                consecutive_parse_errors += 1
                
                # Prüfe ob zu viele aufeinanderfolgende Fehler
                if consecutive_parse_errors >= MAX_CONSECUTIVE_ERRORS:
                    logger.error(f"🛑 {MAX_CONSECUTIVE_ERRORS} aufeinanderfolgende Parsing-Fehler! API scheint blockiert zu sein.")
                    logger.warning(f"⏸️  LANGE PAUSE: 30 Minuten warten...")
                    time.sleep(1800)  # 30 Minuten
                    consecutive_parse_errors = 0  # Counter zurücksetzen
                    logger.info(f"▶️ Setze Verarbeitung fort nach langer Pause...")
                
                if retry_count < max_retries:
                    logger.warning(f"⚠️ Parsing-Fehler bei Tile {tile.x}/{tile.y} (Versuch {retry_count + 1}/{max_retries}, konsekutiv: {consecutive_parse_errors}). Pausiere für 5 Minuten...")
                    time.sleep(300)  # 5 Minuten Pause
                    return process_tile(tile, retry_count + 1, max_retries)
                else:
                    logger.error(f"❌ Tile {tile.x}/{tile.y} nach {max_retries} Versuchen fehlgeschlagen: {error_msg}")
                    return None
            else:
                logger.error(f"❌ Fehler bei Tile {tile.x}/{tile.y}: {error_msg}")
                return None

    gdf_all = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(process_tile, tile): tile for tile in tiles}
        for future in tqdm(as_completed(futures), total=len(futures), desc=f"🧩 {bundesland_id}", disable=not TQDM_ENABLED):
            try:
                result = future.result()
                processed_count += 1
                
                if result is not None:
                    gdf_all.append(result)
                    successful_count += 1
                
                # Progress-Logging alle 1000 Tiles (nur wenn >= 1000 Tiles total)
                if total_tiles >= 1000 and processed_count % 1000 == 0:
                    logger.info(f"📈 {bundesland_id}: {processed_count}/{total_tiles} Tiles verarbeitet ({successful_count} erfolgreich)")
                    
            except SSLError as e:
                logger.warning(f"⚠️ SSLError: {e}. Pausiere für 5 Minuten...")
                time.sleep(300)
            except Exception as e:
                logger.error(f"⚠️ Unbekannter Fehler: {e}")
    
    # Final Summary
    logger.info(f"✅ {bundesland_id}: {processed_count}/{total_tiles} Tiles abgeschlossen ({successful_count} erfolgreich, {processed_count - successful_count} fehlgeschlagen)")

    if gdf_all:
        gdf_all = gpd.GeoDataFrame(pd.concat(gdf_all, ignore_index=True))
        timestamp = export_geodata(
            gdfs=gdf_all,
            output_folder=output_folder,
            region=bundesland_id,
            save_parquet=True,
            save_geojson_gz=False
        )
        return timestamp
    else:
        logger.warning(f"⚠️ Keine Daten für {bundesland_id}.")
        return None

# %%
# Verarbeitung der Bundesländer basierend auf config.py
# takes about ~6.5h for all 16 bundesländer (on lokal machine)

bland = gpd.read_file("https://raw.githubusercontent.com/isellsoap/deutschlandGeoJSON/main/2_bundeslaender/1_sehr_hoch.geo.json")

# Filter Bundesländer basierend auf config.py
from config import GEOFABRIK_CONFIG

selected_bundeslaender = GEOFABRIK_CONFIG.get("bundeslaender")
if selected_bundeslaender:
    # Nur die ausgewählten Bundesländer verarbeiten
    bland_filtered = bland[bland['id'].isin(selected_bundeslaender)]
    logger.info(f"🎯 Verarbeite {len(bland_filtered)} ausgewählte Bundesländer: {', '.join(selected_bundeslaender)}")
else:
    # Alle Bundesländer verarbeiten
    bland_filtered = bland
    logger.info(f"📍 Verarbeite alle {len(bland_filtered)} Bundesländer")

# Sammle Timestamps für Metadata
ml_timestamps = {}

for _, row in bland_filtered.iterrows():
    b_id = row["id"]
    name = row["name"]

    # Nur verarbeiten, wenn eine JSON-Datei existiert
    tile_json_path = os.path.join(TILES_CONFIG["cache_folder"], f"{b_id}_tiles.json")
    if not os.path.exists(tile_json_path):
        logger.warning(f"⏩ Überspringe {b_id}, keine Tiles gefunden.")
        continue

    # Prüfe ob Parquet bereits existiert und noch aktuell ist
    output_folder = PROCESSING_CONFIG["ml_output_folder"]
    parquet_path = os.path.join(output_folder, f"mapillary_coverage_{b_id}_latest.parquet")
    max_age_days = PROCESSING_CONFIG.get('max_file_age_days', 4)
    
    if os.path.exists(parquet_path):
        file_mtime = os.path.getmtime(parquet_path)
        file_age_days = (datetime.now().timestamp() - file_mtime) / 86400  # Sekunden in Tage
        
        if file_age_days < max_age_days:
            logger.info(f"⏩ {b_id}: Datei ist {file_age_days:.1f} Tage alt, überspringe Download")
            # Timestamp aus existierender Datei für Metadata verwenden
            ml_timestamps[b_id] = datetime.fromtimestamp(file_mtime, tz=timezone.utc).isoformat()
            continue
        else:
            logger.info(f"🔄 {b_id}: Datei ist {file_age_days:.1f} Tage alt, lade neu")

    timestamp = process_bundesland(b_id, region_name=name)
    if timestamp:
        ml_timestamps[b_id] = timestamp

# Speichere Metadata ähnlich wie osm_metadata.json
if ml_timestamps:
    # Finde ältesten Timestamp
    oldest_ml_timestamp = min(ml_timestamps.values())
    
    metadata = {
        "ml_data_from": oldest_ml_timestamp,
        "bundeslaender": ml_timestamps,
        "processed_date": datetime.now(timezone.utc).isoformat()
    }
    
    with open("ml_metadata.json", "w", encoding="utf-8") as f:
        json.dump(metadata, f, ensure_ascii=False, indent=2)
    
    logger.info(f"\n📅 Ältester Mapillary-Timestamp: {oldest_ml_timestamp}")
    logger.info(f"💾 Metadata gespeichert: ml_metadata.json")
    logger.info(f"📄 Log-Datei: {log_file}")
else:
    logger.warning("\n⚠️  Keine Mapillary-Daten verarbeitet, keine Metadata erstellt.")

logger.info("=== Mapillary Coverage Download abgeschlossen ===")
# Out:
# 2025-12-09 12:42:38,963 - INFO - 📍 Verarbeite alle 16 Bundesländer
# 2025-12-09 12:42:38,969 - INFO - 🔄 DE-BW: Datei ist 3.0 Tage alt, lade neu
# 2025-12-09 12:42:38,971 - INFO - ▶️ Starte Verarbeitung für DE-BW...
# 2025-12-09 12:42:39,020 - INFO - 📊 DE-BW: 14160 Tiles zu verarbeiten
# 2025-12-09 12:44:52,556 - INFO - 📈 DE-BW: 1000/14160 Tiles verarbeitet (828 erfolgreich)
# 2025-12-09 12:46:34,209 - INFO - 📈 DE-BW: 2000/14160 Tiles verarbeitet (1576 erfolgreich)
# 2025-12-09 12:48:22,774 - INFO - 📈 DE-BW: 3000/14160 Tiles verarbeitet (2359 erfolgreich)
# 2025-12-09 12:49:29,347 - WARNING - ⚠️ HTTP 404 bei Tile 8576/5590
# 2025-12-09 12:51:21,165 - INFO - 📈 DE-BW: 4000/14160 Tiles verarbeitet (3207 erfolgreich)
# 2025-12-09 14:36:12,524 - INFO - 🔄 DE-BB: Datei ist 3.1 Tage alt, lade neu
# 2025-12-09 14:36:12,525 - INFO - ▶️ Starte Verarbeitung für DE-BB...
# 2025-12-09 14:36:12,579 - INFO - 📊 DE-BB: 13585 Tiles zu verarbeiten
# 2025-12-09 14:38:07,570 - INFO - 📈 DE-BB: 1000/13585 Tiles verarbeitet (635 erfolgreich)
# 2025-12-09 14:39:24,434 - INFO - 📈 DE-BB: 2000/13585 Tiles verarbeitet (1285 erfolgreich)
# 2025-12-09 14:40:47,528 - INFO - 📈 DE-BB: 3000/13585 Tiles verarbeitet (1916 erfolgreich)
# 2025-12-09 14:42:27,322 - INFO - 📈 DE-BB: 4000/13585 Tiles verarbeitet (2654 erfolgreich)
# 2025-12-09 14:44:29,615 - INFO - 📈 DE-BB: 5000/13585 Tiles verarbeitet (3461 erfolgreich)
# 2025-12-09 14:46:37,627 - INFO - 📈 DE-BB: 6000/13585 Tiles verarbeitet (4323 erfolgreich)
# 2025-12-09 14:49:02,110 - INFO - 📈 DE-BB: 7000/13585 Tiles verarbeitet (5183 erfolgreich)
# 2025-12-09 14:51:22,362 - INFO - 📈 DE-BB: 8000/13585 Tiles verarbeitet (6061 erfolgreich)
# 2025-12-09 14:53:20,262 - INFO - 📈 DE-BB: 9000/13585 Tiles verarbeitet (6926 erfolgreich)
# 2025-12-09 14:55:00,621 - INFO - 📈 DE-BB: 10000/13585 Tiles verarbeitet (7782 erfolgreich)
# 2025-12-09 14:56:26,270 - INFO - 📈 DE-BB: 11000/13585 Tiles verarbeitet (8615 erfolgreich)
# 2025-12-09 14:57:48,344 - INFO - 📈 DE-BB: 12000/13585 Tiles verarbeitet (9389 erfolgreich)
# 2025-12-09 14:59:16,251 - INFO - 📈 DE-BB: 13000/13585 Tiles verarbeitet (10221 erfolgreich)
# 2025-12-09 15:00:09,392 - INFO - ✅ DE-BB: 13585/13585 Tiles abgeschlossen (10710 erfolgreich, 2875 fehlgeschlagen)
# 2025-12-09 15:00:17,063 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BB_latest.parquet
# 2025-12-09 15:00:17,597 - INFO - 🔄 DE-HB: Datei ist 3.1 Tage alt, lade neu
# 2025-12-09 15:00:17,598 - INFO - ▶️ Starte Verarbeitung für DE-HB...
# 2025-12-09 15:00:17,602 - INFO - 📊 DE-HB: 145 Tiles zu verarbeiten
# 2025-12-09 15:01:21,775 - INFO - ✅ DE-HB: 145/145 Tiles abgeschlossen (135 erfolgreich, 10 fehlgeschlagen)
# 2025-12-09 15:01:21,875 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HB_latest.parquet
# 2025-12-09 15:01:21,891 - INFO - 🔄 DE-HH: Datei ist 3.1 Tage alt, lade neu
# 2025-12-09 15:01:21,893 - INFO - ▶️ Starte Verarbeitung für DE-HH...
# 2025-12-09 15:01:21,896 - INFO - 📊 DE-HH: 361 Tiles zu verarbeiten
# 2025-12-09 15:04:40,138 - INFO - ✅ DE-HH: 361/361 Tiles abgeschlossen (359 erfolgreich, 2 fehlgeschlagen)
# 2025-12-09 17:27:55,922 - INFO - 📈 DE-NW: 15000/15243 Tiles verarbeitet (12660 erfolgreich)
# 2025-12-09 17:28:19,973 - INFO - ✅ DE-NW: 15243/15243 Tiles abgeschlossen (12833 erfolgreich, 2410 fehlgeschlagen)
# 2025-12-09 17:28:28,560 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-NW_latest.parquet
# 2025-12-09 17:28:29,641 - INFO - 🔄 DE-RP: Datei ist 3.0 Tage alt, lade neu
# 2025-12-09 17:28:29,643 - INFO - ▶️ Starte Verarbeitung für DE-RP...
# 2025-12-09 17:28:29,667 - INFO - 📊 DE-RP: 8240 Tiles zu verarbeiten
# 2025-12-09 17:31:13,089 - INFO - 📈 DE-RP: 1000/8240 Tiles verarbeitet (832 erfolgreich)
# 2025-12-09 17:33:17,636 - INFO - 📈 DE-RP: 2000/8240 Tiles verarbeitet (1752 erfolgreich)
# 2025-12-09 17:35:28,281 - INFO - 📈 DE-RP: 3000/8240 Tiles verarbeitet (2651 erfolgreich)
# 2025-12-09 17:37:50,095 - INFO - 📈 DE-RP: 4000/8240 Tiles verarbeitet (3554 erfolgreich)
# 2025-12-09 17:40:16,442 - INFO - 📈 DE-RP: 5000/8240 Tiles verarbeitet (4415 erfolgreich)
# 2025-12-09 17:42:42,054 - INFO - 📈 DE-RP: 6000/8240 Tiles verarbeitet (5217 erfolgreich)
# 2025-12-09 17:45:04,137 - INFO - 📈 DE-RP: 7000/8240 Tiles verarbeitet (6025 erfolgreich)
# 2025-12-09 17:47:57,557 - INFO - 📈 DE-RP: 8000/8240 Tiles verarbeitet (6926 erfolgreich)
# 2025-12-09 17:48:53,814 - INFO - ✅ DE-RP: 8240/8240 Tiles abgeschlossen (7148 erfolgreich, 1092 fehlgeschlagen)
# 2025-12-09 17:48:59,113 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-RP_latest.parquet
# 2025-12-09 17:48:59,564 - INFO - 🔄 DE-SL: Datei ist 3.3 Tage alt, lade neu
# 2025-12-09 17:48:59,566 - INFO - ▶️ Starte Verarbeitung für DE-SL...
# 2025-12-09 17:48:59,572 - INFO - 📊 DE-SL: 1170 Tiles zu verarbeiten
# 2025-12-09 17:52:09,828 - INFO - 📈 DE-SL: 1000/1170 Tiles verarbeitet (883 erfolgreich)
# 2025-12-09 17:52:55,958 - INFO - ✅ DE-SL: 1170/1170 Tiles abgeschlossen (1035 erfolgreich, 135 fehlgeschlagen)
# 2025-12-09 17:52:56,700 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SL_latest.parquet
# 2025-12-09 17:52:56,782 - INFO - 🔄 DE-ST: Datei ist 3.0 Tage alt, lade neu
# 2025-12-09 17:52:56,784 - INFO - ▶️ Starte Verarbeitung für DE-ST...
# 2025-12-09 17:52:56,811 - INFO - 📊 DE-ST: 9077 Tiles zu verarbeiten
# 2025-12-09 17:54:39,931 - INFO - 📈 DE-ST: 1000/9077 Tiles verarbeitet (587 erfolgreich)
# 2025-12-09 17:56:19,668 - INFO - 📈 DE-ST: 2000/9077 Tiles verarbeitet (1224 erfolgreich)
# 2025-12-09 17:57:56,561 - INFO - 📈 DE-ST: 3000/9077 Tiles verarbeitet (1768 erfolgreich)
# 2025-12-09 17:59:36,107 - INFO - 📈 DE-ST: 4000/9077 Tiles verarbeitet (2304 erfolgreich)
# 2025-12-09 18:01:27,770 - INFO - 📈 DE-ST: 5000/9077 Tiles verarbeitet (2909 erfolgreich)
# 2025-12-09 18:03:24,872 - INFO - 📈 DE-ST: 6000/9077 Tiles verarbeitet (3593 erfolgreich)
# 2025-12-09 18:06:05,519 - INFO - 📈 DE-ST: 7000/9077 Tiles verarbeitet (4282 erfolgreich)
# 2025-12-09 18:08:19,387 - INFO - 📈 DE-ST: 8000/9077 Tiles verarbeitet (4889 erfolgreich)
# 2025-12-09 18:10:16,225 - INFO - 📈 DE-ST: 9000/9077 Tiles verarbeitet (5642 erfolgreich)
# 2025-12-09 18:10:23,902 - INFO - ✅ DE-ST: 9077/9077 Tiles abgeschlossen (5693 erfolgreich, 3384 fehlgeschlagen)
# 2025-12-09 18:10:27,431 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-ST_latest.parquet
# 2025-12-09 18:10:27,760 - INFO - 🔄 DE-SN: Datei ist 3.0 Tage alt, lade neu
# 2025-12-09 18:10:27,761 - INFO - ▶️ Starte Verarbeitung für DE-SN...
# 2025-12-09 18:10:27,784 - INFO - 📊 DE-SN: 8311 Tiles zu verarbeiten
# 2025-12-09 18:13:18,627 - INFO - 📈 DE-SN: 1000/8311 Tiles verarbeitet (800 erfolgreich)
# 2025-12-09 18:16:43,683 - INFO - 📈 DE-SN: 2000/8311 Tiles verarbeitet (1633 erfolgreich)
# 2025-12-09 18:18:55,606 - INFO - 📈 DE-SN: 3000/8311 Tiles verarbeitet (2419 erfolgreich)
# 2025-12-09 18:20:59,291 - INFO - 📈 DE-SN: 4000/8311 Tiles verarbeitet (3189 erfolgreich)
# 2025-12-09 18:22:46,644 - INFO - 📈 DE-SN: 5000/8311 Tiles verarbeitet (3948 erfolgreich)
# 2025-12-09 18:25:11,698 - INFO - 📈 DE-SN: 6000/8311 Tiles verarbeitet (4751 erfolgreich)
# 2025-12-09 18:26:51,407 - INFO - 📈 DE-SN: 7000/8311 Tiles verarbeitet (5483 erfolgreich)
# 2025-12-09 18:28:47,244 - INFO - 📈 DE-SN: 8000/8311 Tiles verarbeitet (6225 erfolgreich)
# 2025-12-09 18:29:44,354 - INFO - ✅ DE-SN: 8311/8311 Tiles abgeschlossen (6452 erfolgreich, 1859 fehlgeschlagen)
# 2025-12-09 18:29:48,183 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SN_latest.parquet
# 2025-12-09 18:29:48,604 - INFO - 🔄 DE-SH: Datei ist 3.0 Tage alt, lade neu
# 2025-12-09 18:29:48,605 - INFO - ▶️ Starte Verarbeitung für DE-SH...
# 2025-12-09 18:29:48,642 - INFO - 📊 DE-SH: 9101 Tiles zu verarbeiten
# 2025-12-09 18:31:49,231 - INFO - 📈 DE-SH: 1000/9101 Tiles verarbeitet (546 erfolgreich)
# 2025-12-09 18:33:19,669 - INFO - 📈 DE-SH: 2000/9101 Tiles verarbeitet (1054 erfolgreich)
# 2025-12-09 18:34:55,185 - INFO - 📈 DE-SH: 3000/9101 Tiles verarbeitet (1719 erfolgreich)
# 2025-12-09 18:36:47,077 - INFO - 📈 DE-SH: 4000/9101 Tiles verarbeitet (2331 erfolgreich)
# 2025-12-09 18:38:29,745 - INFO - 📈 DE-SH: 5000/9101 Tiles verarbeitet (2901 erfolgreich)
# 2025-12-09 18:40:38,099 - INFO - 📈 DE-SH: 6000/9101 Tiles verarbeitet (3530 erfolgreich)
# 2025-12-09 18:42:27,979 - INFO - 📈 DE-SH: 7000/9101 Tiles verarbeitet (4186 erfolgreich)
# 2025-12-09 18:44:27,558 - INFO - 📈 DE-SH: 8000/9101 Tiles verarbeitet (4964 erfolgreich)
# 2025-12-09 18:47:15,415 - INFO - 📈 DE-SH: 9000/9101 Tiles verarbeitet (5750 erfolgreich)
# 2025-12-09 18:47:25,540 - INFO - ✅ DE-SH: 9101/9101 Tiles abgeschlossen (5804 erfolgreich, 3297 fehlgeschlagen)
# 2025-12-09 18:47:28,755 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SH_latest.parquet
# 2025-12-09 18:47:29,054 - INFO - 🔄 DE-TH: Datei ist 3.0 Tage alt, lade neu
# 2025-12-09 18:47:29,055 - INFO - ▶️ Starte Verarbeitung für DE-TH...
# 2025-12-09 18:47:29,084 - INFO - 📊 DE-TH: 6819 Tiles zu verarbeiten
# 2025-12-09 18:49:10,433 - INFO - 📈 DE-TH: 1000/6819 Tiles verarbeitet (628 erfolgreich)
# 2025-12-09 18:51:20,078 - INFO - 📈 DE-TH: 2000/6819 Tiles verarbeitet (1366 erfolgreich)
# 2025-12-09 18:53:24,202 - INFO - 📈 DE-TH: 3000/6819 Tiles verarbeitet (2066 erfolgreich)
# 2025-12-09 18:55:10,582 - INFO - 📈 DE-TH: 4000/6819 Tiles verarbeitet (2693 erfolgreich)
# 2025-12-09 18:56:56,641 - INFO - 📈 DE-TH: 5000/6819 Tiles verarbeitet (3384 erfolgreich)
# 2025-12-09 18:59:38,360 - INFO - 📈 DE-TH: 6000/6819 Tiles verarbeitet (4218 erfolgreich)
# 2025-12-09 19:01:30,297 - INFO - ✅ DE-TH: 6819/6819 Tiles abgeschlossen (4786 erfolgreich, 2033 fehlgeschlagen)
# 2025-12-09 19:01:33,031 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-TH_latest.parquet
# 2025-12-09 19:01:33,274 - INFO -
# 📅 Ältester Mapillary-Timestamp: 2025-12-09T13:18:09.760379+00:00
# 2025-12-09 19:01:33,276 - INFO - 💾 Metadata gespeichert: ml_metadata.json
# 2025-12-09 19:01:33,278 - INFO - 📄 Log-Datei: ml_output/mapillary_download_20251209_124237.log
# 2025-12-09 19:01:33,280 - INFO - === Mapillary Coverage Download abgeschlossen ===
