# %% [markdown]
# # Was tut dieses Skript?
# Dieses Skript lädt die Mapillay coverage je Bundesland je Tiles herunter,
# filtert sie nach Aufnahmedatum,
# und exportiert die Ergebnisse als Parquet-Dateien.

# %%
# Standard library
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime, timezone
import json
import os
import time
import logging
import sys
import threading

# Third-party
import geopandas as gpd
import mercantile
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from requests.exceptions import SSLError, ConnectionError, ReadTimeout, Timeout
from tqdm import tqdm
from urllib3.util.retry import Retry
from vt2geojson.tools import vt_bytes_to_geojson


from config import TILES_CONFIG, PROCESSING_CONFIG, MAPILLARY_CONFIG

# Setup Logging
log_folder = PROCESSING_CONFIG["ml_output_folder"]
os.makedirs(log_folder, exist_ok=True)
log_file = os.path.join(log_folder, f"mapillary_download_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log")

# Konfiguriere Logger
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file, encoding='utf-8'),
        logging.StreamHandler(sys.stdout)  # Auch in Console ausgeben
    ]
)

logger = logging.getLogger(__name__)
logger.info(f"=== Mapillary Coverage Download gestartet ===")
logger.info(f"Log-Datei: {log_file}")
# Out:
# 2026-03-30 01:19:21,789 - INFO - === Mapillary Coverage Download gestartet ===
# 2026-03-30 01:19:21,791 - INFO - Log-Datei: ml_output/mapillary_download_20260330_011921.log

# %%
TQDM_ENABLED = os.environ.get("TQDM_DISABLE", "0") != "1"

# %%
### Helper function for loading tile lists

def load_tiles_from_json(bundesland_id, input_folder = TILES_CONFIG["cache_folder"]):
    path = os.path.join(input_folder, f"{bundesland_id}_tiles.json")
    with open(path, "r") as f:
        tile_list = json.load(f)
    return [mercantile.Tile(**t) for t in tile_list]

# %%
def export_geodata(gdfs, output_folder = PROCESSING_CONFIG["output_folder"], base_name="mapillary_coverage", region="ger", save_parquet=True, save_geojson_gz=True):
    """
    Export one or more GeoDataFrames into output files (.parquet only, ohne Datum im Namen).
    
    Args:
        gdfs (list or GeoDataFrame): List of GeoDataFrames or a single GeoDataFrame.
        output_folder (str): Output directory (created if it doesn't exist).
        base_name (str): Base filename prefix.
        region (str): Region tag for filename.
        save_parquet (bool): Save .parquet file.
        save_geojson_gz (bool): Save .geojson.gz file (not implemented).
    
    Returns:
        str: Timestamp when data was processed (ISO format)
    """
    if gdfs is None or (isinstance(gdfs, (gpd.GeoDataFrame, pd.DataFrame)) and gdfs.empty):
        logger.warning("No data to export.")
        return None

    # Concatenate if needed
    if isinstance(gdfs, list):
        gdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))
    else:
        gdf = gdfs

    os.makedirs(output_folder, exist_ok=True)
    
    # Aktueller Zeitstempel für Metadata
    current_timestamp = datetime.now(timezone.utc).isoformat()

    if save_parquet:
        # Dateiname OHNE Datum - nur "latest"
        parquet_path = os.path.join(output_folder, f"{base_name}_{region}_latest.parquet")
        gdf.to_parquet(parquet_path, index=False)
        logger.info(f"✔ Parquet saved to: {parquet_path}")
    
    return current_timestamp

# %%
def process_bundesland(bundesland_id, region_name=None, input_folder = TILES_CONFIG["cache_folder"], output_folder = PROCESSING_CONFIG["ml_output_folder"] , max_workers=3, limit_tiles=None):
    logger.info(f"▶️ Starte Verarbeitung für {bundesland_id}...")

    tiles = load_tiles_from_json(bundesland_id, input_folder=input_folder)
    if limit_tiles:
        tiles = tiles[:limit_tiles]

    total_tiles = len(tiles)
    logger.info(f"📊 {bundesland_id}: {total_tiles} Tiles zu verarbeiten")

    ACCESS_TOKEN = MAPILLARY_CONFIG["access_token"]
    tile_layer = "sequence"
    tile_coverage = "mly1_computed_public"

    consecutive_parse_errors = 0
    MAX_CONSECUTIVE_ERRORS = 5

    processed_count = 0
    successful_count = 0

    retry_strategy = Retry(
        total=3,
        connect=3,
        read=3,
        status=3,
        backoff_factor=1.5,
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=["GET"],
        raise_on_status=False,
    )
    adapter = HTTPAdapter(
        max_retries=retry_strategy,
        pool_connections=max_workers * 2,
        pool_maxsize=max_workers * 4,
    )
    thread_local = threading.local()

    def get_session():
        session = getattr(thread_local, "session", None)
        if session is None:
            session = requests.Session()
            session.mount("https://", adapter)
            session.mount("http://", adapter)
            thread_local.session = session
        return session

    def tile_key(tile):
        return f"{tile.z}/{tile.x}/{tile.y}"

    def is_name_resolution_error(err):
        msg = str(err)
        return (
            "NameResolutionError" in msg
            or "Temporary failure in name resolution" in msg
            or "Failed to resolve" in msg
            or "gaierror" in msg
        )

    def process_tile(tile, max_retries=3):
        nonlocal consecutive_parse_errors

        url = f"https://tiles.mapillary.com/maps/vtp/{tile_coverage}/2/{tile.z}/{tile.x}/{tile.y}?access_token={ACCESS_TOKEN}"

        for attempt in range(max_retries + 1):
            try:
                session = get_session()
                response = session.get(url, timeout=(10, 30))

                if response.status_code == 429:
                    if attempt < max_retries:
                        logger.warning(f"⚠️ Rate Limit bei Tile {tile.x}/{tile.y} (Versuch {attempt + 1}/{max_retries + 1}). Pausiere 5 Minuten...")
                        time.sleep(300)
                        continue
                    logger.error(f"❌ Tile {tile.x}/{tile.y} nach {max_retries + 1} Versuchen wegen Rate Limit fehlgeschlagen")
                    return ("failed", None)

                if response.status_code != 200:
                    if response.status_code >= 500 and attempt < max_retries:
                        logger.warning(f"⚠️ HTTP {response.status_code} bei Tile {tile.x}/{tile.y} (Versuch {attempt + 1}/{max_retries + 1}). Retry in 60s...")
                        time.sleep(60)
                        continue
                    if response.status_code >= 500:
                        logger.error(f"❌ HTTP {response.status_code} bei Tile {tile.x}/{tile.y} nach allen Versuchen")
                        return ("failed", None)
                    logger.warning(f"⚠️ HTTP {response.status_code} bei Tile {tile.x}/{tile.y}")
                    return ("empty", None)

                geojson = vt_bytes_to_geojson(response.content, tile.x, tile.y, tile.z, layer=tile_layer)
                features = geojson.get("features", [])
                if not features:
                    return ("empty", None)

                gdf_tile = gpd.GeoDataFrame.from_features(features, crs="EPSG:4326")
                gdf_tile['captured_at'] = gdf_tile['captured_at'].apply(lambda x: datetime.fromtimestamp(x / 1000, tz=timezone.utc))

                min_date_str = PROCESSING_CONFIG["min_capture_date"]
                min_dt = datetime.strptime(min_date_str, "%Y-%m-%d").replace(tzinfo=timezone.utc)
                gdf_tile = gdf_tile[gdf_tile['captured_at'] >= min_dt]

                if gdf_tile.empty:
                    return ("empty", None)

                gdf_tile['captured_at'] = gdf_tile['captured_at'].dt.strftime('%Y-%m-%d')
                gdf_tile['tile_x'] = tile.x
                gdf_tile['tile_y'] = tile.y

                consecutive_parse_errors = 0
                return ("ok", gdf_tile)

            except (ConnectionError, ReadTimeout, Timeout, SSLError) as e:
                wait_seconds = 300 if is_name_resolution_error(e) else 60
                if attempt < max_retries:
                    logger.warning(
                        f"⚠️ Netzwerkfehler bei Tile {tile.x}/{tile.y} "
                        f"(Versuch {attempt + 1}/{max_retries + 1}): {e}. "
                        f"Pausiere {wait_seconds}s..."
                    )
                    time.sleep(wait_seconds)
                    continue

                logger.error(f"❌ Netzwerkfehler bei Tile {tile.x}/{tile.y} nach {max_retries + 1} Versuchen: {e}")
                return ("failed", None)

            except Exception as e:
                error_msg = str(e)

                if "Error parsing message" in error_msg or "vector_tile" in error_msg:
                    consecutive_parse_errors += 1

                    if consecutive_parse_errors >= MAX_CONSECUTIVE_ERRORS:
                        logger.error(f"🛑 {MAX_CONSECUTIVE_ERRORS} aufeinanderfolgende Parsing-Fehler! API scheint blockiert zu sein.")
                        logger.warning(f"⏸️  LANGE PAUSE: 30 Minuten warten...")
                        time.sleep(1800)
                        consecutive_parse_errors = 0
                        logger.info(f"▶️ Setze Verarbeitung fort nach langer Pause...")

                    if attempt < max_retries:
                        logger.warning(
                            f"⚠️ Parsing-Fehler bei Tile {tile.x}/{tile.y} "
                            f"(Versuch {attempt + 1}/{max_retries + 1}, konsekutiv: {consecutive_parse_errors}). "
                            f"Pausiere für 5 Minuten..."
                        )
                        time.sleep(300)
                        continue

                    logger.error(f"❌ Tile {tile.x}/{tile.y} nach {max_retries + 1} Parsing-Versuchen fehlgeschlagen: {error_msg}")
                    return ("failed", None)

                if attempt < max_retries:
                    logger.warning(
                        f"⚠️ Unbekannter Fehler bei Tile {tile.x}/{tile.y} "
                        f"(Versuch {attempt + 1}/{max_retries + 1}): {error_msg}. Retry in 60s..."
                    )
                    time.sleep(60)
                    continue

                logger.error(f"❌ Fehler bei Tile {tile.x}/{tile.y}: {error_msg}")
                return ("failed", None)

        return ("failed", None)

    def run_batch(tile_batch, desc):
        local_gdfs = []
        local_failed_tiles = []
        local_processed = 0
        local_successful = 0

        with ThreadPoolExecutor(max_workers=max_workers) as executor:
            futures = {executor.submit(process_tile, tile): tile for tile in tile_batch}
            for future in tqdm(as_completed(futures), total=len(futures), desc=desc, disable=not TQDM_ENABLED):
                tile = futures[future]
                try:
                    status, result = future.result()
                    local_processed += 1

                    if status == "ok" and result is not None:
                        local_gdfs.append(result)
                        local_successful += 1
                    elif status == "failed":
                        local_failed_tiles.append(tile)

                except Exception as e:
                    logger.error(f"⚠️ Unbekannter Fehler bei Future {tile_key(tile)}: {e}")
                    local_failed_tiles.append(tile)

        return local_gdfs, local_failed_tiles, local_processed, local_successful

    gdf_all = []

    # Erste Runde
    round_gdfs, failed_tiles, p_count, s_count = run_batch(tiles, f"🧩 {bundesland_id}")
    gdf_all.extend(round_gdfs)
    processed_count += p_count
    successful_count += s_count

    # Retry-Runde 1 am Ende des Bundeslandes
    if failed_tiles:
        failed_tiles = list({tile_key(t): t for t in failed_tiles}.values())
        logger.warning(f"🔁 {bundesland_id}: {len(failed_tiles)} fehlgeschlagene Tiles. Pausiere 5 Minuten vor Retry-Runde 1...")
        time.sleep(300)
        round_gdfs, failed_tiles, p_count, s_count = run_batch(failed_tiles, f"🔁 {bundesland_id} retry-1")
        gdf_all.extend(round_gdfs)
        processed_count += p_count
        successful_count += s_count

    # Retry-Runde 2 wenn weiterhin Fehler
    if failed_tiles:
        failed_tiles = list({tile_key(t): t for t in failed_tiles}.values())
        logger.warning(f"🔁 {bundesland_id}: Noch {len(failed_tiles)} fehlgeschlagene Tiles. Pausiere 5 Minuten vor Retry-Runde 2...")
        time.sleep(300)
        round_gdfs, failed_tiles, p_count, s_count = run_batch(failed_tiles, f"🔁 {bundesland_id} retry-2")
        gdf_all.extend(round_gdfs)
        processed_count += p_count
        successful_count += s_count

    logger.info(f"✅ {bundesland_id}: {processed_count} Tile-Versuche abgeschlossen ({successful_count} erfolgreich, {processed_count - successful_count} fehlgeschlagen/ohne Daten)")
    if failed_tiles:
        logger.error(f"❌ {bundesland_id}: Nach finalen Retries bleiben {len(failed_tiles)} Tiles fehlgeschlagen.")

    if gdf_all:
        gdf_all = gpd.GeoDataFrame(pd.concat(gdf_all, ignore_index=True))
        timestamp = export_geodata(
            gdfs=gdf_all,
            output_folder=output_folder,
            region=bundesland_id,
            save_parquet=True,
            save_geojson_gz=False
        )
        return timestamp
    else:
        logger.warning(f"⚠️ Keine Daten für {bundesland_id}.")
        return None

# %%
# Verarbeitung der Bundesländer basierend auf config.py
# takes about ~6.5h for all 16 bundesländer (on lokal machine)

# Lade Bundesländer aus Cache (wurde in Notebook 0 heruntergeladen)
bundesland_cache_path = os.path.join("prep", "bundeslaender.geojson")

if not os.path.exists(bundesland_cache_path):
    logger.error(f"❌ Bundesland-Cache nicht gefunden: {bundesland_cache_path}")
    logger.error(f"   Bitte zuerst Notebook 0_prepare_tiles.ipynb ausführen!")
    raise FileNotFoundError(f"Bundesland-GeoJSON fehlt: {bundesland_cache_path}")

logger.info(f"📂 Lade Bundesländer aus: {bundesland_cache_path}")
bland = gpd.read_file(bundesland_cache_path)

# Filter Bundesländer basierend auf config.py
from config import GEOFABRIK_CONFIG

selected_bundeslaender = GEOFABRIK_CONFIG.get("bundeslaender")
if selected_bundeslaender:
    # Nur die ausgewählten Bundesländer verarbeiten
    bland_filtered = bland[bland['id'].isin(selected_bundeslaender)]
    logger.info(f"🎯 Verarbeite {len(bland_filtered)} ausgewählte Bundesländer: {', '.join(selected_bundeslaender)}")
else:
    # Alle Bundesländer verarbeiten
    bland_filtered = bland
    logger.info(f"📍 Verarbeite alle {len(bland_filtered)} Bundesländer")

# Sammle Timestamps für Metadata
ml_timestamps = {}

for _, row in bland_filtered.iterrows():
    b_id = row["id"]
    name = row["name"]

    # Nur verarbeiten, wenn eine JSON-Datei existiert
    tile_json_path = os.path.join(TILES_CONFIG["cache_folder"], f"{b_id}_tiles.json")
    if not os.path.exists(tile_json_path):
        logger.warning(f"⏩ Überspringe {b_id}, keine Tiles gefunden.")
        continue

    # Prüfe ob Parquet bereits existiert und noch aktuell ist
    output_folder = PROCESSING_CONFIG["ml_output_folder"]
    parquet_path = os.path.join(output_folder, f"mapillary_coverage_{b_id}_latest.parquet")
    max_age_days = PROCESSING_CONFIG.get('max_file_age_days', 4)
    
    if os.path.exists(parquet_path):
        file_mtime = os.path.getmtime(parquet_path)
        file_age_days = (datetime.now().timestamp() - file_mtime) / 86400  # Sekunden in Tage
        
        if file_age_days < max_age_days:
            logger.info(f"⏩ {b_id}: Datei ist {file_age_days:.1f} Tage alt, überspringe Download")
            # Timestamp aus existierender Datei für Metadata verwenden
            ml_timestamps[b_id] = datetime.fromtimestamp(file_mtime, tz=timezone.utc).isoformat()
            continue
        else:
            logger.info(f"🔄 {b_id}: Datei ist {file_age_days:.1f} Tage alt, lade neu")

    timestamp = process_bundesland(b_id, region_name=name)
    if timestamp:
        ml_timestamps[b_id] = timestamp

# Speichere Metadata ähnlich wie osm_metadata.json
if ml_timestamps:
    # Finde ältesten Timestamp
    oldest_ml_timestamp = min(ml_timestamps.values())
    
    metadata = {
        "ml_data_from": oldest_ml_timestamp,
        "bundeslaender": ml_timestamps,
        "processed_date": datetime.now(timezone.utc).isoformat()
    }
    
    with open("output/ml_metadata.json", "w", encoding="utf-8") as f:
        json.dump(metadata, f, ensure_ascii=False, indent=2)
    
    logger.info(f"\n📅 Ältester Mapillary-Timestamp: {oldest_ml_timestamp}")
    logger.info(f"💾 Metadata gespeichert: output/ml_metadata.json")
    logger.info(f"📄 Log-Datei: {log_file}")
else:
    logger.warning("\n⚠️  Keine Mapillary-Daten verarbeitet, keine Metadata erstellt.")

logger.info("=== Mapillary Coverage Download abgeschlossen ===")
# Out:
# 2026-03-30 01:19:21,938 - INFO - 📂 Lade Bundesländer aus: prep/bundeslaender.geojson
# 2026-03-30 01:19:22,569 - INFO - 📍 Verarbeite alle 16 Bundesländer
# 2026-03-30 01:19:22,574 - INFO - 🔄 DE-BW: Datei ist 7.0 Tage alt, lade neu
# 2026-03-30 01:19:22,575 - INFO - ▶️ Starte Verarbeitung für DE-BW...
# 2026-03-30 01:19:22,636 - INFO - 📊 DE-BW: 14160 Tiles zu verarbeiten
# 2026-03-30 01:20:23,999 - WARNING - ⚠️ HTTP 404 bei Tile 8541/5686
# 2026-03-30 01:22:15,622 - WARNING - ⚠️ HTTP 404 bei Tile 8550/5691
# 2026-03-30 01:24:04,424 - WARNING - ⚠️ HTTP 404 bei Tile 8560/5654
# 2026-03-30 01:33:37,324 - WARNING - ⚠️ HTTP 404 bei Tile 8587/5686
# 2026-03-30 01:34:11,530 - WARNING - ⚠️ HTTP 404 bei Tile 8589/5618
# 2026-03-30 01:34:29,789 - WARNING - ⚠️ HTTP 404 bei Tile 8590/5592
# 2026-03-30 01:40:38,018 - WARNING - ⚠️ HTTP 404 bei Tile 8605/5667
# 2026-03-30 01:58:08,394 - WARNING - ⚠️ HTTP 404 bei Tile 8650/5700
# 2026-03-30 01:59:41,904 - INFO - ✅ DE-BW: 14160 Tile-Versuche abgeschlossen (9316 erfolgreich, 4844 fehlgeschlagen/ohne Daten)
# 2026-03-30 01:59:48,214 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BW_latest.parquet
# 2026-03-30 01:59:48,836 - INFO - 🔄 DE-BY: Datei ist 6.9 Tage alt, lade neu
# 2026-03-30 01:59:48,838 - INFO - ▶️ Starte Verarbeitung für DE-BY...
# 2026-03-30 01:59:48,936 - INFO - 📊 DE-BY: 28376 Tiles zu verarbeiten
# 2026-03-30 02:04:10,433 - WARNING - ⚠️ HTTP 404 bei Tile 8640/5720
# 2026-03-30 02:09:26,288 - WARNING - ⚠️ HTTP 404 bei Tile 8659/5603
# 2026-03-30 02:09:58,735 - WARNING - ⚠️ HTTP 404 bei Tile 8660/5708
# 2026-03-30 02:42:09,416 - WARNING - ⚠️ HTTP 404 bei Tile 8718/5563
# 2026-03-30 02:55:28,319 - WARNING - ⚠️ HTTP 404 bei Tile 8744/5706
# 2026-03-30 02:56:55,153 - WARNING - ⚠️ HTTP 404 bei Tile 8747/5651
# 2026-03-30 03:20:11,038 - INFO - ✅ DE-BY: 28376 Tile-Versuche abgeschlossen (12263 erfolgreich, 16113 fehlgeschlagen/ohne Daten)
# 2026-03-30 03:20:21,505 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BY_latest.parquet
# 2026-03-30 03:20:22,556 - INFO - 🔄 DE-BE: Datei ist 7.0 Tage alt, lade neu
# 2026-03-30 03:20:22,558 - INFO - ▶️ Starte Verarbeitung für DE-BE...
# 2026-03-30 03:20:22,563 - INFO - 📊 DE-BE: 399 Tiles zu verarbeiten
# 2026-03-30 03:32:13,063 - INFO - ✅ DE-BE: 399 Tile-Versuche abgeschlossen (393 erfolgreich, 6 fehlgeschlagen/ohne Daten)
# 2026-03-30 03:32:14,216 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BE_latest.parquet
# 2026-03-30 03:32:14,371 - INFO - 🔄 DE-BB: Datei ist 7.0 Tage alt, lade neu
# 2026-03-30 03:32:14,372 - INFO - ▶️ Starte Verarbeitung für DE-BB...
# 2026-03-30 03:32:14,449 - INFO - 📊 DE-BB: 13585 Tiles zu verarbeiten
# 2026-03-30 03:41:51,744 - WARNING - ⚠️ HTTP 404 bei Tile 8790/5408
# 2026-03-30 03:46:41,709 - WARNING - ⚠️ HTTP 404 bei Tile 8807/5449
# 2026-03-30 03:49:15,101 - WARNING - ⚠️ HTTP 404 bei Tile 8815/5332
# 2026-03-30 03:51:23,477 - WARNING - ⚠️ HTTP 404 bei Tile 8821/5330
# 2026-03-30 03:59:30,762 - INFO - ✅ DE-BB: 13585 Tile-Versuche abgeschlossen (8916 erfolgreich, 4669 fehlgeschlagen/ohne Daten)
# 2026-03-30 03:59:35,986 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-BB_latest.parquet
# 2026-03-30 03:59:36,422 - INFO - 🔄 DE-HB: Datei ist 7.0 Tage alt, lade neu
# 2026-03-30 03:59:36,424 - INFO - ▶️ Starte Verarbeitung für DE-HB...
# 2026-03-30 03:59:36,427 - INFO - 📊 DE-HB: 145 Tiles zu verarbeiten
# 2026-03-30 04:00:59,842 - INFO - ✅ DE-HB: 145 Tile-Versuche abgeschlossen (114 erfolgreich, 31 fehlgeschlagen/ohne Daten)
# 2026-03-30 04:00:59,949 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HB_latest.parquet
# 2026-03-30 04:00:59,972 - INFO - 🔄 DE-HH: Datei ist 7.0 Tage alt, lade neu
# 2026-03-30 04:00:59,973 - INFO - ▶️ Starte Verarbeitung für DE-HH...
# 2026-03-30 04:00:59,976 - INFO - 📊 DE-HH: 361 Tiles zu verarbeiten
# 2026-03-30 04:05:15,689 - INFO - ✅ DE-HH: 361 Tile-Versuche abgeschlossen (340 erfolgreich, 21 fehlgeschlagen/ohne Daten)
# 2026-03-30 04:05:15,965 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HH_latest.parquet
# 2026-03-30 04:05:16,009 - INFO - 🔄 DE-HE: Datei ist 7.0 Tage alt, lade neu
# 2026-03-30 04:05:16,012 - INFO - ▶️ Starte Verarbeitung für DE-HE...
# 2026-03-30 04:05:16,058 - INFO - 📊 DE-HE: 8704 Tiles zu verarbeiten
# 2026-03-30 04:22:53,322 - WARNING - ⚠️ HTTP 404 bei Tile 8603/5511
# 2026-03-30 04:23:20,858 - WARNING - ⚠️ HTTP 404 bei Tile 8605/5495
# 2026-03-30 04:23:43,081 - WARNING - ⚠️ HTTP 404 bei Tile 8607/5490
# 2026-03-30 04:24:04,921 - WARNING - ⚠️ HTTP 404 bei Tile 8609/5456
# 2026-03-30 04:24:36,520 - WARNING - ⚠️ HTTP 404 bei Tile 8611/5494
# 2026-03-30 04:31:31,976 - INFO - ✅ DE-HE: 8704 Tile-Versuche abgeschlossen (4678 erfolgreich, 4026 fehlgeschlagen/ohne Daten)
# 2026-03-30 04:31:35,518 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-HE_latest.parquet
# 2026-03-30 04:31:35,845 - INFO - 🔄 DE-MV: Datei ist 7.0 Tage alt, lade neu
# 2026-03-30 04:31:35,846 - INFO - ▶️ Starte Verarbeitung für DE-MV...
# 2026-03-30 04:31:35,886 - INFO - 📊 DE-MV: 12294 Tiles zu verarbeiten
# 2026-03-30 04:49:57,970 - INFO - ✅ DE-MV: 12294 Tile-Versuche abgeschlossen (3243 erfolgreich, 9051 fehlgeschlagen/ohne Daten)
# 2026-03-30 04:50:00,157 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-MV_latest.parquet
# 2026-03-30 04:50:00,323 - INFO - 🔄 DE-NI: Datei ist 7.0 Tage alt, lade neu
# 2026-03-30 04:50:00,325 - INFO - ▶️ Starte Verarbeitung für DE-NI...
# 2026-03-30 04:50:00,426 - INFO - 📊 DE-NI: 22844 Tiles zu verarbeiten
# 2026-03-30 05:06:17,307 - WARNING - ⚠️ HTTP 404 bei Tile 8584/5316
# 2026-03-30 05:07:15,674 - WARNING - ⚠️ HTTP 404 bei Tile 8590/5274
# 2026-03-30 05:08:06,816 - WARNING - ⚠️ HTTP 404 bei Tile 8594/5361
# 2026-03-30 05:10:27,388 - WARNING - ⚠️ HTTP 404 bei Tile 8606/5371
# 2026-03-30 05:26:34,648 - WARNING - ⚠️ HTTP 404 bei Tile 8652/5386
# 2026-03-30 05:26:39,267 - WARNING - ⚠️ HTTP 404 bei Tile 8652/5404
# 2026-03-30 05:31:42,833 - WARNING - ⚠️ HTTP 404 bei Tile 8666/5417
# 2026-03-30 05:39:12,798 - INFO - ✅ DE-NI: 22844 Tile-Versuche abgeschlossen (11074 erfolgreich, 11770 fehlgeschlagen/ohne Daten)
# 2026-03-30 05:39:19,862 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-NI_latest.parquet
# 2026-03-30 05:39:20,463 - INFO - 🔄 DE-NW: Datei ist 7.0 Tage alt, lade neu
# 2026-03-30 05:39:20,464 - INFO - ▶️ Starte Verarbeitung für DE-NW...
# 2026-03-30 05:39:20,517 - INFO - 📊 DE-NW: 15243 Tiles zu verarbeiten
# 2026-03-30 05:47:09,776 - WARNING - ⚠️ HTTP 404 bei Tile 8472/5515
# 2026-03-30 05:47:39,386 - WARNING - ⚠️ HTTP 404 bei Tile 8473/5519
# 2026-03-30 05:48:30,939 - WARNING - ⚠️ HTTP 404 bei Tile 8476/5422
# 2026-03-30 06:06:42,343 - WARNING - ⚠️ HTTP 404 bei Tile 8508/5446
# 2026-03-30 06:07:42,818 - WARNING - ⚠️ HTTP 404 bei Tile 8509/5487
# 2026-03-30 06:16:46,808 - WARNING - ⚠️ HTTP 404 bei Tile 8526/5468
# 2026-03-30 06:22:12,318 - WARNING - ⚠️ HTTP 404 bei Tile 8540/5473
# 2026-03-30 06:29:49,266 - WARNING - ⚠️ HTTP 404 bei Tile 8572/5434
# 2026-03-30 06:37:57,634 - INFO - ✅ DE-NW: 15243 Tile-Versuche abgeschlossen (10061 erfolgreich, 5182 fehlgeschlagen/ohne Daten)
# 2026-03-30 06:38:06,094 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-NW_latest.parquet
# 2026-03-30 06:38:06,887 - INFO - 🔄 DE-RP: Datei ist 7.0 Tage alt, lade neu
# 2026-03-30 06:38:06,889 - INFO - ▶️ Starte Verarbeitung für DE-RP...
# 2026-03-30 06:38:06,923 - INFO - 📊 DE-RP: 8240 Tiles zu verarbeiten
# 2026-03-30 06:46:24,854 - WARNING - ⚠️ HTTP 404 bei Tile 8524/5591
# 2026-03-30 06:46:28,450 - WARNING - ⚠️ HTTP 404 bei Tile 8525/5521
# 2026-03-30 06:51:12,105 - WARNING - ⚠️ HTTP 404 bei Tile 8542/5558
# 2026-03-30 06:58:10,110 - INFO - ✅ DE-RP: 8240 Tile-Versuche abgeschlossen (5409 erfolgreich, 2831 fehlgeschlagen/ohne Daten)
# 2026-03-30 06:58:14,612 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-RP_latest.parquet
# 2026-03-30 06:58:14,956 - INFO - 🔄 DE-SL: Datei ist 7.0 Tage alt, lade neu
# 2026-03-30 06:58:14,958 - INFO - ▶️ Starte Verarbeitung für DE-SL...
# 2026-03-30 06:58:14,971 - INFO - 📊 DE-SL: 1170 Tiles zu verarbeiten
# 2026-03-30 07:00:06,599 - WARNING - ⚠️ HTTP 404 bei Tile 8508/5607
# 2026-03-30 07:02:02,887 - INFO - ✅ DE-SL: 1170 Tile-Versuche abgeschlossen (663 erfolgreich, 507 fehlgeschlagen/ohne Daten)
# 2026-03-30 07:02:03,472 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SL_latest.parquet
# 2026-03-30 07:02:03,515 - INFO - 🔄 DE-ST: Datei ist 7.0 Tage alt, lade neu
# 2026-03-30 07:02:03,517 - INFO - ▶️ Starte Verarbeitung für DE-ST...
# 2026-03-30 07:02:03,549 - INFO - 📊 DE-ST: 9077 Tiles zu verarbeiten
# 2026-03-30 07:08:13,930 - WARNING - ⚠️ HTTP 404 bei Tile 8715/5397
# 2026-03-30 07:19:48,260 - INFO - ✅ DE-ST: 9077 Tile-Versuche abgeschlossen (4125 erfolgreich, 4952 fehlgeschlagen/ohne Daten)
# 2026-03-30 07:19:51,154 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-ST_latest.parquet
# 2026-03-30 07:19:51,455 - INFO - 🔄 DE-SN: Datei ist 7.0 Tage alt, lade neu
# 2026-03-30 07:19:51,457 - INFO - ▶️ Starte Verarbeitung für DE-SN...
# 2026-03-30 07:19:51,482 - INFO - 📊 DE-SN: 8311 Tiles zu verarbeiten
# 2026-03-30 07:22:11,102 - WARNING - ⚠️ HTTP 404 bei Tile 8751/5514
# 2026-03-30 07:40:14,470 - INFO - ✅ DE-SN: 8311 Tile-Versuche abgeschlossen (4327 erfolgreich, 3984 fehlgeschlagen/ohne Daten)
# 2026-03-30 07:40:17,677 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SN_latest.parquet
# 2026-03-30 07:40:18,000 - INFO - 🔄 DE-SH: Datei ist 7.0 Tage alt, lade neu
# 2026-03-30 07:40:18,002 - INFO - ▶️ Starte Verarbeitung für DE-SH...
# 2026-03-30 07:40:18,041 - INFO - 📊 DE-SH: 9101 Tiles zu verarbeiten
# 2026-03-30 07:55:54,209 - WARNING - ⚠️ HTTP 404 bei Tile 8678/5245
# 2026-03-30 07:58:02,946 - INFO - ✅ DE-SH: 9101 Tile-Versuche abgeschlossen (4230 erfolgreich, 4871 fehlgeschlagen/ohne Daten)
# 2026-03-30 07:58:06,026 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-SH_latest.parquet
# 2026-03-30 07:58:06,296 - INFO - 🔄 DE-TH: Datei ist 7.0 Tage alt, lade neu
# 2026-03-30 07:58:06,297 - INFO - ▶️ Starte Verarbeitung für DE-TH...
# 2026-03-30 07:58:06,339 - INFO - 📊 DE-TH: 6819 Tiles zu verarbeiten
# 2026-03-30 08:12:14,372 - INFO - ✅ DE-TH: 6819 Tile-Versuche abgeschlossen (2753 erfolgreich, 4066 fehlgeschlagen/ohne Daten)
# 2026-03-30 08:12:16,420 - INFO - ✔ Parquet saved to: ml_output/mapillary_coverage_DE-TH_latest.parquet
# 2026-03-30 08:12:16,596 - INFO -
# 📅 Ältester Mapillary-Timestamp: 2026-03-30T01:59:47.044240+00:00
# 2026-03-30 08:12:16,599 - INFO - 💾 Metadata gespeichert: output/ml_metadata.json
# 2026-03-30 08:12:16,600 - INFO - 📄 Log-Datei: ml_output/mapillary_download_20260330_011921.log
# 2026-03-30 08:12:16,603 - INFO - === Mapillary Coverage Download abgeschlossen ===
